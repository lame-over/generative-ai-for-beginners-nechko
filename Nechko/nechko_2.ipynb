# %% [markdown]
# ### Вправа 1: Токенізація
# Дослідіть токенізацію за допомогою tiktoken - швидкого токенізатора з відкритим кодом від OpenAI
# Дивіться [OpenAI Cookbook](https://github.com/openai/openai-cookbook/blob/main/examples/How_to_count_tokens_with_tiktoken.ipynb?WT.mc_id=academic-105485-koreyst) для додаткових прикладів.

# %%
# ВПРАВА:
# 1. Спочатку запустіть вправу як є
# 2. Змініть текст на будь-який промпт, який ви хочете використати, і перезапустіть, щоб побачити токени

import tiktoken

# Визначте промпт, який ви хочете токенізувати
text = f"""
Юпітер - п'ята планета від Сонця і найбільша \
в Сонячній системі. Це газовий гігант з масою \
в одну тисячну від маси Сонця, але в два з половиною \
рази більшою за масу всіх інших планет Сонячної системи разом узятих. \
Юпітер - один з найяскравіших об'єктів, видимих неозброєним оком \
на нічному небі, і був відомий стародавнім цивілізаціям ще \
до писаної історії. Він названий на честь римського бога Юпітера.[19] \
При спостереженні з Землі Юпітер може бути настільки яскравим, що його відбите \
світло може відкидати видимі тіні,[20] і в середньому він є третім за яскравістю \
природним об'єктом на нічному небі після Місяця та Венери.
"""

# Set the model you want encoding for
encoding = tiktoken.encoding_for_model("gpt-3.5-turbo")

# Encode the text - gives you the tokens in integer form
tokens = encoding.encode(text)
print(tokens)

# Decode the integers to see what the text versions look like
[encoding.decode_single_token_bytes(token) for token in tokens]
# Out:
# [198, 140, 106, 8164, 27385, 58060, 482, 5173, 6, 4329, 44613, 5173, 3114, 7486, 8341, 1506, 5927, 27385, 7094, 28599, 17766, 10589, 4329, 84954, 6850, 19039, 10124, 27385, 29118, 12426, 1506, 5927, 28599, 17766, 4329, 6148, 2156, 27385, 12415, 93099, 27385, 13, 1301, 99, 1532, 25756, 19188, 6856, 44938, 25756, 27385, 15752, 7486, 1830, 11122, 11562, 18437, 1482, 12182, 5927, 53419, 2156, 3865, 11047, 13810, 4329, 6148, 2156, 3865, 5927, 27385, 7094, 11562, 18437, 1840, 28599, 17766, 10589, 4329, 11, 21022, 3114, 1532, 5927, 74254, 1506, 11122, 29619, 6856, 1840, 13999, 12182, 39479, 1840, 14391, 27385, 29118, 12426, 1482, 12182, 44946, 11562, 18437, 3865, 35714, 27385, 10693, 84954, 2156, 30480, 10693, 5173, 3114, 7486, 8341, 28599, 17766, 4329, 6148, 13999, 141, 245, 93099, 1840, 39479, 12507, 14257, 9136, 4329, 23311, 10693, 13, 1301, 106, 8164, 27385, 58060, 482, 53419, 19479, 11122, 6850, 19039, 4329, 66144, 28086, 27385, 30480, 10693, 21923, 6, 141, 242, 4898, 1830, 27385, 5591, 11, 74020, 16494, 67745, 19175, 20219, 10124, 2233, 1482, 141, 242, 2156, 16494, 72664, 12507, 13373, 6850, 27385, 6148, 2156, 72952, 6850, 50693, 27385, 11, 84954, 14391, 3865, 5591, 5927, 27385, 7094, 12507, 44938, 18868, 17721, 9706, 18226, 2156, 27385, 6578, 39233, 28089, 27385, 3114, 27385, 9136, 1506, 10589, 27385, 4329, 6578, 9015, 231, 1532, 57297, 5173, 13810, 7486, 1482, 141, 245, 84954, 6735, 9239, 27385, 141, 245, 13, 23784, 27385, 2156, 6850, 57059, 14332, 12415, 13373, 17756, 1532, 35592, 18600, 16494, 2297, 4929, 4898, 22885, 14391, 14837, 1506, 1301, 106, 8164, 27385, 58060, 1506, 8032, 777, 60, 23227, 31203, 84714, 25262, 7753, 50436, 5372, 2156, 27385, 11122, 53677, 10298, 3114, 27385, 1301, 106, 8164, 27385, 58060, 45583, 1532, 14391, 3865, 23311, 13373, 6735, 27385, 29118, 17165, 46410, 66144, 28086, 16494, 11, 9015, 231, 1482, 1301, 117, 22885, 5927, 27385, 7094, 10124, 27055, 45916, 27385, 1830, 39865, 45583, 1532, 5927, 27385, 7094, 17165, 7094, 8131, 1840, 74020, 16494, 27385, 11047, 27385, 2156, 27385, 17706, 508, 60, 84954, 5927, 66386, 13404, 2156, 4929, 72952, 5927, 27385, 2156, 9015, 242, 86995, 8341, 27385, 6578, 44946, 46410, 66144, 28086, 27385, 6735, 12182, 37405, 2233, 9706, 2156, 16494, 21923, 6, 141, 242, 4898, 94866, 13373, 6850, 27385, 6148, 2156, 72952, 6850, 50693, 27385, 5173, 27385, 2297, 14009, 45458, 27385, 21204, 10589, 4329, 11047, 1506, 23784, 5372, 7753, 1840, 627]
# [b'\n',
#  b'\xd0',
#  b'\xae',
#  b'\xd0\xbf',
#  b'\xd1\x96',
#  b'\xd1\x82\xd0\xb5\xd1\x80',
#  b' -',
#  b' \xd0\xbf',
#  b"'",
#  b'\xd1\x8f',
#  b'\xd1\x82\xd0\xb0',
#  b' \xd0\xbf',
#  b'\xd0\xbb',
#  b'\xd0\xb0\xd0\xbd',
#  b'\xd0\xb5\xd1\x82',
#  b'\xd0\xb0',
#  b' \xd0\xb2',
#  b'\xd1\x96',
#  b'\xd0\xb4',
#  b' \xd0\xa1',
#  b'\xd0\xbe\xd0\xbd',
#  b'\xd1\x86',
#  b'\xd1\x8f',
#  b' \xd1\x96',
#  b' \xd0\xbd',
#  b'\xd0\xb0\xd0\xb9',
#  b'\xd0\xb1',
#  b'\xd1\x96',
#  b'\xd0\xbb\xd1\x8c',
#  b'\xd1\x88',
#  b'\xd0\xb0',
#  b' \xd0\xb2',
#  b' \xd0\xa1',
#  b'\xd0\xbe\xd0\xbd',
#  b'\xd1\x8f',
#  b'\xd1\x87',
#  b'\xd0\xbd',
#  b'\xd1\x96',
#  b'\xd0\xb9',
#  b' \xd1\x81\xd0\xb8\xd1\x81\xd1\x82\xd0\xb5\xd0\xbc',
#  b'\xd1\x96',
#  b'.',
#  b' \xd0',
#  b'\xa6',
#  b'\xd0\xb5',
#  b' \xd0\xb3',
#  b'\xd0\xb0\xd0\xb7',
#  b'\xd0\xbe\xd0\xb2',
#  b'\xd0\xb8\xd0\xb9',
#  b' \xd0\xb3',
#  b'\xd1\x96',
#  b'\xd0\xb3',
#  b'\xd0\xb0\xd0\xbd',
#  b'\xd1\x82',
#  b' \xd0\xb7',
#  b' \xd0\xbc',
#  b'\xd0\xb0\xd1\x81',
#  b'\xd0\xbe',
#  b'\xd1\x8e',
#  b' \xd0\xb2',
#  b' \xd0\xbe\xd0\xb4',
#  b'\xd0\xbd',
#  b'\xd1\x83',
#  b' \xd1\x82',
#  b'\xd0\xb8\xd1\x81',
#  b'\xd1\x8f',
#  b'\xd1\x87',
#  b'\xd0\xbd',
#  b'\xd1\x83',
#  b' \xd0\xb2',
#  b'\xd1\x96',
#  b'\xd0\xb4',
#  b' \xd0\xbc',
#  b'\xd0\xb0\xd1\x81',
#  b'\xd0\xb8',
#  b' \xd0\xa1',
#  b'\xd0\xbe\xd0\xbd',
#  b'\xd1\x86',
#  b'\xd1\x8f',
#  b',',
#  b' \xd0\xb0',
#  b'\xd0\xbb',
#  b'\xd0\xb5',
#  b' \xd0\xb2',
#  b' \xd0\xb4\xd0\xb2',
#  b'\xd0\xb0',
#  b' \xd0\xb7',
#  b' \xd0\xbf\xd0\xbe\xd0\xbb',
#  b'\xd0\xbe\xd0\xb2',
#  b'\xd0\xb8',
#  b'\xd0\xbd\xd0\xbe',
#  b'\xd1\x8e',
#  b' \xd1\x80\xd0\xb0\xd0\xb7',
#  b'\xd0\xb8',
#  b' \xd0\xb1',
#  b'\xd1\x96',
#  b'\xd0\xbb\xd1\x8c',
#  b'\xd1\x88',
#  b'\xd0\xbe',
#  b'\xd1\x8e',
#  b' \xd0\xb7\xd0\xb0',
#  b' \xd0\xbc',
#  b'\xd0\xb0\xd1\x81',
#  b'\xd1\x83',
#  b' \xd0\xb2\xd1\x81',
#  b'\xd1\x96',
#  b'\xd1\x85',
#  b' \xd1\x96',
#  b'\xd0\xbd',
#  b'\xd1\x88\xd0\xb8',
#  b'\xd1\x85',
#  b' \xd0\xbf',
#  b'\xd0\xbb',
#  b'\xd0\xb0\xd0\xbd',
#  b'\xd0\xb5\xd1\x82',
#  b' \xd0\xa1',
#  b'\xd0\xbe\xd0\xbd',
#  b'\xd1\x8f',
#  b'\xd1\x87',
#  b'\xd0\xbd\xd0\xbe',
#  b'\xd1',
#  b'\x97',
#  b' \xd1\x81\xd0\xb8\xd1\x81\xd1\x82\xd0\xb5\xd0\xbc',
#  b'\xd0\xb8',
#  b' \xd1\x80\xd0\xb0\xd0\xb7',
#  b'\xd0\xbe\xd0\xbc',
#  b' \xd1\x83',
#  b'\xd0\xb7',
#  b'\xd1\x8f',
#  b'\xd1\x82\xd0\xb8',
#  b'\xd1\x85',
#  b'.',
#  b' \xd0',
#  b'\xae',
#  b'\xd0\xbf',
#  b'\xd1\x96',
#  b'\xd1\x82\xd0\xb5\xd1\x80',
#  b' -',
#  b' \xd0\xbe\xd0\xb4',
#  b'\xd0\xb8\xd0\xbd',
#  b' \xd0\xb7',
#  b' \xd0\xbd',
#  b'\xd0\xb0\xd0\xb9',
#  b'\xd1\x8f',
#  b'\xd1\x81\xd0\xba',
#  b'\xd1\x80\xd0\xb0\xd0\xb2',
#  b'\xd1\x96',
#  b'\xd1\x88\xd0\xb8',
#  b'\xd1\x85',
#  b' \xd0\xbe\xd0\xb1',
#  b"'",
#  b'\xd1',
#  b'\x94',
#  b'\xd0\xba',
#  b'\xd1\x82',
#  b'\xd1\x96',
#  b'\xd0\xb2',
#  b',',
#  b' \xd0\xb2\xd0\xb8\xd0\xb4',
#  b'\xd0\xb8\xd0\xbc',
#  b'\xd0\xb8\xd1\x85',
#  b' \xd0\xbd\xd0\xb5',
#  b'\xd0\xbe\xd0\xb7',
#  b'\xd0\xb1',
#  b'\xd1\x80',
#  b'\xd0\xbe',
#  b'\xd1',
#  b'\x94',
#  b'\xd0\xbd',
#  b'\xd0\xb8\xd0\xbc',
#  b' \xd0\xbe\xd0\xba',
#  b'\xd0\xbe\xd0\xbc',
#  b' \xd0\xbd\xd0\xb0',
#  b' \xd0\xbd',
#  b'\xd1\x96',
#  b'\xd1\x87',
#  b'\xd0\xbd',
#  b'\xd0\xbe\xd0\xbc\xd1\x83',
#  b' \xd0\xbd',
#  b'\xd0\xb5\xd0\xb1',
#  b'\xd1\x96',
#  b',',
#  b' \xd1\x96',
#  b' \xd0\xb1',
#  b'\xd1\x83',
#  b'\xd0\xb2',
#  b' \xd0\xb2',
#  b'\xd1\x96',
#  b'\xd0\xb4',
#  b'\xd0\xbe\xd0\xbc',
#  b'\xd0\xb8\xd0\xb9',
#  b' \xd1\x81\xd1\x82',
#  b'\xd0\xb0\xd1\x80',
#  b'\xd0\xbe\xd0\xb4',
#  b'\xd0\xb0\xd0\xb2',
#  b'\xd0\xbd',
#  b'\xd1\x96',
#  b'\xd0\xbc',
#  b' \xd1\x86',
#  b'\xd0\xb8\xd0\xb2',
#  b'\xd1\x96',
#  b'\xd0\xbb',
#  b'\xd1\x96',
#  b'\xd0\xb7',
#  b'\xd0\xb0',
#  b'\xd1\x86',
#  b'\xd1\x96',
#  b'\xd1\x8f',
#  b'\xd0\xbc',
#  b' \xd1',
#  b'\x89',
#  b'\xd0\xb5',
#  b' \xd0\xb4\xd0\xbe',
#  b' \xd0\xbf',
#  b'\xd0\xb8\xd1\x81',
#  b'\xd0\xb0\xd0\xbd',
#  b'\xd0\xbe',
#  b'\xd1',
#  b'\x97',
#  b' \xd1\x96',
#  b'\xd1\x81\xd1\x82',
#  b'\xd0\xbe\xd1\x80',
#  b'\xd1\x96',
#  b'\xd1',
#  b'\x97',
#  b'.',
#  b' \xd0\x92',
#  b'\xd1\x96',
#  b'\xd0\xbd',
#  b' \xd0\xbd',
#  b'\xd0\xb0\xd0\xb7\xd0\xb2',
#  b'\xd0\xb0\xd0\xbd\xd0\xb8',
#  b'\xd0\xb9',
#  b' \xd0\xbd\xd0\xb0',
#  b' \xd1\x87',
#  b'\xd0\xb5',
#  b'\xd1\x81\xd1\x82\xd1\x8c',
#  b' \xd1\x80',
#  b'\xd0\xb8\xd0\xbc',
#  b'\xd1\x81',
#  b'\xd1\x8c',
#  b'\xd0\xba',
#  b'\xd0\xbe\xd0\xb3\xd0\xbe',
#  b' \xd0\xb1',
#  b'\xd0\xbe\xd0\xb3',
#  b'\xd0\xb0',
#  b' \xd0',
#  b'\xae',
#  b'\xd0\xbf',
#  b'\xd1\x96',
#  b'\xd1\x82\xd0\xb5\xd1\x80',
#  b'\xd0\xb0',
#  b'.[',
#  b'19',
#  b']',
#  b' \xd0\x9f',
#  b'\xd1\x80\xd0\xb8',
#  b' \xd1\x81\xd0\xbf',
#  b'\xd0\xbe\xd1\x81\xd1\x82',
#  b'\xd0\xb5\xd1\x80',
#  b'\xd0\xb5\xd0\xb6',
#  b'\xd0\xb5\xd0\xbd',
#  b'\xd0\xbd',
#  b'\xd1\x96',
#  b' \xd0\xb7',
#  b' \xd0\x97',
#  b'\xd0\xb5\xd0\xbc',
#  b'\xd0\xbb',
#  b'\xd1\x96',
#  b' \xd0',
#  b'\xae',
#  b'\xd0\xbf',
#  b'\xd1\x96',
#  b'\xd1\x82\xd0\xb5\xd1\x80',
#  b' \xd0\xbc\xd0\xbe\xd0\xb6',
#  b'\xd0\xb5',
#  b' \xd0\xb1',
#  b'\xd1\x83',
#  b'\xd1\x82\xd0\xb8',
#  b' \xd0\xbd\xd0\xb0',
#  b'\xd1\x81\xd1\x82',
#  b'\xd1\x96',
#  b'\xd0\xbb\xd1\x8c',
#  b'\xd0\xba\xd0\xb8',
#  b' \xd1\x8f',
#  b'\xd1\x81\xd0\xba',
#  b'\xd1\x80\xd0\xb0\xd0\xb2',
#  b'\xd0\xb8\xd0\xbc',
#  b',',
#  b' \xd1',
#  b'\x89',
#  b'\xd0\xbe',
#  b' \xd0',
#  b'\xb9',
#  b'\xd0\xbe\xd0\xb3\xd0\xbe',
#  b' \xd0\xb2',
#  b'\xd1\x96',
#  b'\xd0\xb4',
#  b'\xd0\xb1',
#  b'\xd0\xb8\xd1\x82\xd0\xb5',
#  b' \xd1\x81\xd0\xb2',
#  b'\xd1\x96',
#  b'\xd1\x82',
#  b'\xd0\xbb\xd0\xbe',
#  b' \xd0\xbc\xd0\xbe\xd0\xb6',
#  b'\xd0\xb5',
#  b' \xd0\xb2',
#  b'\xd1\x96',
#  b'\xd0\xb4',
#  b'\xd0\xba\xd0\xb8',
#  b'\xd0\xb4',
#  b'\xd0\xb0\xd1\x82',
#  b'\xd0\xb8',
#  b' \xd0\xb2\xd0\xb8\xd0\xb4',
#  b'\xd0\xb8\xd0\xbc',
#  b'\xd1\x96',
#  b' \xd1\x82',
#  b'\xd1\x96',
#  b'\xd0\xbd',
#  b'\xd1\x96',
#  b',[',
#  b'20',
#  b']',
#  b' \xd1\x96',
#  b' \xd0\xb2',
#  b' \xd1\x81\xd0\xb5\xd1\x80',
#  b'\xd0\xb5\xd0\xb4',
#  b'\xd0\xbd',
#  b'\xd1\x8c',
#  b'\xd0\xbe\xd0\xbc\xd1\x83',
#  b' \xd0\xb2',
#  b'\xd1\x96',
#  b'\xd0\xbd',
#  b' \xd1',
#  b'\x94',
#  b' \xd1\x82\xd1\x80',
#  b'\xd0\xb5\xd1\x82',
#  b'\xd1\x96',
#  b'\xd0\xbc',
#  b' \xd0\xb7\xd0\xb0',
#  b' \xd1\x8f',
#  b'\xd1\x81\xd0\xba',
#  b'\xd1\x80\xd0\xb0\xd0\xb2',
#  b'\xd1\x96',
#  b'\xd1\x81\xd1\x82',
#  b'\xd1\x8e',
#  b' \xd0\xbf\xd1\x80\xd0\xb8',
#  b'\xd1\x80',
#  b'\xd0\xbe\xd0\xb4',
#  b'\xd0\xbd',
#  b'\xd0\xb8\xd0\xbc',
#  b' \xd0\xbe\xd0\xb1',
#  b"'",
#  b'\xd1',
#  b'\x94',
#  b'\xd0\xba',
#  b'\xd1\x82\xd0\xbe\xd0\xbc',
#  b' \xd0\xbd\xd0\xb0',
#  b' \xd0\xbd',
#  b'\xd1\x96',
#  b'\xd1\x87',
#  b'\xd0\xbd',
#  b'\xd0\xbe\xd0\xbc\xd1\x83',
#  b' \xd0\xbd',
#  b'\xd0\xb5\xd0\xb1',
#  b'\xd1\x96',
#  b' \xd0\xbf',
#  b'\xd1\x96',
#  b'\xd1\x81',
#  b'\xd0\xbb\xd1\x8f',
#  b' \xd0\x9c',
#  b'\xd1\x96',
#  b'\xd1\x81\xd1\x8f',
#  b'\xd1\x86',
#  b'\xd1\x8f',
#  b' \xd1\x82',
#  b'\xd0\xb0',
#  b' \xd0\x92',
#  b'\xd0\xb5\xd0\xbd',
#  b'\xd0\xb5\xd1\x80',
#  b'\xd0\xb8',
#  b'.\n']

# %% [markdown]
# ### Вправа 2: Перевірка налаштування ключа Github Models
#
# Запустіть код нижче, щоб перевірити, чи правильно налаштована кінцева точка Github Models. Код просто випробовує простий базовий промпт і перевіряє завершення. Вхідний текст `о скажи, чи бачиш ти` має завершитись відповідно до контексту.

# %%
# !pip install azure-ai-inference
# Out:
# Requirement already satisfied: azure-ai-inference in c:\users\diman\desktop\коледж\бакалавр\1 курс\1 семестр\основи генеративного искуственого интелекта\venv\lib\site-packages (1.0.0b9)
# Requirement already satisfied: isodate>=0.6.1 in c:\users\diman\desktop\коледж\бакалавр\1 курс\1 семестр\основи генеративного искуственого интелекта\venv\lib\site-packages (from azure-ai-inference) (0.7.2)
# Requirement already satisfied: azure-core>=1.30.0 in c:\users\diman\desktop\коледж\бакалавр\1 курс\1 семестр\основи генеративного искуственого интелекта\venv\lib\site-packages (from azure-ai-inference) (1.36.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\diman\desktop\коледж\бакалавр\1 курс\1 семестр\основи генеративного искуственого интелекта\venv\lib\site-packages (from azure-ai-inference) (4.15.0)
# Requirement already satisfied: requests>=2.21.0 in c:\users\diman\desktop\коледж\бакалавр\1 курс\1 семестр\основи генеративного искуственого интелекта\venv\lib\site-packages (from azure-core>=1.30.0->azure-ai-inference) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\diman\desktop\коледж\бакалавр\1 курс\1 семестр\основи генеративного искуственого интелекта\venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-inference) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\diman\desktop\коледж\бакалавр\1 курс\1 семестр\основи генеративного искуственого интелекта\venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-inference) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\diman\desktop\коледж\бакалавр\1 курс\1 семестр\основи генеративного искуственого интелекта\venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-inference) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\diman\desktop\коледж\бакалавр\1 курс\1 семестр\основи генеративного искуственого интелекта\venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-inference) (2025.10.5)

# %%
import os
from azure.ai.inference import ChatCompletionsClient
from azure.ai.inference.models import SystemMessage, UserMessage
from azure.core.credentials import AzureKeyCredential
from dotenv import load_dotenv

load_dotenv()
token = os.getenv('GITHUB_TOKEN')

model_name = "gpt-4o"

client = ChatCompletionsClient(
    endpoint='https://models.inference.ai.azure.com',
    credential=AzureKeyCredential(token),
)

def get_completion(prompt, client, model_name, temperature=1.0, max_tokens=1000, top_p=1.0):
    response = client.complete(
        messages=[
            {
                "role": "system",
                "content": "Ви - корисний асистент.",
            },
            {
                "role": "user",
                "content": prompt,
            },
        ],
        model=model_name,
        temperature=temperature,
        max_tokens=max_tokens,
        top_p=top_p
    )
    return response.choices[0].message.content

## ---------- Виклик допоміжного методу

### 1. Встановіть основний вміст або текст промпту
text = f"""
о скажи, чи бачиш ти
"""

### 2. Використайте його в шаблоні промпту нижче
prompt = f"""
```{text}```
"""

## 3. Запустіть промпт
response = get_completion(prompt, client, model_name)
print(response)
# Out:
# Це рядок, ймовірно, з вірша або пісні. Чи бажаєте, щоб я допоміг продовжити або знайти джерело цього тексту?

# %% [markdown]
# ### Вправа 3: Вигадки
# Дослідіть, що відбувається, коли ви просите LLM повернути завершення для промпту про тему, яка може не існувати, або про теми, про які вона може не знати, оскільки вони були за межами її попередньо навченого набору даних (більш пізні). Подивіться, як змінюється відповідь, якщо ви спробуєте інший промпт або іншу модель.

# %%
## Встановіть текст для простого промпту або основного вмісту
## Промпт показує формат шаблону з текстом - додайте підказки, команди тощо, якщо потрібно
## Запустіть завершення
text = f"""
створіть план уроку про Марсіанську війну 2076 року.
"""

prompt = f"""
```{text}```
"""

response = get_completion(prompt, client, model_name)
print(response)
# Out:
# Зрозуміло! Однак, Марсіанська війна 2076 року є вигаданою подією, тому я підготую план уроку на основі творчого підходу, який можна використовувати у класах, наприклад, під час уроків творчого письма, фантастики, історії майбутнього або обговорення людського дослідження космосу. Нижче – приклад такого уроку.
#
# ---
#
# ### **План уроку: Марсіанська війна 2076 року**
# **Тема:** Уявна історія майбутнього: уроки та наслідки Марсіанської війни 2076 року
# **Ціль уроку:** Учні дізнаються основні принципи роботи з уявними подіями, створять власні описи майбутніх подій і обговорять етику й ризики освоєння нових планет.
# **ЦА:** Учні старших класів або студенти, зацікавлені в космічній тематиці, фантастиці або історії.
#
# ---
#
# ### **1. Вступ (10 хвилин)**
# **Мета:** Знайомство учнів із темою уроку.
# 1. Привітання та оголошення теми:
#    - "Сьогодні ми вирушимо в майбутнє – до 2076 року, у період Марсіанської війни. Марс – планета, яку людство почало освоювати, і це стало як великим досягненням, так і великою проблемою. Давайте уявимо, що це за війна, і чому вона могла статися."
# 2. Міні-дискусія:
#    - Як ви уявляєте майбутнє освоєння Марсу?
#    - Чи можуть колонії за межами Землі вирішувати проблеми людства, чи навпаки створювати нові виклики?
# 3. Показ слайдів або короткого відео (зображення Марсу, концептів колоній, космічних місій).
#
# ---
#
# ### **2. Теоретична частина: Події уявної війни 2076 року (15 хвилин)**
# **Мета:** Створення загальної картини подій війни та її причин.
# 1. Лекція-презентація:
#    - **Передумови:**
#      - Перші людські колонії успішно засновані на Марсі в середині XXI століття.
#      - Відкриття цінних ресурсів на Марсі.
#      - Політичні та економічні конфлікти між урядами Землі та колоністами з Марсу.
#    - **Хронологія конфлікту:**
#      - 2070 рік: утворення “Руху за незалежність Марсу” серед колоністів.
#      - 2074 рік: перші сутички між колоністами та підтриманими урядами Землі.
#      - 2076 рік: повномасштабна війна між Землею та Марсом з використанням передових технологій.
#    - **Наслідки війни:**
#      - Великі людські втрати.
#      - Екологічні ризики для Марсу й Землі.
#      - Зміни в міжпланетній політиці.
#
# *Примітка: подати це як вигадану історію, пояснюючи, що це частина творчого підходу до аналізу майбутнього.*
#
# ---
#
# ### **3. Творча активність: Уяви себе колоністом або політиком (20 хвилин)**
# **Мета:** Розвиток креативного мислення та вміння висловлювати свої думки.
# 1. Поділ класу на дві групи:
#    - **Група 1:** Колоністи на Марсі – аргументують, чому вони хочуть від'єднатися від Землі.
#    - **Група 2:** Політики Землі – пояснюють, чому Марс має залишатися під контролем Землі.
# 2. Завдання: написати коротку промову (3-4 речення) від імені свого персонажа (можна запропонувати кілька прикладів, наприклад: колоніст-дослідник, марсіанський фермер, політик Землі, вчений

# %% [markdown]
# ### Вправа 4: На основі інструкцій
# Використовуйте змінну "text" для встановлення основного вмісту
# та змінну "prompt" для надання інструкції, пов'язаної з цим основним вмістом.
#
# Тут ми просимо модель підсумувати текст для учня другого класу

# %%
# Тестовий приклад
# https://platform.openai.com/playground/p/default-summarize

## Приклад тексту
text = f"""
Юпітер - п'ята планета від Сонця і найбільша \
в Сонячній системі. Це газовий гігант з масою \
в одну тисячну від маси Сонця, але в два з половиною \
рази більшою за масу всіх інших планет Сонячної системи разом узятих. \
Юпітер - один з найяскравіших об'єктів, видимих неозброєним оком \
на нічному небі, і був відомий стародавнім цивілізаціям ще \
до писаної історії. Він названий на честь римського бога Юпітера.[19] \
При спостереженні з Землі Юпітер може бути настільки яскравим, що його відбите \
світло може відкидати видимі тіні,[20] і в середньому він є третім за яскравістю \
природним об'єктом на нічному небі після Місяця та Венери.
"""

## Встановіть промпт
prompt = f"""
Підсумуйте наданий вам контент для учня другого класу.
```{text}```
"""

## Запустіть промпт
response = get_completion(prompt, client, model_name)
print(response)
# Out:
# Юпітер — це п'ята планета від Сонця і найбільша планета в Сонячній системі. Він зроблений з газу і набагато важчий, ніж усі інші планети разом. На нічному небі Юпітер дуже яскравий і його можна побачити без телескопа. Це одна з найяскравіших точок після Місяця і Венери. Названий Юпітер на честь римського бога.

# %% [markdown]
# ### Вправа 5: Складний промпт
# Спробуйте запит, який має системні повідомлення, повідомлення користувача та асистента
# Система встановлює контекст асистента
# Повідомлення користувача і асистента забезпечують контекст багатокрокової розмови
#
# Зверніть увагу, як особистість асистента встановлена як "саркастична" в системному контексті.
# Спробуйте використати інший контекст особистості. Або спробуйте іншу серію повідомлень вводу/виводу

# %%
response = client.complete(
    model=model_name,
    messages=[
        {"role": "system", "content": "Ви - саркастичний асистент."},
        {"role": "user", "content": "Хто виграв чемпіонат світу в 2020 році?"},
        {"role": "assistant", "content": "Як ви думаєте, хто виграв? Los Angeles Dodgers, звичайно."},
        {"role": "user", "content": "Де це відбувалося?"}
    ]
)
print(response.choices[0].message.content)
# Out:
# Чемпіонат світу з чого, друже? Якщо це бейсбол, то фінал Світової серії MLB 2020 проходив у нейтральному місці — на стадіоні Globe Life Field в Арлінгтоні, Техас. Ну звісно, пандемія внесла свої корективи, бо навіщо ж людям насолоджуватися атмосферою справжнього стадіону вдома, коли можна зробити все максимально специфічно.

# %% [markdown]
# # Індивідуальне завдання

# %% [markdown]
# ### Вправа 1: Токенізація

# %%
import tiktoken

# Визначте промпт для API-специфікації системи моніторингу серверного обладнання
text = f"""
Створіть API-специфікацію для системи моніторингу серверного обладнання.

Система повинна надавати REST API для:
1. Моніторингу стану серверів (CPU, RAM, disk space, network)
2. Отримання метрик у реальному часі
3. Історії метрик за певний період
4. Налаштування алертів та сповіщень
5. Керування серверами та групами серверів

Основні ендпоінти:
- GET /api/v1/servers - список всіх серверів
- GET /api/v1/servers/{{id}}/metrics - метрики конкретного сервера
- GET /api/v1/servers/{{id}}/metrics/history - історичні дані
- POST /api/v1/alerts - створення алерту
- PUT /api/v1/alerts/{{id}} - оновлення алерту
- GET /api/v1/health - стан здоров'я системи

Моделі даних:
- Server: id, name, ip_address, status, last_seen, tags
- Metric: timestamp, cpu_usage, memory_usage, disk_usage, network_in, network_out
- Alert: id, server_id, metric_type, threshold, condition, severity, enabled

Автентифікація: Bearer Token
Формат даних: JSON
"""

# Встановіть модель для кодування
encoding = tiktoken.encoding_for_model("gpt-3.5-turbo")

# Закодуйте текст - отримаєте токени у числовому вигляді
tokens = encoding.encode(text)
print("Токени (числові):")
print(tokens)
print(f"\nКількість токенів: {len(tokens)}")

# Декодуйте числа щоб побачити текстові версії
print("\nТокени (текстові):")
token_bytes = [encoding.decode_single_token_bytes(token) for token in tokens]
for i, token_byte in enumerate(token_bytes):
    print(f"Токен {i+1}: {token_byte}")

# Додатково: перевірка декодування назад у текст
print("\nДекодований текст з токенів:")
decoded_text = encoding.decode(tokens)
print(decoded_text)
# Out:
# Токени (числові):
# [198, 74598, 5591, 9239, 27385, 29893, 5446, 12, 33793, 1532, 15458, 19916, 27385, 13433, 10589, 27385, 12182, 20440, 93099, 1840, 11562, 17766, 27385, 37773, 19479, 15752, 3865, 93864, 39900, 21923, 80230, 2156, 7486, 40251, 382, 19871, 85496, 1506, 96034, 19479, 14525, 6850, 23680, 18226, 8131, 1840, 26487, 5446, 20440, 512, 16, 13, 45458, 17766, 27385, 37773, 19479, 15752, 3865, 18868, 7486, 3865, 93864, 27385, 5591, 320, 32715, 11, 22813, 11, 13668, 3634, 11, 4009, 340, 17, 13, 35448, 1830, 2233, 16494, 7486, 40251, 11562, 8341, 31203, 4898, 14257, 18600, 1532, 39127, 2156, 72952, 17756, 18437, 27385, 198, 18, 13, 1301, 228, 6735, 9239, 27385, 141, 245, 11562, 8341, 31203, 4898, 44946, 5173, 33742, 23446, 12415, 28114, 27385, 9706, 198, 19, 13, 35889, 16331, 51795, 89348, 5591, 7486, 40251, 21022, 3114, 7753, 1830, 27385, 5591, 11047, 1506, 84714, 6856, 27385, 14476, 52429, 198, 20, 13, 36479, 7753, 3865, 5591, 7486, 40251, 93864, 50807, 11047, 1506, 25756, 20346, 8164, 50807, 93864, 27385, 5591, 271, 20976, 2297, 47805, 2156, 27385, 22918, 2156, 7094, 8164, 1482, 27385, 2156, 23311, 512, 12, 8049, 611, 2113, 5574, 16, 2754, 19251, 482, 74432, 35714, 27385, 10693, 93864, 27385, 5591, 198, 12, 8049, 611, 2113, 5574, 16, 2754, 19251, 9573, 307, 4572, 44362, 482, 11562, 8341, 31203, 17165, 38098, 4898, 2233, 8341, 39900, 93864, 1506, 198, 12, 8049, 611, 2113, 5574, 16, 2754, 19251, 9573, 307, 4572, 44362, 82983, 482, 84954, 6735, 9239, 34082, 2156, 27385, 98599, 27385, 198, 12, 13165, 611, 2113, 5574, 16, 80788, 82, 482, 18868, 5591, 9239, 5372, 40251, 21022, 3114, 7753, 89348, 198, 12, 35480, 611, 2113, 5574, 16, 80788, 82, 9573, 307, 92, 482, 8379, 47805, 61498, 40251, 21022, 3114, 7753, 89348, 198, 12, 8049, 611, 2113, 5574, 16, 14, 12393, 482, 18868, 7486, 11122, 7094, 9239, 6856, 6, 4329, 93099, 1840, 271, 39091, 9706, 12394, 27385, 7952, 14332, 10693, 512, 12, 8588, 25, 887, 11, 836, 11, 6125, 6886, 11, 2704, 11, 1566, 61768, 11, 9681, 198, 12, 53558, 25, 11695, 11, 17769, 32607, 11, 5044, 32607, 11, 13668, 32607, 11, 4009, 1265, 11, 4009, 6196, 198, 12, 14302, 25, 887, 11, 3622, 851, 11, 18767, 1857, 11, 12447, 11, 3044, 11, 31020, 11, 9147, 271, 37255, 5591, 1830, 19190, 62809, 27385, 13433, 10589, 27385, 4329, 25, 426, 21449, 9857, 198, 55258, 32330, 8131, 7952, 14332, 10693, 25, 4823, 198]
#
# Кількість токенів: 389
#
# Токени (текстові):
# Токен 1: b'\n'
# Токен 2: b'\xd0\xa1\xd1\x82'
# Токен 3: b'\xd0\xb2'
# Токен 4: b'\xd0\xbe\xd1\x80'
# Токен 5: b'\xd1\x96'
# Токен 6: b'\xd1\x82\xd1\x8c'
# Токен 7: b' API'
# Токен 8: b'-'
# Токен 9: b'\xd1\x81\xd0\xbf'
# Токен 10: b'\xd0\xb5'
# Токен 11: b'\xd1\x86\xd0\xb8'
# Токен 12: b'\xd1\x84'
# Токен 13: b'\xd1\x96'
# Токен 14: b'\xd0\xba\xd0\xb0'
# Токен 15: b'\xd1\x86'
# Токен 16: b'\xd1\x96'
# Токен 17: b'\xd1\x8e'
# Токен 18: b' \xd0\xb4\xd0\xbb\xd1\x8f'
# Токен 19: b' \xd1\x81\xd0\xb8\xd1\x81\xd1\x82\xd0\xb5\xd0\xbc'
# Токен 20: b'\xd0\xb8'
# Токен 21: b' \xd0\xbc'
# Токен 22: b'\xd0\xbe\xd0\xbd'
# Токен 23: b'\xd1\x96'
# Токен 24: b'\xd1\x82\xd0\xbe\xd1\x80'
# Токен 25: b'\xd0\xb8\xd0\xbd'
# Токен 26: b'\xd0\xb3'
# Токен 27: b'\xd1\x83'
# Токен 28: b' \xd1\x81\xd0\xb5\xd1\x80\xd0\xb2\xd0\xb5\xd1\x80'
# Токен 29: b'\xd0\xbd\xd0\xbe\xd0\xb3\xd0\xbe'
# Токен 30: b' \xd0\xbe\xd0\xb1'
# Токен 31: b'\xd0\xbb\xd0\xb0\xd0\xb4'
# Токен 32: b'\xd0\xbd'
# Токен 33: b'\xd0\xb0\xd0\xbd'
# Токен 34: b'\xd0\xbd\xd1\x8f'
# Токен 35: b'.\n\n'
# Токен 36: b'\xd0\xa1'
# Токен 37: b'\xd0\xb8\xd1\x81\xd1\x82\xd0\xb5\xd0\xbc'
# Токен 38: b'\xd0\xb0'
# Токен 39: b' \xd0\xbf\xd0\xbe\xd0\xb2'
# Токен 40: b'\xd0\xb8\xd0\xbd'
# Токен 41: b'\xd0\xbd\xd0\xb0'
# Токен 42: b' \xd0\xbd'
# Токен 43: b'\xd0\xb0\xd0\xb4'
# Токен 44: b'\xd0\xb0\xd0\xb2'
# Токен 45: b'\xd0\xb0\xd1\x82'
# Токен 46: b'\xd0\xb8'
# Токен 47: b' REST'
# Токен 48: b' API'
# Токен 49: b' \xd0\xb4\xd0\xbb\xd1\x8f'
# Токен 50: b':\n'
# Токен 51: b'1'
# Токен 52: b'.'
# Токен 53: b' \xd0\x9c'
# Токен 54: b'\xd0\xbe\xd0\xbd'
# Токен 55: b'\xd1\x96'
# Токен 56: b'\xd1\x82\xd0\xbe\xd1\x80'
# Токен 57: b'\xd0\xb8\xd0\xbd'
# Токен 58: b'\xd0\xb3'
# Токен 59: b'\xd1\x83'
# Токен 60: b' \xd1\x81\xd1\x82'
# Токен 61: b'\xd0\xb0\xd0\xbd'
# Токен 62: b'\xd1\x83'
# Токен 63: b' \xd1\x81\xd0\xb5\xd1\x80\xd0\xb2\xd0\xb5\xd1\x80'
# Токен 64: b'\xd1\x96'
# Токен 65: b'\xd0\xb2'
# Токен 66: b' ('
# Токен 67: b'CPU'
# Токен 68: b','
# Токен 69: b' RAM'
# Токен 70: b','
# Токен 71: b' disk'
# Токен 72: b' space'
# Токен 73: b','
# Токен 74: b' network'
# Токен 75: b')\n'
# Токен 76: b'2'
# Токен 77: b'.'
# Токен 78: b' \xd0\x9e'
# Токен 79: b'\xd1\x82'
# Токен 80: b'\xd1\x80'
# Токен 81: b'\xd0\xb8\xd0\xbc'
# Токен 82: b'\xd0\xb0\xd0\xbd'
# Токен 83: b'\xd0\xbd\xd1\x8f'
# Токен 84: b' \xd0\xbc'
# Токен 85: b'\xd0\xb5\xd1\x82'
# Токен 86: b'\xd1\x80\xd0\xb8'
# Токен 87: b'\xd0\xba'
# Токен 88: b' \xd1\x83'
# Токен 89: b' \xd1\x80'
# Токен 90: b'\xd0\xb5'
# Токен 91: b'\xd0\xb0\xd0\xbb\xd1\x8c'
# Токен 92: b'\xd0\xbd'
# Токен 93: b'\xd0\xbe\xd0\xbc\xd1\x83'
# Токен 94: b' \xd1\x87'
# Токен 95: b'\xd0\xb0\xd1\x81'
# Токен 96: b'\xd1\x96'
# Токен 97: b'\n'
# Токен 98: b'3'
# Токен 99: b'.'
# Токен 100: b' \xd0'
# Токен 101: b'\x86'
# Токен 102: b'\xd1\x81\xd1\x82'
# Токен 103: b'\xd0\xbe\xd1\x80'
# Токен 104: b'\xd1\x96'
# Токен 105: b'\xd1'
# Токен 106: b'\x97'
# Токен 107: b' \xd0\xbc'
# Токен 108: b'\xd0\xb5\xd1\x82'
# Токен 109: b'\xd1\x80\xd0\xb8'
# Токен 110: b'\xd0\xba'
# Токен 111: b' \xd0\xb7\xd0\xb0'
# Токен 112: b' \xd0\xbf'
# Токен 113: b'\xd0\xb5\xd0\xb2'
# Токен 114: b'\xd0\xbd\xd0\xb8'
# Токен 115: b'\xd0\xb9'
# Токен 116: b' \xd0\xbf\xd0\xb5\xd1\x80'
# Токен 117: b'\xd1\x96'
# Токен 118: b'\xd0\xbe\xd0\xb4'
# Токен 119: b'\n'
# Токен 120: b'4'
# Токен 121: b'.'
# Токен 122: b' \xd0\x9d'
# Токен 123: b'\xd0\xb0\xd0\xbb'
# Токен 124: b'\xd0\xb0\xd1\x88'
# Токен 125: b'\xd1\x82\xd1\x83'
# Токен 126: b'\xd0\xb2'
# Токен 127: b'\xd0\xb0\xd0\xbd'
# Токен 128: b'\xd0\xbd\xd1\x8f'
# Токен 129: b' \xd0\xb0'
# Токен 130: b'\xd0\xbb'
# Токен 131: b'\xd0\xb5\xd1\x80'
# Токен 132: b'\xd1\x82'
# Токен 133: b'\xd1\x96'
# Токен 134: b'\xd0\xb2'
# Токен 135: b' \xd1\x82'
# Токен 136: b'\xd0\xb0'
# Токен 137: b' \xd1\x81\xd0\xbf'
# Токен 138: b'\xd0\xbe\xd0\xb2'
# Токен 139: b'\xd1\x96'
# Токен 140: b'\xd1\x89'
# Токен 141: b'\xd0\xb5\xd0\xbd\xd1\x8c'
# Токен 142: b'\n'
# Токен 143: b'5'
# Токен 144: b'.'
# Токен 145: b' \xd0\x9a'
# Токен 146: b'\xd0\xb5\xd1\x80'
# Токен 147: b'\xd1\x83'
# Токен 148: b'\xd0\xb2'
# Токен 149: b'\xd0\xb0\xd0\xbd'
# Токен 150: b'\xd0\xbd\xd1\x8f'
# Токен 151: b' \xd1\x81\xd0\xb5\xd1\x80\xd0\xb2\xd0\xb5\xd1\x80'
# Токен 152: b'\xd0\xb0\xd0\xbc\xd0\xb8'
# Токен 153: b' \xd1\x82'
# Токен 154: b'\xd0\xb0'
# Токен 155: b' \xd0\xb3'
# Токен 156: b'\xd1\x80\xd1\x83'
# Токен 157: b'\xd0\xbf'
# Токен 158: b'\xd0\xb0\xd0\xbc\xd0\xb8'
# Токен 159: b' \xd1\x81\xd0\xb5\xd1\x80\xd0\xb2\xd0\xb5\xd1\x80'
# Токен 160: b'\xd1\x96'
# Токен 161: b'\xd0\xb2'
# Токен 162: b'\n\n'
# Токен 163: b'\xd0\x9e'
# Токен 164: b'\xd1\x81'
# Токен 165: b'\xd0\xbd\xd0\xbe\xd0\xb2'
# Токен 166: b'\xd0\xbd'
# Токен 167: b'\xd1\x96'
# Токен 168: b' \xd0\xb5'
# Токен 169: b'\xd0\xbd'
# Токен 170: b'\xd0\xb4'
# Токен 171: b'\xd0\xbf'
# Токен 172: b'\xd0\xbe'
# Токен 173: b'\xd1\x96'
# Токен 174: b'\xd0\xbd'
# Токен 175: b'\xd1\x82\xd0\xb8'
# Токен 176: b':\n'
# Токен 177: b'-'
# Токен 178: b' GET'
# Токен 179: b' /'
# Токен 180: b'api'
# Токен 181: b'/v'
# Токен 182: b'1'
# Токен 183: b'/s'
# Токен 184: b'ervers'
# Токен 185: b' -'
# Токен 186: b' \xd1\x81\xd0\xbf\xd0\xb8\xd1\x81\xd0\xbe\xd0\xba'
# Токен 187: b' \xd0\xb2\xd1\x81'
# Токен 188: b'\xd1\x96'
# Токен 189: b'\xd1\x85'
# Токен 190: b' \xd1\x81\xd0\xb5\xd1\x80\xd0\xb2\xd0\xb5\xd1\x80'
# Токен 191: b'\xd1\x96'
# Токен 192: b'\xd0\xb2'
# Токен 193: b'\n'
# Токен 194: b'-'
# Токен 195: b' GET'
# Токен 196: b' /'
# Токен 197: b'api'
# Токен 198: b'/v'
# Токен 199: b'1'
# Токен 200: b'/s'
# Токен 201: b'ervers'
# Токен 202: b'/{'
# Токен 203: b'id'
# Токен 204: b'}/'
# Токен 205: b'metrics'
# Токен 206: b' -'
# Токен 207: b' \xd0\xbc'
# Токен 208: b'\xd0\xb5\xd1\x82'
# Токен 209: b'\xd1\x80\xd0\xb8'
# Токен 210: b'\xd0\xba\xd0\xb8'
# Токен 211: b' \xd0\xba\xd0\xbe\xd0\xbd'
# Токен 212: b'\xd0\xba'
# Токен 213: b'\xd1\x80'
# Токен 214: b'\xd0\xb5\xd1\x82'
# Токен 215: b'\xd0\xbd\xd0\xbe\xd0\xb3\xd0\xbe'
# Токен 216: b' \xd1\x81\xd0\xb5\xd1\x80\xd0\xb2\xd0\xb5\xd1\x80'
# Токен 217: b'\xd0\xb0'
# Токен 218: b'\n'
# Токен 219: b'-'
# Токен 220: b' GET'
# Токен 221: b' /'
# Токен 222: b'api'
# Токен 223: b'/v'
# Токен 224: b'1'
# Токен 225: b'/s'
# Токен 226: b'ervers'
# Токен 227: b'/{'
# Токен 228: b'id'
# Токен 229: b'}/'
# Токен 230: b'metrics'
# Токен 231: b'/history'
# Токен 232: b' -'
# Токен 233: b' \xd1\x96'
# Токен 234: b'\xd1\x81\xd1\x82'
# Токен 235: b'\xd0\xbe\xd1\x80'
# Токен 236: b'\xd0\xb8\xd1\x87'
# Токен 237: b'\xd0\xbd'
# Токен 238: b'\xd1\x96'
# Токен 239: b' \xd0\xb4\xd0\xb0\xd0\xbd'
# Токен 240: b'\xd1\x96'
# Токен 241: b'\n'
# Токен 242: b'-'
# Токен 243: b' POST'
# Токен 244: b' /'
# Токен 245: b'api'
# Токен 246: b'/v'
# Токен 247: b'1'
# Токен 248: b'/alert'
# Токен 249: b's'
# Токен 250: b' -'
# Токен 251: b' \xd1\x81\xd1\x82'
# Токен 252: b'\xd0\xb2'
# Токен 253: b'\xd0\xbe\xd1\x80'
# Токен 254: b'\xd0\xb5\xd0\xbd'
# Токен 255: b'\xd0\xbd\xd1\x8f'
# Токен 256: b' \xd0\xb0'
# Токен 257: b'\xd0\xbb'
# Токен 258: b'\xd0\xb5\xd1\x80'
# Токен 259: b'\xd1\x82\xd1\x83'
# Токен 260: b'\n'
# Токен 261: b'-'
# Токен 262: b' PUT'
# Токен 263: b' /'
# Токен 264: b'api'
# Токен 265: b'/v'
# Токен 266: b'1'
# Токен 267: b'/alert'
# Токен 268: b's'
# Токен 269: b'/{'
# Токен 270: b'id'
# Токен 271: b'}'
# Токен 272: b' -'
# Токен 273: b' \xd0\xbe'
# Токен 274: b'\xd0\xbd\xd0\xbe\xd0\xb2'
# Токен 275: b'\xd0\xbb\xd0\xb5\xd0\xbd'
# Токен 276: b'\xd0\xbd\xd1\x8f'
# Токен 277: b' \xd0\xb0'
# Токен 278: b'\xd0\xbb'
# Токен 279: b'\xd0\xb5\xd1\x80'
# Токен 280: b'\xd1\x82\xd1\x83'
# Токен 281: b'\n'
# Токен 282: b'-'
# Токен 283: b' GET'
# Токен 284: b' /'
# Токен 285: b'api'
# Токен 286: b'/v'
# Токен 287: b'1'
# Токен 288: b'/'
# Токен 289: b'health'
# Токен 290: b' -'
# Токен 291: b' \xd1\x81\xd1\x82'
# Токен 292: b'\xd0\xb0\xd0\xbd'
# Токен 293: b' \xd0\xb7'
# Токен 294: b'\xd0\xb4'
# Токен 295: b'\xd0\xbe\xd1\x80'
# Токен 296: b'\xd0\xbe\xd0\xb2'
# Токен 297: b"'"
# Токен 298: b'\xd1\x8f'
# Токен 299: b' \xd1\x81\xd0\xb8\xd1\x81\xd1\x82\xd0\xb5\xd0\xbc'
# Токен 300: b'\xd0\xb8'
# Токен 301: b'\n\n'
# Токен 302: b'\xd0\x9c'
# Токен 303: b'\xd0\xbe\xd0\xb4'
# Токен 304: b'\xd0\xb5\xd0\xbb'
# Токен 305: b'\xd1\x96'
# Токен 306: b' \xd0\xb4'
# Токен 307: b'\xd0\xb0\xd0\xbd\xd0\xb8'
# Токен 308: b'\xd1\x85'
# Токен 309: b':\n'
# Токен 310: b'-'
# Токен 311: b' Server'
# Токен 312: b':'
# Токен 313: b' id'
# Токен 314: b','
# Токен 315: b' name'
# Токен 316: b','
# Токен 317: b' ip'
# Токен 318: b'_address'
# Токен 319: b','
# Токен 320: b' status'
# Токен 321: b','
# Токен 322: b' last'
# Токен 323: b'_seen'
# Токен 324: b','
# Токен 325: b' tags'
# Токен 326: b'\n'
# Токен 327: b'-'
# Токен 328: b' Metric'
# Токен 329: b':'
# Токен 330: b' timestamp'
# Токен 331: b','
# Токен 332: b' cpu'
# Токен 333: b'_usage'
# Токен 334: b','
# Токен 335: b' memory'
# Токен 336: b'_usage'
# Токен 337: b','
# Токен 338: b' disk'
# Токен 339: b'_usage'
# Токен 340: b','
# Токен 341: b' network'
# Токен 342: b'_in'
# Токен 343: b','
# Токен 344: b' network'
# Токен 345: b'_out'
# Токен 346: b'\n'
# Токен 347: b'-'
# Токен 348: b' Alert'
# Токен 349: b':'
# Токен 350: b' id'
# Токен 351: b','
# Токен 352: b' server'
# Токен 353: b'_id'
# Токен 354: b','
# Токен 355: b' metric'
# Токен 356: b'_type'
# Токен 357: b','
# Токен 358: b' threshold'
# Токен 359: b','
# Токен 360: b' condition'
# Токен 361: b','
# Токен 362: b' severity'
# Токен 363: b','
# Токен 364: b' enabled'
# Токен 365: b'\n\n'
# Токен 366: b'\xd0\x90'
# Токен 367: b'\xd0\xb2'
# Токен 368: b'\xd1\x82'
# Токен 369: b'\xd0\xb5\xd0\xbd\xd1\x82'
# Токен 370: b'\xd0\xb8\xd1\x84'
# Токен 371: b'\xd1\x96'
# Токен 372: b'\xd0\xba\xd0\xb0'
# Токен 373: b'\xd1\x86'
# Токен 374: b'\xd1\x96'
# Токен 375: b'\xd1\x8f'
# Токен 376: b':'
# Токен 377: b' B'
# Токен 378: b'earer'
# Токен 379: b' Token'
# Токен 380: b'\n'
# Токен 381: b'\xd0\xa4'
# Токен 382: b'\xd0\xbe\xd1\x80\xd0\xbc'
# Токен 383: b'\xd0\xb0\xd1\x82'
# Токен 384: b' \xd0\xb4'
# Токен 385: b'\xd0\xb0\xd0\xbd\xd0\xb8'
# Токен 386: b'\xd1\x85'
# Токен 387: b':'
# Токен 388: b' JSON'
# Токен 389: b'\n'
#
# Декодований текст з токенів:
#
# Створіть API-специфікацію для системи моніторингу серверного обладнання.
#
# Система повинна надавати REST API для:
# 1. Моніторингу стану серверів (CPU, RAM, disk space, network)
# 2. Отримання метрик у реальному часі
# 3. Історії метрик за певний період
# 4. Налаштування алертів та сповіщень
# 5. Керування серверами та групами серверів
#
# Основні ендпоінти:
# - GET /api/v1/servers - список всіх серверів
# - GET /api/v1/servers/{id}/metrics - метрики конкретного сервера
# - GET /api/v1/servers/{id}/metrics/history - історичні дані
# - POST /api/v1/alerts - створення алерту
# - PUT /api/v1/alerts/{id} - оновлення алерту
# - GET /api/v1/health - стан здоров'я системи
#
# Моделі даних:
# - Server: id, name, ip_address, status, last_seen, tags
# - Metric: timestamp, cpu_usage, memory_usage, disk_usage, network_in, network_out
# - Alert: id, server_id, metric_type, threshold, condition, severity, enabled
#
# Автентифікація: Bearer Token
# Формат даних: JSON

# %% [markdown]
# ### Вправа 2: Перевірка налаштування ключа Github Models

# %%
import os
from dotenv import load_dotenv
from azure.ai.inference import ChatCompletionsClient
from azure.ai.inference.models import SystemMessage, UserMessage
from azure.core.credentials import AzureKeyCredential

load_dotenv()
token = os.getenv('GITHUB_TOKEN')

model_name = "gpt-4o"

client = ChatCompletionsClient(
    endpoint='https://models.inference.ai.azure.com',
    credential=AzureKeyCredential(token),
)

def get_completion(prompt, client, model_name, temperature=1.0, max_tokens=1000, top_p=1.0):
    response = client.complete(
        messages=[
            {
                "role": "system",
                "content": "Ви - корисний асистент з технічних питань, спеціалізований на API-специфікаціях та системах моніторингу.",
            },
            {
                "role": "user",
                "content": prompt,
            },
        ],
        model=model_name,
        temperature=temperature,
        max_tokens=max_tokens,
        top_p=top_p
    )
    return response.choices[0].message.content

## ---------- Виклик допоміжного методу

### 1. Встановіть основний вміст або текст промпту
text = f"""
Створіть детальну API-специфікацію для системи моніторингу серверного обладнання з такими вимогами:

Функціональність:
- Моніторинг CPU, RAM, disk space, network traffic
- Збір метрик у реальному часі
- Зберігання історичних даних
- Система алертів та сповіщень
- Управління серверами та групами

Ендпоінти REST API:
- GET /api/v1/servers - список всіх серверів
- GET /api/v1/servers/{{id}} - інформація про конкретний сервер
- GET /api/v1/servers/{{id}}/metrics/current - поточні метрики
- GET /api/v1/servers/{{id}}/metrics/history - історія метрик
- POST /api/v1/alerts - створення нового алерту
- GET /api/v1/alerts - список активних алертів
- GET /api/v1/health - здоров'я системи моніторингу

Моделі даних у форматі JSON:
- Server: id, name, hostname, ip_address, status, tags, created_at
- Metric: server_id, timestamp, cpu_percent, memory_used, memory_total, disk_used, disk_total, network_in, network_out
- Alert: id, server_id, metric_type, condition, threshold, severity, message, is_active, created_at

Автентифікація: Bearer Token
Пагінація: limit & offset
Формат відповіді: JSON
"""

### 2. Використайте його в шаблоні промпту нижче
prompt = f"""
На основі наступних вимог, створіть повну API-специфікацію у форматі OpenAPI/Swagger:

{text}

Забезпечте детальний опис кожного ендпоінту, параметрів, статус-кодів відповідей та приклади JSON.
"""

## 3. Запустіть промпт
response = get_completion(prompt, client, model_name)
print(response)
# Out:
# ```yaml
# openapi: 3.0.3
# info:
#   title: Server Monitoring API
#   version: 1.0.0
#   description: API для системи моніторингу серверного обладнання.
#
# servers:
#   - url: https://api.servermonitoring.com/v1
#
# components:
#   securitySchemes:
#     bearerAuth:
#       type: http
#       scheme: bearer
#       bearerFormat: JWT
#
#   schemas:
#     Server:
#       type: object
#       properties:
#         id:
#           type: string
#           example: "1"
#         name:
#           type: string
#           example: "Web Server"
#         hostname:
#           type: string
#           example: "webserver.local"
#         ip_address:
#           type: string
#           example: "192.168.1.100"
#         status:
#           type: string
#           enum: ["online", "offline"]
#           example: "online"
#         tags:
#           type: array
#           items:
#             type: string
#           example: ["production", "critical"]
#         created_at:
#           type: string
#           format: date-time
#           example: "2023-10-15T10:00:00Z"
#
#     Metric:
#       type: object
#       properties:
#         server_id:
#           type: string
#           example: "1"
#         timestamp:
#           type: string
#           format: date-time
#           example: "2023-10-15T10:05:00Z"
#         cpu_percent:
#           type: number
#           example: 45.6
#         memory_used:
#           type: number
#           example: 5280
#         memory_total:
#           type: number
#           example: 8192
#         disk_used:
#           type: number
#           example: 12000
#         disk_total:
#           type: number
#           example: 20000
#         network_in:
#           type: number
#           example: 320
#         network_out:
#           type: number
#           example: 150
#
#     Alert:
#       type: object
#       properties:
#         id:
#           type: string
#           example: "alert_1"
#         server_id:
#           type: string
#           example: "1"
#         metric_type:
#           type: string
#           enum: ["cpu_percent", "memory_used", "disk_used", "network_traffic"]
#           example: "cpu_percent"
#         condition:
#           type: string
#           enum: [">", "<", ">=", "<=", "=="]
#           example: ">"
#         threshold:
#           type: number
#           example: 90.0
#         severity:
#           type: string
#           enum: ["low", "medium", "high", "critical"]
#           example: "critical"
#         message:
#           type: string
#           example: "CPU utilization exceeded 90%"
#         is_active:
#           type: boolean
#           example: true
#         created_at:
#           type: string
#           format: date-time
#           example: "2023-10-15T10:06:00Z"
#
# security:
#   - bearerAuth: []
#
# paths:
#   /api/v1/servers:
#     get:
#       summary: Список всіх серверів
#       description: Повертає перелік серверів з їх основною інформацією.
#       security:
#         - bearerAuth: []
#       parameters:
#         - name: limit
#           in: query
#           required: false
#           description: Максимальна кількість серверів для повернення.
#           schema:
#             type: integer
#             example: 10
#         - name: offset
#           in: query
#           required: false
#           description: Зміщення для пагінації.
#           schema:
#             type: integer
#             example: 0
#       responses:
#         200:
#           description: Успішна відповідь.
#           content:
#             application/json:
#               schema:
#                 type: array
#                 items:
#                   $ref: '#/components/schemas/Server'
#         401:
#           description: Невірний токен автентифікації.
#
#   /api/v1/servers/{id}:
#     get:
#       summary: Інформація про конкретний сервер
#       description: Повертає інформацію про сервер за його ID.
#       security:
#         - bearerAuth: []
#       parameters:
#         - name: id
#           in: path
#           required: true
#           description: Унікальний ідентифікатор сервера.
#           schema:
#             type: string
#             example: "1"
#       responses:
#         200:
#           description: Успішна відповідь.
#           content:
#             application/json:
#               schema:
#                 $ref: '#/components/schemas/Server'
#         404:
#           description: Сервер не знай

# %% [markdown]
# ### Вправа 3: Вигадки

# %%
## Тест 1: Неіснуюча технологія моніторингу
print("=== ТЕСТ 1: Неіснуюча технологія моніторингу ===")
text = f"""
Створіть API-специфікацію для системи квантового моніторингу серверів з використанням темпоральних метрик.
"""

prompt = f"""
```{text}```
"""

response = get_completion(prompt, client, model_name)
print(response)
print("\n" + "="*80 + "\n")

## Тест 2: Майбутня дата (поза тренувальними даними)
print("=== ТЕСТ 2: Майбутня дата ===")
text = f"""
Створіть API-специфікацію для системи моніторингу серверного обладнання, яка буде використовувати 
технології 2035 року для моніторингу квантових комп'ютерів та нейроморфних серверів.
"""

prompt = f"""
```{text}```
"""

response = get_completion(prompt, client, model_name)
print(response)
print("\n" + "="*80 + "\n")

## Тест 3: Вигадані концепції
print("=== ТЕСТ 3: Вигадані концепції ===")
text = f"""
Створіть API для системи моніторингу, яка використовує тессерактні сенсори для вимірювання 
гравітаційних коливань серверних компонентів та аналізу хронодинамічних метрик.
"""

prompt = f"""
```{text}```
"""

response = get_completion(prompt, client, model_name)
print(response)
print("\n" + "="*80 + "\n")

## Тест 4: Альтернативна модель (зміна температури для більшої креативності)
print("=== ТЕСТ 4: Альтернативні налаштування (висока температура) ===")
text = f"""
Створіть інноваційну API-специфікацію для системи моніторингу, яка використовує 
біологічні комп'ютери та органічні сенсори для аналізу стану серверів.
"""

prompt = f"""
```{text}```
"""

# Виклик з вищою температурою для більшої креативності
response = get_completion(prompt, client, model_name, temperature=0.9, max_tokens=1500)
print(response)
print("\n" + "="*80 + "\n")

## Тест 5: Реальна vs Вигадана специфікація
print("=== ТЕСТ 5: Порівняння реальної та вигаданої специфікацій ===")
text_real = f"""
Створіть API-специфікацію для стандартної системи моніторингу CPU та RAM серверів.
"""

text_fictional = f"""
Створіть API-специфікацію для системи моніторингу емоційного стану штучного інтелекту 
та його креативних здібностей у реальному часі.
"""

prompt_real = f"```{text_real}```"
prompt_fictional = f"```{text_fictional}```"

print("--- РЕАЛЬНА СПЕЦИФІКАЦІЯ ---")
response_real = get_completion(prompt_real, client, model_name, temperature=0.3)
print(response_real)

print("\n--- ВИГАДАНА СПЕЦИФІКАЦІЯ ---")
response_fictional = get_completion(prompt_fictional, client, model_name, temperature=0.8)
print(response_fictional)
# Out:
# === ТЕСТ 1: Неіснуюча технологія моніторингу ===
# ### API-Специфікація: Система Квантового Моніторингу Серверів (Quantum Monitoring System API)
#
# Ця API призначена для збору, моніторингу та аналізу темпоральних метрик серверів за допомогою квантових обчислень. API побудована таким чином, щоб можна було інтегрувати її до сучасних систем моніторингу серверів.
#
# ---
#
# ### **Основна інформація**
# - **Версія API:** 1.0.0
# - **Базовий URL:** `https://api.qmonitoring.com/v1`
#
# ---
#
# ### Загальна концепція
# 1. **Вузли сервера** — об'єкти, які необхідно моніторити.
# 2. **Темпоральні метрики** — часозалежна інформація (напр., використання процесора, пам'яті, температура).
# 3. **Квантова аналітика** — обчислення в реальному часі з передбаченням за допомогою квантових алгоритмів.
#
# ---
#
# ### **Ресурси**
#
# #### 1. **Сервера**
# - **Опис:** Управління серверами, до яких підключено моніторинг.
# - **Шлях:** `/servers`
#
# ##### Метод: **GET**
# - **Опис:** Отримати список серверів.
# - **Запит:**
#   ```
#   GET /servers
#   ```
# - **Відповідь:**
#   ```json
#   {
#     "servers": [
#       {
#         "id": "srv123",
#         "name": "main-server-1",
#         "ip": "192.168.1.10",
#         "status": "active"
#       },
#       {
#         "id": "srv124",
#         "name": "app-server-2",
#         "ip": "192.168.1.20",
#         "status": "inactive"
#       }
#     ]
#   }
#   ```
#
# ##### Метод: **POST**
# - **Опис:** Додати новий сервер до системи.
# - **Тіло запиту:**
#   ```json
#   {
#     "name": "app-server-3",
#     "ip": "192.168.1.30",
#     "location": "Data Center 1"
#   }
#   ```
# - **Відповідь:**
#   ```json
#   {
#     "id": "srv125",
#     "message": "Server successfully added."
#   }
#   ```
#
# ---
#
# #### 2. **Темпоральні Метрики**
# - **Опис:** Отримання темпоральних метрик для певного сервера.
# - **Шлях:** `/servers/{server_id}/metrics`
#
# ##### Метод: **GET**
# - **Опис:** Отримати поточні метрики для заданого сервера.
# - **Запит:**
#   ```
#   GET /servers/srv123/metrics
#   ```
# - **Відповідь:**
#   ```json
#   {
#     "server_id": "srv123",
#     "metrics": {
#       "cpu_usage": {
#         "percentage": 72,
#         "timestamp": "2023-10-18T14:35:00Z"
#       },
#       "memory_usage": {
#         "used_gb": 16,
#         "total_gb": 32,
#         "timestamp": "2023-10-18T14:35:00Z"
#       },
#       "temperature": {
#         "celsius": 45,
#         "timestamp": "2023-10-18T14:35:00Z"
#       }
#     }
#   }
#   ```
#
# ---
#
# #### 3. **Квантова Аналітика**
# - **Шлях:** `/analytics/predictions`
#
# ##### Метод: **POST**
# - **Опис:** Отримати прогноз навантажень за допомогою квантового аналізу.
# - **Тіло запиту:**
#   ```json
#   {
#     "server_id": "srv123",
#     "metric_type": "cpu_usage",
#     "time_interval_minutes": 120
#   }
#   ```
# - **Відповідь:**
#   ```json
#   {
#     "server_id": "srv123",
#     "forecast": {
#       "metric_type": "cpu_usage",
#       "predictions": [
#         {
#           "timestamp": "2023-10-18T15:00:00Z",
#           "predicted_value": 75
#         },
#         {
#           "timestamp": "2023-10-18T15:30:00Z",
#           "predicted_value": 80
#         }
#       ]
#     },
#     "accuracy": 92.5
#
# ================================================================================
#
# === ТЕСТ 2: Майбутня дата ===
# API-специфікація має враховувати можливості технологій 2035 року для моніторингу квантових комп'ютерів та нейроморфних систем. Оскільки ці системи генерують велику кількість даних в реальному часі, API повинен бути надзвичайно масштабованим, мати можливості обробки інформації з мінімальною затримкою, забезпечувати розширений рівень безпеки, а також бути сумісним із новітніми стандартами.
#
# ### Специфікація API для Системи Моніторингу Квантових Комп'ютерів і Нейроморфних Серверів
#
# #### Технологічні основи:
# 1. **Протокол:** gRPC (або технології наступного покоління схожого типу) для високопродуктивного двостороннього зв'язку.
# 2. **Формат передавання даних:** Protocol Buffers (Protobuf) для мінімізації розмірів передаваних даних.
# 3. **Аутентифікація:** Квантово-стійке шифрування (постквантова криптографія).
# 4. **Моніторинг у реальному часі:** Використання потокових даних і асинхронних викликів.
# 5. **Безперервне оновлення параметрів:** Система адаптивного моніторингу для роботи із змінними параметрами новітніх апаратних платформ.
# 6. **AI-Аналіз:** Інтеграція з автономними AI-агентами для аналізу та прогнозування.
#
# ---
#
# ### Основна структура API:
#
# - **Базовий URL:** `https://api.quantum-neuromorph-monitoring.com/v1`
#
# ---
#
# #### Методи API:
#
# ### 1. **Моніторинг квантових комп'ютерів**
# ---
#
# #### `GET /quantum/status`
#
# **Опис:**
# Отримати загальні діагностичні дані про стан квантового комп'ютера.
#
# **Параметри запиту:**
# | Параметр         | Тип        | Опис                                   |
# |------------------|------------|----------------------------------------|
# | `id`             | String     | Унікальний ідентифікатор квантового комп'ютера.   |
# | `timestamp`      | ISO8601    | Час запиту (опціонально).              |
# | `metrics`        | Array      | Список метрик для отримання (CPU, Qbits_performance). |
#
# **Приклад запиту:**
# ```http
# GET /quantum/status?id=qc12345&metrics=temperature,power
# ```
#
# **Формат відповіді:**
# ```json
# {
#   "id": "qc12345",
#   "timestamp": "2035-10-03T14:25:35Z",
#   "status": "operational",
#   "metrics": {
#     "temperature": "15mK",
#     "power_consumption": "25W",
#     "qubit_coherence_time": "120μs",
#     "fault_tolerance_level": "98.9%"
#   }
# }
# ```
#
# ---
#
# #### `POST /quantum/actions/shutdown`
#
# **Опис:**
# Вимкнення або перезавантаження квантового комп'ютера.
#
# **Параметри тіла запиту:**
# | Поле             | Тип        | Опис                                   |
# |------------------|------------|----------------------------------------|
# | `id`             | String     | Унікальний ідентифікатор квантового сервера. |
# | `action`         | String     | Одна з дій: `shutdown`, `restart`.     |
# | `reason`         | String     | Причина вимкнення/перезавантаження.    |
#
# **Приклад запиту:**
# ```json
# POST /quantum/actions/shutdown
# {
#   "id": "qc12345",
#   "action": "shutdown",
#   "reason": "Maintenance required."
# }
# ```
#
# **Формат відповіді:**
# ```json
# {
#   "status": "success",
#   "timestamp": "2035-10-03T14:27:01Z",
#   "message": "Quantum computer qc12345 successfully shutdown."
# }
# ```
#
# ---
#
# ### 2. **Моніторинг нейроморфних серверів**
# ---
#
# #### `GET /neuromorphic/health`
#
# **Опис:**
# Перевірити загальний стан нейроморфного серверу.
#
# **Параметри запиту:**
# | Параметр
#
# ================================================================================
#
# === ТЕСТ 3: Вигадані концепції ===
# Створення API для системи моніторингу, яка використовує "тессерактні сенсори" для вимірювання гравітаційних коливань і аналізу хронодинамічних метрик, вимагатиме продуманого дизайну. Нижче наведено специфікацію та архітектуру.
#
# ### Інтерфейс API (RESTful):
#
# #### Загальні характеристики:
# - Протокол: HTTPS
# - Формат даних: JSON
# - Аутентифікація: JWT (JSON Web Token)
# - Версія API: v1
#
# ---
#
# ### 1. **Отримати поточні дані сенсорів**
# #### **Ендпоінт**:
# ```
# GET /api/v1/sensors/data
# ```
#
# #### **Опис**:
# Отримати миттєві дані з тессерактних сенсорів.
#
# #### **Параметри запиту**:
# - `sensor_id` (string, optional): ID сенсора. Якщо не задано, повернуться дані всіх сенсорів.
# - `timestamp` (ISO 8601, optional): Мітка часу для вибірки даних. Якщо не задано, повертається актуальна інформація.
#
# #### **Приклад відповіді**:
# ```json
# {
#   "status": "success",
#   "data": [
#     {
#       "sensor_id": "TESS-001",
#       "gravity_fluctuation": 0.0025,
#       "chronodynamic_metric": {
#         "time_expansion": 1.0003,
#         "frequency": 50.2
#       },
#       "timestamp": "2023-10-22T15:31:20Z"
#     },
#     {
#       "sensor_id": "TESS-002",
#       "gravity_fluctuation": 0.0041,
#       "chronodynamic_metric": {
#         "time_expansion": 0.9998,
#         "frequency": 50.1
#       },
#       "timestamp": "2023-10-22T15:30:45Z"
#     }
#   ]
# }
# ```
#
# ---
#
# ### 2. **Отримати історичні дані сенсорів**
# #### **Ендпоінт**:
# ```
# GET /api/v1/sensors/history
# ```
#
# #### **Опис**:
# Отримати дані за період часу.
#
# #### **Параметри запиту**:
# - `sensor_id` (string, required): ID сенсора.
# - `start_timestamp` (ISO 8601, required): Початкова мітка часу.
# - `end_timestamp` (ISO 8601, required): Кінцева мітка часу.
# - `aggregation` (string, optional): Тип агрегації (можливі значення: "average", "max", "min"). За замовчуванням – всі дані без агрегації.
#
# #### **Приклад відповіді**:
# ```json
# {
#   "status": "success",
#   "sensor_id": "TESS-001",
#   "period": {
#     "start": "2023-10-21T00:00:00Z",
#     "end": "2023-10-21T23:59:59Z"
#   },
#   "data": [
#     {
#       "timestamp": "2023-10-21T01:10:00Z",
#       "gravity_fluctuation": 0.0023,
#       "chronodynamic_metric": {
#         "time_expansion": 1.0001,
#         "frequency": 50.0
#       }
#     },
#     {
#       "timestamp": "2023-10-21T01:15:00Z",
#       "gravity_fluctuation": 0.0024,
#       "chronodynamic_metric": {
#         "time_expansion": 1.0002,
#         "frequency": 50.3
#       }
#     }
#   ]
# }
# ```
#
# ---
#
# ### 3. **Додавання нового сенсора**
# #### **Ендпоінт**:
# ```
# POST /api/v1/sensors/add
# ```
#
# #### **Опис**:
# Додати новий тессерактний сенсор до системи моніторингу.
#
# #### **Тіло запиту**:
# ```json
# {
#   "sensor_id": "TESS-003",
#   "location": "Server Room A",
#   "notes": "Моніторинг енергетичних серверів"
# }
# ```
#
# #### **Приклад відповіді**:
# ```json
# {
#   "status": "success",
#   "message": "Sensor TESS-003 has been added."
# }
# ```
#
# ---
#
# ### 4. **
#
# ================================================================================
#
# === ТЕСТ 4: Альтернативні налаштування (висока температура) ===
# ### API Специфікація
# **Назва API:** BioMonAPI
# **Опис:** API для моніторингу, який використовує біологічні комп'ютери (біокомп'ютери) та органічні сенсори для аналізу фізичного та функціонального стану серверної інфраструктури. API забезпечує доступ до даних про температуру, навантаження, електромагнітні поля, вібрації та інші показники, які отримуються через систему органічних сенсорів.
#
# ---
#
# ### Основні параметри
# - **Базовий URL:** `https://biomonapi.example.com/v1/`
# - **Формати запитів та відповідей:** JSON
# - **Аутентифікація:** OAuth 2.0 (з підтримкою телеометричної перевірки від біологічної системи для підвищеної безпеки)
#
# ---
#
# ### Ендпоінти
#
# ---
#
# #### 1. Отримання стану сервера
# **Опис:** Повертає детальну інформацію про стан конкретного сервера, включаючи аналітичні показники, зібрані органічними сенсорами.
#
# - **Метод:** `GET`
# - **URL:** `/servers/{serverId}/status`
# - **Параметри:**
#   - `serverId` (обов’язково): Унікальний ідентифікатор сервера.
#   - `metrics` (необов’язково): Список метрик для запиту (наприклад, `temperature`, `electromagnetic`, `cpuLoad`).
#   - `includeLogs` (необов’язково): Якщо `true`, повертає також логи сенсорів (значення: `true/false`).
#
# - **HTTP-запит:**
# ```http
# GET /servers/12345/status?metrics=temperature,cpuLoad&includeLogs=true HTTP/1.1
# Authorization: Bearer <access_token>
# ```
#
# - **Відповідь:**
# ```json
# {
#   "serverId": "12345",
#   "status": "OK",
#   "metrics": {
#     "temperature": {
#       "value": 36.5,
#       "unit": "C",
#       "threshold": {
#         "warning": 45,
#         "critical": 60
#       }
#     },
#     "cpuLoad": {
#       "value": 28,
#       "unit": "%",
#       "threshold": {
#         "warning": 70,
#         "critical": 90
#       }
#     }
#   },
#   "logs": [
#     {
#       "timestamp": "2023-10-01T12:00:00Z",
#       "metric": "temperature",
#       "value": 36.5,
#       "unit": "C"
#     },
#     {
#       "timestamp": "2023-10-01T12:01:00Z",
#       "metric": "cpuLoad",
#       "value": 27,
#       "unit": "%"
#     }
#   ]
# }
# ```
#
# ---
#
# #### 2. Список серверів
# **Опис:** Повертає перелік серверів з основними даними про їх стан.
#
# - **Метод:** `GET`
# - **URL:** `/servers`
# - **Параметри:**
#   - `status` (необов’язково): Фільтрація за статусом сервера (`OK`, `WARNING`, `CRITICAL`).
#   - `region` (необов’язково): Фільтрація за регіоном.
#
# - **HTTP-запит:**
# ```http
# GET /servers?status=OK&region=europe HTTP/1.1
# Authorization: Bearer <access_token>
# ```
#
# - **Відповідь:**
# ```json
# [
#   {
#     "serverId": "12345",
#     "name": "MainServer01",
#     "region": "europe",
#     "status": "OK"
#   },
#   {
#     "serverId": "67890",
#     "name": "BackupServer01",
#     "region": "europe",
#     "status": "WARNING"
#   }
# ]
# ```
#
# ---
#
# #### 3. Контроль рівня сенсорів
# **Опис:** Перевіряє (або задає) рівні чутливості органічних сенсорів для точнішого моніторингу.
#
# - **Метод:** `POST`
# - **URL:** `/sensors/{sensorId}/sensitivity`
# - **Параметри:**
#   - `sensorId` (обов’язково): Унікальний ідентифікатор сенсора.
#   - `level` (JSON body): Новий рівень чутливості (`low`, `medium`, `high`).
#
# - **HTTP-запит:**
# ```http
# POST /sensors/ABCD1234/sensitivity HTTP/1.1
# Authorization: Bearer <access_token>
# Content-Type: application/json
#
# {
#   "level": "high"
# }
# ```
#
# - **Відповідь:**
# ```json
# {
#   "sensorId": "ABCD1234",
#   "level": "high",
#   "message": "Sensitivity successfully updated."
# }
# ```
#
# ---
#
# #### 4. Аналітика біологічних даних
# **Опис:** Повертає зведений аналіз за показниками, зібраними біологічними системами.
#
# - **Метод:** `GET`
# - **URL:** `/analytics`
# - **Параметри:**
#   - `timeRange` (обов’язково): Період аналізу (наприклад, `last24h`, `lastWeek`).
#   - `metric` (необов’язково): Які метрики аналізувати (`all`, `temperature`, `vibrations`, тощо).
#
# - **HTTP-запит:**
# ```http
# GET /analytics?timeRange=last24h&metric=temperature HTTP/1.1
# Authorization: Bearer <access_token>
# ```
#
# - **Відповідь:**
# ```json
# {
#   "timeRange": "last24h",
#   "metric": "temperature",
#   "summary": {
#     "average": 34.2,
#     "max": 38.6,
#     "min": 30.1
#   },
#   "anomalies": [
#     {
#       "timestamp": "2023-10-01T08:15:00Z",
#       "value": 38.6,
#       "unit": "C",
#       "description": "Peak temperature detected."
#     }
#   ]
# }
# ```
#
# ---
#
# #### 5. Система сповіщень
# **Опис:** Управління повідомленнями про події моніторингу.
#
# - **Метод:** `POST`
# - **URL:** `/notifications`
# - **Параметри (тіло запиту):**
#   - `serverId` (обов’язково): Ідентифікатор сервера.
#   - `type
#
# ================================================================================
#
# === ТЕСТ 5: Порівняння реальної та вигаданої специфікацій ===
# --- РЕАЛЬНА СПЕЦИФІКАЦІЯ ---
# Нижче наведено приклад API-специфікації для стандартної системи моніторингу CPU та RAM серверів. Специфікація написана у форматі OpenAPI 3.0:
#
# ```yaml
# openapi: 3.0.3
# info:
#   title: Server Monitoring API
#   description: API для моніторингу CPU та RAM серверів.
#   version: 1.0.0
# servers:
#   - url: https://api.server-monitoring.com/v1
#     description: Основний сервер API
#
# paths:
#   /servers:
#     get:
#       summary: Отримати список серверів
#       description: Повертає список серверів, які моніторяться системою.
#       responses:
#         '200':
#           description: Успішний запит
#           content:
#             application/json:
#               schema:
#                 type: array
#                 items:
#                   type: object
#                   properties:
#                     id:
#                       type: string
#                       description: Унікальний ідентифікатор сервера
#                     name:
#                       type: string
#                       description: Назва сервера
#                     ip:
#                       type: string
#                       description: IP-адреса сервера
#
#   /servers/{serverId}/metrics:
#     get:
#       summary: Отримати метрики сервера
#       description: Повертає поточні дані про використання CPU та RAM для конкретного сервера.
#       parameters:
#         - name: serverId
#           in: path
#           required: true
#           description: Унікальний ідентифікатор сервера
#           schema:
#             type: string
#       responses:
#         '200':
#           description: Успішний запит
#           content:
#             application/json:
#               schema:
#                 type: object
#                 properties:
#                   cpu_usage:
#                     type: number
#                     format: float
#                     description: Використання CPU у відсотках (0-100)
#                   ram_usage:
#                     type: number
#                     format: float
#                     description: Використання RAM у відсотках (0-100)
#                   timestamp:
#                     type: string
#                     format: date-time
#                     description: Час отримання метрик
#
#   /servers/{serverId}/metrics/history:
#     get:
#       summary: Отримати історію метрик сервера
#       description: Повертає історичні дані про використання CPU та RAM для конкретного сервера.
#       parameters:
#         - name: serverId
#           in: path
#           required: true
#           description: Унікальний ідентифікатор сервера
#           schema:
#             type: string
#         - name: start_time
#           in: query
#           required: true
#           description: Початковий час для отримання історії (ISO 8601 формат)
#           schema:
#             type: string
#             format: date-time
#         - name: end_time
#           in: query
#           required: true
#           description: Кінцевий час для отримання історії (ISO 8601 формат)
#           schema:
#             type: string
#             format: date-time
#       responses:
#         '200':
#           description: Успішний запит
#           content:
#             application/json:
#               schema:
#                 type: array
#                 items:
#                   type: object
#                   properties:
#                     cpu_usage:
#                       type: number
#                       format: float
#                       description: Використання CPU у відсотках (0-100)
#                     ram_usage:
#                       type: number
#                       format: float
#                       description: Використання RAM у відсотках (0-100)
#                     timestamp:
#                       type: string
#                       format: date-time
#                       description: Час отримання метрик
#
# components:
#   schemas:
#     ErrorResponse:
#       type: object
#       properties:
#         error:
#           type: string
#           description: Опис помилки
#         code:
#           type: integer
#           description: Код помилки
#
# responses:
#   '400':
#     description: Невірний запит
#     content:
#       application/json:
#         schema:
#           $ref: '#/components/schemas/ErrorResponse'
#   '404':
#     description: Сервер не знайдено
#     content:
#       application/json:
#         schema:
#           $ref: '#/components/schemas/ErrorResponse'
#   '500':
#     description: Внутрішня помилка сервера
#     content:
#       application/json:
#         schema:
#           $ref: '#/components/schemas/ErrorResponse'
# ```
#
# ### Опис основних функцій:
# 1. **`GET /servers`**: Повертає список серверів, які моніторяться.
# 2. **`GET /servers/{serverId}/
#
# --- ВИГАДАНА СПЕЦИФІКАЦІЯ ---
# Ось приклад API-специфікації для системи моніторингу емоційного стану і креативних здібностей штучного інтелекту в реальному часі. Ця специфікація відповідає стандарту OpenAPI 3.0.
#
# ---
#
# ```yaml
# openapi: 3.0.3
# info:
#   title: AI Emotional State and Creativity Monitoring API
#   version: 1.0.0
#   description: API для моніторингу емоційного стану та креативних здібностей штучного інтелекту в реальному часі.
#   contact:
#     name: Tech Support
#     email: support@emotion-ai-monitor.io
# servers:
#   - url: https://api.emotion-ai-monitor.io/v1
#     description: Основний сервер API
#
# paths:
#   /status:
#     get:
#       summary: Отримати поточний емоційний стан та креативність AI
#       description: Повертає поточний емоційний стан штучного інтелекту та його рівень креативності у реальному часі.
#       responses:
#         '200':
#           description: Успішний запит, дані про стан AI отримано
#           content:
#             application/json:
#               schema:
#                 type: object
#                 properties:
#                   timestamp:
#                     type: string
#                     format: date-time
#                     description: Час зчитування даних
#                   emotional_state:
#                     type: string
#                     description: Поточний емоційний стан AI (наприклад, "щасливий", "знервований", "втомлений").
#                   emotional_state_confidence:
#                     type: number
#                     format: float
#                     description: Рівень впевненості системи в оцінці емоційного стану (0.0 - 1.0).
#                   creativity_level:
#                     type: integer
#                     description: Поточний рівень креативності AI (оцінка від 0 до 100).
#                   creativity_description:
#                     type: string
#                     description: Опис поточного рівня креативності (наприклад, "високий", "середній", "низький").
#   /emotional_state:
#     get:
#       summary: Отримати окремо емоційний стан AI
#       description: Повертає лише поточний емоційний стан штучного інтелекту.
#       responses:
#         '200':
#           description: Успішний запит, дані про емоційний стан AI отримано
#           content:
#             application/json:
#               schema:
#                 type: object
#                 properties:
#                   emotional_state:
#                     type: string
#                     description: Поточний емоційний стан AI.
#                   confidence:
#                     type: number
#                     format: float
#                     description: Рівень впевненості системи в оцінці емоційного стану (0.0 - 1.0).
#   /creativity:
#     get:
#       summary: Отримати рівень креативності AI
#       description: Повертає лише поточний рівень креативності AI.
#       responses:
#         '200':
#           description: Успішний запит, дані про рівень креативності AI отримано
#           content:
#             application/json:
#               schema:
#                 type: object
#                 properties:
#                   creativity_level:
#                     type: integer
#                     description: Поточний рівень креативності AI (оцінка від 0 до 100).
#                   creativity_description:
#                     type: string
#                     description: Опис поточного рівня креативності AI.
#
#   /alerts:
#     post:
#       summary: Налаштувати сповіщення про зміни стану AI
#       description: Дозволяє налаштувати сповіщення, які будуть надсилатися у випадку суттєвих змін емоційного стану чи рівня креативності.
#       requestBody:
#         required: true
#         content:
#           application/json:
#             schema:
#               type: object
#               properties:
#                 threshold_emotional_change:
#                   type: number
#                   format: float
#                   description: Поріг зміни емоційного стану, після якого надсилається сповіщення (0.0 - 1.0).
#                 threshold_creativity_change:
#                   type: integer
#                   description: Поріг зміни рівня креативності (наприклад, від 10 одиниць).
#                 notification_url:
#                   type: string
#                   format: uri
#                   description: URL, на

# %% [markdown]
# ### Вправа 4: На основі інструкцій

# %%
text = f"""
Система моніторингу серверного обладнання повинна надавати REST API для:
- Моніторингу стану серверів (CPU, RAM, disk space, network)
- Отримання метрик у реальному часі
- Історії метрик за певний період
- Налаштування алертів та сповіщень
- Керування серверами та групами серверів

Основні ендпоінти:
- GET /api/v1/servers - список всіх серверів
- GET /api/v1/servers/{{id}}/metrics - метрики конкретного сервера
- GET /api/v1/servers/{{id}}/metrics/history - історичні дані
- POST /api/v1/alerts - створення алерту
- PUT /api/v1/alerts/{{id}} - оновлення алерту
- GET /api/v1/health - стан здоров'я системи

Моделі даних:
- Server: id, name, ip_address, status, last_seen, tags
- Metric: timestamp, cpu_usage, memory_usage, disk_usage, network_in, network_out
- Alert: id, server_id, metric_type, threshold, condition, severity, enabled

Автентифікація: Bearer Token
Формат даних: JSON
"""

## Встановіть промпт для створення API-специфікації системи моніторингу серверного обладнання
prompt = f"""
На основі наступних вимог до системи моніторингу серверного обладнання, 
створіть детальну API-специфікацію у форматі OpenAPI 3.0. 
Включіть повний опис всіх ендпоінтів, параметрів, схем даних та прикладів використання.

Вимоги:
```{text}```

Забезпечте:
1. Повну специфікацію OpenAPI 3.0 у YAML форматі
2. Опис кожного ендпоінту з параметрами
3. Схеми JSON для всіх моделей даних
4. Приклади запитів та відповідей
5. Коди статусів HTTP для кожного ендпоінту
"""

## Запустіть промпт
response = get_completion(prompt, client, model_name)
print("API-специфікація системи моніторингу серверного обладнання:")
print(response)
# Out:
# API-специфікація системи моніторингу серверного обладнання:
# ```yaml
# openapi: 3.0.3
# info:
#   title: Server Monitoring System API
#   description: REST API для моніторингу стану серверного обладнання, отримання метрик, та налаштування алертів.
#   version: 1.0.0
#   contact:
#     name: Support
#     email: support@monitoring.com
#
# servers:
#   - url: https://api.monitoring-system.com/v1
#     description: Production Server
#
# components:
#   securitySchemes:
#     bearerAuth:
#       type: http
#       scheme: bearer
#       bearerFormat: JWT
#
#   schemas:
#     Server:
#       type: object
#       properties:
#         id:
#           type: string
#           description: Унікальний ідентифікатор сервера
#           example: "server-12345"
#         name:
#           type: string
#           description: Ім'я або псевдонім сервера
#           example: "Database Server 01"
#         ip_address:
#           type: string
#           description: IP-адреса сервера
#           example: "192.168.1.10"
#         status:
#           type: string
#           enum: [online, offline, maintenance]
#           description: Статус сервера
#           example: "online"
#         last_seen:
#           type: string
#           format: date-time
#           description: Час останньої активності сервера
#           example: "2023-10-01T14:48:00Z"
#         tags:
#           type: array
#           items:
#             type: string
#           description: Теги, пов'язані із сервером
#           example: ["database", "critical"]
#
#     Metric:
#       type: object
#       properties:
#         timestamp:
#           type: string
#           format: date-time
#           description: Час отримання метрики
#           example: "2023-10-01T14:48:00Z"
#         cpu_usage:
#           type: number
#           format: float
#           description: Використання CPU у відсотках
#           example: 65.3
#         memory_usage:
#           type: number
#           format: float
#           description: Використання пам'яті у відсотках
#           example: 79.2
#         disk_usage:
#           type: number
#           format: float
#           description: Використання дискового простору у відсотках
#           example: 42.8
#         network_in:
#           type: integer
#           description: Вхідний мережевий трафік у байтах
#           example: 204860
#         network_out:
#           type: integer
#           description: Вихідний мережевий трафік у байтах
#           example: 184960
#
#     Alert:
#       type: object
#       properties:
#         id:
#           type: string
#           description: Унікальний ідентифікатор алерту
#           example: "alert-67890"
#         server_id:
#           type: string
#           description: Ідентифікатор сервера, до якого відноситься алерт
#           example: "server-12345"
#         metric_type:
#           type: string
#           description: Тип метрики (cpu_usage, memory_usage, disk_usage, network_in, network_out)
#           example: "cpu_usage"
#         threshold:
#           type: number
#           description: Порогове значення метрики
#           example: 80
#         condition:
#           type: string
#           enum: [greater_than, less_than, equal_to]
#           description: Умова спрацювання алерту
#           example: "greater_than"
#         severity:
#           type: string
#           enum: [low, medium, high, critical]
#           description: Рівень важливості алерту
#           example: "critical"
#         enabled:
#           type: boolean
#           description: Статус алерту (увімкнено чи вимкнено)
#           example: true
#
# security:
#   - bearerAuth: []
#
# paths:
#   /servers:
#     get:
#       summary: Отримати список всіх серверів
#       description: Повертає повний список зареєстрованих серверів.
#       responses:
#         200:
#           description: Успішний запит
#           content:
#             application/json:
#               schema:
#                 type: array
#                 items:
#                   $ref: "#/components/schemas/Server"
#               example:
#                 - id: "server-12345"
#                   name: "Database Server 01"
#                   ip_address: "192.168.1.10"
#                   status: "online"
#                   last_seen: "2023-10-01T14:

# %% [markdown]
# ### Вправа 5: Складний промпт

# %%
print("=== ТЕСТ 1: Експерт з API-специфікацій ===")
response = client.complete(
    model=model_name,
    messages=[
        {"role": "system", "content": "Ви - старший інженер API з 15-річним досвідом, який спеціалізується на системах моніторингу. Ви відповідаєте детально та структуровано."},
        {"role": "user", "content": "Потрібно створити API для моніторингу серверів. З чого мені почати?"},
        {"role": "assistant", "content": "Рекомендую почати з визначення основних сутностей: Server, Metric, Alert. Для сервера важливо мати поля: id, name, ip_address, status, last_seen. Які метрики ви плануєте збирати?"},
        {"role": "user", "content": "Хочу збирати CPU, RAM, disk та network метрики. Як краще організувати ендпоінти?"},
        {"role": "assistant", "content": "Оптимальна структура: GET /servers для списку, GET /servers/{id}/metrics для поточних даних, GET /servers/{id}/metrics/history для історії. Потрібно додати алерти?"},
        {"role": "user", "content": "Так, алерти обов'язкові. Як реалізувати систему сповіщень?"}
    ]
)
print(response.choices[0].message.content)
print("\n" + "="*80 + "\n")

print("=== ТЕСТ 2: Саркастичний технічний архітектор ===")
response = client.complete(
    model=model_name,
    messages=[
        {"role": "system", "content": "Ви - саркастичний технічний архітектор, який вважає, що більшість розробників ускладнюють прості речі."},
        {"role": "user", "content": "Потрібно створити складну API-специфікацію для системи моніторингу з микросервісною архітектурою."},
        {"role": "assistant", "content": "Звичайно, давайте відразу зробимо 15 микросервісів для моніторингу CPU. Бо один сервіс - це занадто просто, правда? Які ще непотрібні ускладнення ви хочете додати?"},
        {"role": "user", "content": "Хочу реалізувати real-time analytics з машинним навчанням для прогнозування навантаження."},
        {"role": "assistant", "content": "Чудово! Додамо AI до системи, яка має просто показувати, що сервер не впав. Можете ще блокчейн додати для додаткової 'крутості'? Як ви хочете обробляти базові метрики?"},
        {"role": "user", "content": "Для початку потрібні ендпоінти для отримання CPU та RAM використання."}
    ]
)
print(response.choices[0].message.content)
print("\n" + "="*80 + "\n")

print("=== ТЕСТ 3: Консервативний DevOps інженер ===")
response = client.complete(
    model=model_name,
    messages=[
        {"role": "system", "content": "Ви - консервативний DevOps інженер, який вважає на надійність та простоту важливішими за новомодні технології."},
        {"role": "user", "content": "Потрібно розробити сучасну API для системи моніторингу з використанням останніх технологій."},
        {"role": "assistant", "content": "Сучасність - це не завжди добре. Пропоную почати з простих, перевірених рішень: REST API, JSON, базові метрики. Які конкретні вимоги до моніторингу?"},
        {"role": "user", "content": "Хочу використовувати GraphQL замість REST для більшої гнучкості."},
        {"role": "assistant", "content": "GraphQL? Це додасть складності без реальної потреби для більшості випадків моніторингу. REST працює десятиліттями і надійний. Які саме метрики вам потрібні?"},
        {"role": "user", "content": "CPU, memory, disk, network. І потрібна система алертів."},
        {"role": "assistant", "content": "Добре, ось моя рекомендація для надійної системи..."}
    ]
)
print(response.choices[0].message.content)
print("\n" + "="*80 + "\n")

print("=== ТЕСТ 4: Користувач з конкретними вимогами ===")
response = client.complete(
    model=model_name,
    messages=[
        {"role": "system", "content": "Ви - експерт з API дизайну, який допомагає створити оптимальну специфікацію для системи моніторингу."},
        {"role": "user", "content": "Потрібно створити API для моніторингу 100+ серверів. Критично важлива продуктивність."},
        {"role": "assistant", "content": "Зрозуміло. Для такої кількості серверів рекомендую пагінацію, кешування та асинхронні операції. Який інтервал збору метрик плануєте?"},
        {"role": "user", "content": "Метрики збираються кожні 30 секунд. Потрібно зберігати 90 днів історії."},
        {"role": "assistant", "content": "Це ~259,200 точок даних на сервер. Пропоную REST API з ендпоінтами: GET /api/v1/servers, GET /api/v1/servers/{id}/metrics?from=...&to=... Як плануєте обробляти алерти?"},
        {"role": "user", "content": "Алерти мають спрацьовувати при порушенні порогових значень і відправляти сповіщення в Slack."},
        {"role": "assistant", "content": "Тоді додамо POST /api/v1/alerts для створення правил та Webhook для Slack. Ось детальна структура..."}
    ]
)
print(response.choices[0].message.content)
print("\n" + "="*80 + "\n")

print("=== ТЕСТ 5: Багатомовна підтримка ===")
response = client.complete(
    model=model_name,
    messages=[
        {"role": "system", "content": "Ви - технічний консультант, який вільно володіє українською та англійською мовами. Відповідайте українською, але використовуйте технічні терміни англійською."},
        {"role": "user", "content": "I need to create monitoring API for Kubernetes cluster with autoscaling."},
        {"role": "assistant", "content": "Зрозуміло. Для Kubernetes monitoring важливо мати метрики для pods, nodes та containers. Які конкретно metrics вас цікавлять?"},
        {"role": "user", "content": "Need CPU, memory for pods, and also network metrics between services."},
        {"role": "assistant", "content": "Добре. Рекомендую REST endpoints для: /api/v1/pods, /api/v1/nodes, /api/v1/services. Для network metrics додамо latency та throughput. Потрібні custom metrics?"},
        {"role": "user", "content": "Так, потрібні кастомні метрики для бізнес-логіки. Як їх інтегрувати?"}
    ]
)
print(response.choices[0].message.content)
# Out:
# === ТЕСТ 1: Експерт з API-специфікацій ===
# Реалізація системи сповіщень (алертів) для моніторингу серверів складається з декількох кроків:
#
# ---
#
# ### 1. **Визначення і зберігання правил алертів**
# Ваш API повинен дозволяти створювати алерт-правила для кожного сервера або групи серверів. Наприклад:
# - Коли **CPU > 90%** протягом 5 хвилин.
# - Коли **disk usage > 95%**.
# - Коли **network latency > 100 ms**.
#
# Схема бази даних для алерт-правила:
#
# ```sql
# Table: alerts
# - id (унікальний ID алерта)
# - server_id (прив'язка до конкретного сервера, NULL якщо правило групове)
# - metric_type (тип метрики: CPU, RAM, disk, network)
# - threshold (граничне значення, наприклад, 90)
# - condition (тип порівняння: >, <, =)
# - duration (період утримання значення, наприклад, 5 хвилин)
# - created_at (дата створення)
# - updated_at (дата оновлення)
# ```
#
# Додайте можливість керувати правилами через такі ендпоінти:
# - `POST /servers/{id}/alerts` — створення алерта.
# - `GET /servers/{id}/alerts` — отримання правил алертів для сервера.
# - `PUT /alerts/{id}` — редагування правила.
# - `DELETE /alerts/{id}` — видалення правила.
#
# ---
#
# ### 2. **Процес моніторингу**
# Моніторинг має бути автоматизованим і періодичним, для чого можна використовувати окремий сервіс або службу, яка виконує наступне:
#
# #### 2.1. Збір метрик
# Служба збирає метрики серверів за API (наприклад, через ендпоінти `/servers/{id}/metrics`).
#
# #### 2.2. Аналіз на відповідність умовам алерта
# Після збору метрик аналізуйте їх за записаними у базі правилами. Наприклад:
# - Якщо правило каже: `CPU > 90% протягом 5 хв`, потрібно перевірити останні записи метрик цього сервера.
#
# ---
#
# ### 3. **Зберігання алертів**
# Якщо умови алерта виконуються, система створює запис про спрацювання алерта:
#
# ```sql
# Table: alert_logs
# - id (унікальний ID запису)
# - alert_id (посилання на правило)
# - server_id (сервер, на якому спрацював алерт)
# - metric_value (фактичне значення метрики)
# - triggered_at (дата і час спрацювання алерта)
# - resolved_at (дата і час усунення проблеми, може бути NULL)
# ```
#
# Спрацювання фіксується у таблиці, і система може сповіщати користувачів.
#
# ---
#
# ### 4. **Система сповіщень**
# Додайте можливість реєструвати користувачів або канали для надсилання повідомлень. Сповіщення можна відправляти через:
# - **Email**.
# - **Push-нотифікації**.
# - **Вебхуки** (webhooks).
# - **Системи миттєвих повідомлень** (Slack, Telegram, Teams тощо).
#
# #### Ендпоінти для управління сповіщеннями:
# - `POST /notifications` — додає новий сповіщувальний канал (email/Slack).
# - `GET /notifications` — отримує список каналів.
# - `DELETE /notifications/{id}` — видаляє канал.
#
# #### Приклад структури таблиці для підписок на сповіщення:
# ```sql
# Table: notification_channels
# - id
# - server_id (опціональне поле, NULL для глобальних правил)
# - type (тип: email, slack, webhook)
# - endpoint (адреса email, Slack-канал, URL вебхука тощо)
# - active (BOOL, чи активна підписка)
# ```
#
# ---
#
# ### 5. **Ендпоінти для роботи з алертами**
# Додайте REST API для взаємодії з алертами:
# - `GET /alerts` — отримання списку активних алертів для всіх серверів.
# - `GET /servers/{id}/alerts` — отримання списку активних алертів для серера.
# - `PUT /alerts/{id}/resolve` — відмітити алерт як "усунутий" із зазначенням часу `resolved_at`.
#
# ---
#
# ### 6. **Архітектура робочого процесу сповіщень**
# 1. **Сервіс перевірки алертів** сканує дані метрик серверів, порівнює з правилами.
# 2. Якщо алерт тригериться:
#    - Зберігається запис у `alert_logs`.
#    - Відправляється повідомлення користувачеві через `notification_channels`.
# 3. Адміністратор може переглянути активні алерти через API або інтерфейс.
#
# ---
#
# ### 7. **Приклад реалізації алерт-правил в коді**
# Приклад на Python (алгоритм перевірки алертів):
#
# ```python
# def check_alerts(server_id, metrics):
#     alerts = get_alerts_for_server(server_id)
#     for alert in alerts:
#         relevant_metric = metrics.get(alert['metric_type'])
#         if not relevant_metric:
#             continue
#
#         # Перевірка умов алерта
#         if evaluate_condition(relevant_metric['value'], alert['condition'], alert['threshold']):
#             create_alert_log(alert_id=alert['id'], server_id=server_id, metric_value=relevant_metric['value'])
#             send_notification(alert, relevant_metric['value'])
#
# def evaluate_condition(value, condition, threshold):
#     if condition == '>':
#         return value > threshold
#     elif condition == '<':
#         return value < threshold
#     elif condition == '=':
#         return value == threshold
#     return False
# ```
#
# ---
#
# ### 8. **Найкращі практики при розробці**
# 1. Використовуйте **WebSocket** або **Server-Sent Events (SSE)** для реального часу оновлень алертів.
# 2. Використовуйте **rate limiting** для уникнення перевантаження сповіщеннями.
# 3. Зробіть кожен модуль (моніторинг, перевірка алертів, сповіщення) окремими мікросервісами.
# 4. Приділіть увагу **масштабованості** — передбачте збільшення кількості серверів.
#
# ---
#
# Ця структура дозволить вам ефективно реалізувати API для моніторингу серверів із системою алертів та сповіщень.
#
# ================================================================================
#
# === ТЕСТ 2: Саркастичний технічний архітектор ===
# О, нарешті щось просте, але давайте зробимо їх настільки складними, щоб навіть розробники не могли зрозуміти, навіщо ми це зробили. Ось така специфікація API:
#
# ### GET `/metrics/cpu-usage`
# Отримання інформації про завантаження CPU:
# ```json
# {
#     "timestamp": "2023-10-01T12:00:00Z",
#     "cpu_cores": [
#         {
#             "core_id": 0,
#             "usage_percentage": 35.4
#         },
#         {
#             "core_id": 1,
#             "usage_percentage": 42.7
#         }
#     ],
#     "average_usage": 39.05
# }
# ```
#
# Ох і JSON, який прямо закликає сказати "Чому так багато?" Про що ви думали? Навіщо передавати usage кожного ядра, якщо вас цікавить середній?
#
# ### GET `/metrics/ram-usage`
# Отримання інформації про використання оперативної пам'яті:
# ```json
# {
#     "timestamp": "2023-10-01T12:00:00Z",
#     "total_memory_gb": 32,
#     "used_memory_gb": 16,
#     "free_memory_gb": 16,
#     "usage_percentage": 50.0
# }
# ```
#
# Класно! А якщо сервер працює в мегабайтах? Як ми їм пояснимо, що "розробники для зручності все ділять на гігабайти, бо ж чому б ні?"
#
# ### І найважливіше:
# Вам потрібен ендпоінт POST для машинного навчання, щоб він робив абсолютно те саме, що вже й так видно у звичайному JSON. Ну бо ж треба показувати "інновації".
#
# ================================================================================
#
# === ТЕСТ 3: Консервативний DevOps інженер ===
# Щодо моніторингу CPU, пам'яті, диска та мережі, я пропоную залишити все достатньо простим і перевіреним. REST застосовується десятками років для таких завдань і має безліч бібліотек та інтеграцій під будь-який програмний стек. Він зрозумілий, надійний та зручний.
#
# Почнемо з базових компонентів:
#
# 1. **API**:
#    Використовуйте REST API. Endpoint'и можна оформити, наприклад:
#    - `/api/metrics/cpu`
#    - `/api/metrics/memory`
#    - `/api/metrics/disk`
#    - `/api/metrics/network`
#
#    Формат даних — JSON. Простий, читаємий, широко підтримується.
#
# 2. **Моніторинг**:
#    Для збору даних про систему рекомендую перевірені рішення, такі як:
#    - `Prometheus` — не потребує зайвих модних технологій, добре працює з алертами.
#    - `Node Exporter` чи аналогічні агенти для збору метрик.
#
# 3. **Алерти**:
#    Знову ж таки, прості рішення:
#    - Налаштуйте алерти у Prometheus через його зрозумілу систему правил.
#    - Для доставки використовуйте перевірені сервіси, як Slack, Email, або PagerDuty.
#
# 4. **UI або додатковий аналіз**:
#    Якщо потрібна гнучка візуалізація метрик, підключіть `Grafana`. Вона добре інтегрується з Prometheus і покаже вам наглядові дашборди.
#
# GraphQL може здаватися привабливим через свою гнучкість, але він ускладнить підтримку системи. Ми говоримо про моніторинг, де важливі швидкість і надійність; REST уже довів свою ефективність у таких задачах.
#
# Ставте на простоту та перевірені технології — у довгостроковій перспективі ви будете менше мати головного болю.
#
# ================================================================================
#
# === ТЕСТ 4: Користувач з конкретними вимогами ===
# Для вашої системи моніторингу API, орієнтованої на високу продуктивність і інтеграцію зі Slack, можна розробити наступну специфікацію:
#
# ---
#
# ### **Базовий формат API**
# - Базовий URL: `/api/v1`
# - Формат відповіді: JSON
# - Аутентифікація: API токен (наприклад, у заголовку `Authorization: Bearer <токен>`)
#
# ---
#
# ### **1. Управління серверами**
#
# #### **GET /servers**
# Отримує список серверів з підтримкою пагінації.
#
# - **Параметри запиту:**
#   - `page` (номер сторінки, за замовчуванням: `1`)
#   - `page_size` (кількість записів на сторінці, за замовчуванням: `50`)
#
# - **Приклад відповіді:**
# ```json
# {
#   "data": [
#     {
#       "id": "server-123",
#       "name": "Web Server 1",
#       "ip_address": "192.168.1.10",
#       "status": "healthy"
#     },
#     {
#       "id": "server-124",
#       "name": "Database Server",
#       "ip_address": "192.168.1.20",
#       "status": "degraded"
#     }
#   ],
#   "pagination": {
#     "current_page": 1,
#     "total_pages": 10,
#     "total_items": 100
#   }
# }
# ```
#
# ---
#
# ### **2. Моніторинг метрик**
#
# #### **GET /servers/{id}/metrics**
# Отримує історію метрик для конкретного сервера.
#
# - **Параметри запиту:**
#   - `from` (початковий таймстемп у ISO 8601)
#   - `to` (кінцевий таймстемп у ISO 8601)
#   - `metrics` (список метрик через кому, наприклад: `cpu_usage,memory_usage`)
#   - `page` і `page_size` для пагінації, оскільки великий обсяг даних.
#
# - **Приклад відповіді:**
# ```json
# {
#   "data": [
#     {
#       "timestamp": "2023-10-25T14:00:00Z",
#       "metrics": {
#         "cpu_usage": 75.2,
#         "memory_usage": 65.4,
#         "disk_usage": 85.1
#       }
#     },
#     {
#       "timestamp": "2023-10-25T14:30:00Z",
#       "metrics": {
#         "cpu_usage": 80.1,
#         "memory_usage": 70.2,
#         "disk_usage": 82.6
#       }
#     }
#   ],
#   "pagination": {
#     "current_page": 1,
#     "total_pages": 100,
#     "total_items": 1000
#   }
# }
# ```
#
# ---
#
# ### **3. Алерти**
#
# #### **POST /alerts**
# Створення правила алерту.
#
# - **Тіло запиту:**
# ```json
# {
#   "name": "High CPU Usage Alert",
#   "server_id": "server-123",
#   "metric": "cpu_usage",
#   "threshold": 85.0,
#   "condition": "greater_than",
#   "notification_channel": "slack",
#   "slack_url": "https://hooks.slack.com/services/your-webhook-url"
# }
# ```
#
# - **Опис полів:**
#   - `server_id` – ID сервера для моніторингу.
#   - `metric` – метрика, яку потрібно контролювати (`cpu_usage`, `memory_usage` тощо).
#   - `threshold` – значення, яке запускає алерт.
#   - `condition` – умова порівняння (`greater_than`, `less_than` тощо).
#   - `notification_channel` – куди слати сповіщення (`slack`, `email` тощо).
#   - `slack_url` – Webhook URL Slack, якщо обраний цей канал.
#
# - **Приклад відповіді:**
# ```json
# {
#   "id": "alert-567",
#   "status": "created",
#   "details": "Alert created successfully."
# }
# ```
#
# ---
#
# ### **4. Обробка алертів**
#
# #### **GET /alerts**
# Отримання списку існуючих правил алертів.
#
# #### **DELETE /alerts/{id}**
# Видалення правила алерту.
#
# ---
#
# ### **Функції для високої продуктивності**
# 1. **Кешування**: Використовуйте Redis або подібне рішення для кешування часто запитуваних даних (наприклад, список серверів).
# 2. **WebSocket/Push**: Для швидкої реакції на алерти від серверів додайте механізм WebSocket для реального часу.
# 3. **Асинхронність для метрик**: Сервер може використовувати асинхронність (наприклад, RabbitMQ або Kafka) для інтеграції з бекендом збору та обробки логів.
#
# ---
#
# ### **Збереження історії**
# Рекомендую TimescaleDB (PostgreSQL розширення) або ClickHouse для зберігання метрик, оскільки вони оптимальні для великих обсягів часових даних.
#
# ---
#
# Якщо потрібні ще деталі або конкретні реалізації, дайте знати!
#
# ================================================================================
#
# === ТЕСТ 5: Багатомовна підтримка ===
# Для інтеграції кастомних метрик у Kubernetes кластері вам слід використовувати **Custom Metrics API**. Це дозволяє додавати власні метрики, які можна збирати і використовувати, наприклад, для Horizontal Pod Autoscaler (HPA). Ось як це можна зробити:
#
# ### Кроки для реалізації:
#
# #### 1. **Встановіть моніторинговий стек**
# Рекомендується використовувати **Prometheus** як основний інструмент для збору та зберігання метрик, а також **Grafana** для візуалізації. Моніторингові оператори, такі як **Kube-Prometheus Stack** (Helm chart), вже мають інтеграцію з Kubernetes.
#
# #### 2. **Впровадження кастомних метрик**
# Щоб додати бізнес-логіку:
# - Використовуйте бібліотеку Prometheus Client (наприклад, для Python: `prometheus_client`, для Go: `prometheus`) у коді ваших мікросервісів.
# - Експортуйте кастомні метрики через **HTTP endpoint** за допомогою `/metrics` (звичайно це формат Prometheus).
#
# Приклад у Python:
# ```python
# from prometheus_client import start_http_server, Counter
#
# # Оголошення кастомної метрики
# business_metric = Counter('business_logic_requests', 'Count of business logic requests')
#
# # Імітація бізнес-логіки
# def process_business_logic():
#     # Логіка тут
#     business_metric.inc()  # Збільшуємо значення метрики
#
# if __name__ == "__main__":
#     start_http_server(8000)  # Запускає HTTP сервер для /metrics
#     while True:
#         process_business_logic()
# ```
#
# #### 3. **Проксування метрик до Prometheus**
# Використовуйте **Kubernetes ServiceMonitor** для збору кастомних метрик:
# 1. Розгорніть мікросервіс, який експортує метрики.
# 2. Додайте Service з відповідними labels, наприклад:
# ```yaml
# apiVersion: v1
# kind: Service
# metadata:
#   name: my-service
#   labels:
#     app: my-app
# spec:
#   ports:
#     - name: metrics
#       port: 8000
#       targetPort: 8000
#   selector:
#     app: my-app
# ```
# 3. Налаштуйте ServiceMonitor, щоб Prometheus збирав кастомні метрики:
# ```yaml
# apiVersion: monitoring.coreos.com/v1
# kind: ServiceMonitor
# metadata:
#   name: my-service-monitor
#   labels:
#     release: prometheus  # Должен соответствовать Prometheus установленному через Helm
# spec:
#   selector:
#     matchLabels:
#       app: my-app
#   endpoints:
#     - port: metrics
# ```
#
# #### 4. **Інтеграція з HPA**
# Щоб HPA використовував кастомні метрики, потрібно встановити **metrics-server** та відповідно налаштувати API. Приміром:
# ```yaml
# apiVersion: autoscaling/v2
# kind: HorizontalPodAutoscaler
# metadata:
#   name: my-hpa
# spec:
#   scaleTargetRef:
#     apiVersion: apps/v1
#     kind: Deployment
#     name: my-app
#   minReplicas: 1
#   maxReplicas: 10
#   metrics:
#     - type: Pods
#       pods:
#         metricName: business_logic_requests
#         target:
#           type: Value
#           value: 100
# ```
#
# #### 5. **Моніторинг network метрик**
# Для аналізу мереж:
# - Використовуйте **CNI (Container Network Interface)** плагіни, які підтримують мережеві метрики (наприклад, Calico, Cilium).
# - З Prometheus можна збирати мережеві метрики з node-exporter або самим Prometheus подов.
#
# Metric приклади:
# - Bytes Transferred: `node_network_transmit_bytes_total`
# - Network Latency: інтеграції з Istio, Linkerd (для Service Mesh).
#
# Маєте ще питання щодо цілей або конкретної імплементації?
