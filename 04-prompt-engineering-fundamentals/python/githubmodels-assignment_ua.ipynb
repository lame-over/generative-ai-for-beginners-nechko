# %% [markdown]
# # Вступ до інженерії промптів
# Інженерія промптів - це процес розробки та оптимізації промптів для завдань обробки природної мови. Він включає вибір правильних промптів, налаштування їхніх параметрів та оцінку їх ефективності. Інженерія промптів є критично важливою для досягнення високої точності та ефективності в моделях NLP. У цьому розділі ми дослідимо основи інженерії промптів, використовуючи моделі OpenAI для експериментів.

# %% [markdown]
# ### Вправа 1: Токенізація
# Дослідіть токенізацію за допомогою tiktoken - швидкого токенізатора з відкритим кодом від OpenAI
# Дивіться [OpenAI Cookbook](https://github.com/openai/openai-cookbook/blob/main/examples/How_to_count_tokens_with_tiktoken.ipynb?WT.mc_id=academic-105485-koreyst) для додаткових прикладів.

# %%
# ВПРАВА:
# 1. Спочатку запустіть вправу як є
# 2. Змініть текст на будь-який промпт, який ви хочете використати, і перезапустіть, щоб побачити токени

import tiktoken

# Визначте промпт, який ви хочете токенізувати
text = f"""
Юпітер - п'ята планета від Сонця і найбільша \
в Сонячній системі. Це газовий гігант з масою \
в одну тисячну від маси Сонця, але в два з половиною \
рази більшою за масу всіх інших планет Сонячної системи разом узятих. \
Юпітер - один з найяскравіших об'єктів, видимих неозброєним оком \
на нічному небі, і був відомий стародавнім цивілізаціям ще \
до писаної історії. Він названий на честь римського бога Юпітера.[19] \
При спостереженні з Землі Юпітер може бути настільки яскравим, що його відбите \
світло може відкидати видимі тіні,[20] і в середньому він є третім за яскравістю \
природним об'єктом на нічному небі після Місяця та Венери.
"""

# Set the model you want encoding for
encoding = tiktoken.encoding_for_model("gpt-3.5-turbo")

# Encode the text - gives you the tokens in integer form
tokens = encoding.encode(text)
print(tokens)

# Decode the integers to see what the text versions look like
[encoding.decode_single_token_bytes(token) for token in tokens]
# Out:
# [198, 140, 106, 8164, 27385, 58060, 482, 5173, 6, 4329, 44613, 5173, 3114, 7486, 8341, 1506, 5927, 27385, 7094, 28599, 17766, 10589, 4329, 84954, 6850, 19039, 10124, 27385, 29118, 12426, 1506, 5927, 28599, 17766, 4329, 6148, 2156, 27385, 12415, 93099, 27385, 13, 1301, 99, 1532, 25756, 19188, 6856, 44938, 25756, 27385, 15752, 7486, 1830, 11122, 11562, 18437, 1482, 12182, 5927, 53419, 2156, 3865, 11047, 13810, 4329, 6148, 2156, 3865, 5927, 27385, 7094, 11562, 18437, 1840, 28599, 17766, 10589, 4329, 11, 21022, 3114, 1532, 5927, 74254, 1506, 11122, 29619, 6856, 1840, 13999, 12182, 39479, 1840, 14391, 27385, 29118, 12426, 1482, 12182, 44946, 11562, 18437, 3865, 35714, 27385, 10693, 84954, 2156, 30480, 10693, 5173, 3114, 7486, 8341, 28599, 17766, 4329, 6148, 13999, 141, 245, 93099, 1840, 39479, 12507, 14257, 9136, 4329, 23311, 10693, 13, 1301, 106, 8164, 27385, 58060, 482, 53419, 19479, 11122, 6850, 19039, 4329, 66144, 28086, 27385, 30480, 10693, 21923, 6, 141, 242, 4898, 1830, 27385, 5591, 11, 74020, 16494, 67745, 19175, 20219, 10124, 2233, 1482, 141, 242, 2156, 16494, 72664, 12507, 13373, 6850, 27385, 6148, 2156, 72952, 6850, 50693, 27385, 11, 84954, 14391, 3865, 5591, 5927, 27385, 7094, 12507, 44938, 18868, 17721, 9706, 18226, 2156, 27385, 6578, 39233, 28089, 27385, 3114, 27385, 9136, 1506, 10589, 27385, 4329, 6578, 9015, 231, 1532, 57297, 5173, 13810, 7486, 1482, 141, 245, 84954, 6735, 9239, 27385, 141, 245, 13, 23784, 27385, 2156, 6850, 57059, 14332, 12415, 13373, 17756, 1532, 35592, 18600, 16494, 2297, 4929, 4898, 22885, 14391, 14837, 1506, 1301, 106, 8164, 27385, 58060, 1506, 8032, 777, 60, 23227, 31203, 84714, 25262, 7753, 50436, 5372, 2156, 27385, 11122, 53677, 10298, 3114, 27385, 1301, 106, 8164, 27385, 58060, 45583, 1532, 14391, 3865, 23311, 13373, 6735, 27385, 29118, 17165, 46410, 66144, 28086, 16494, 11, 9015, 231, 1482, 1301, 117, 22885, 5927, 27385, 7094, 10124, 27055, 45916, 27385, 1830, 39865, 45583, 1532, 5927, 27385, 7094, 17165, 7094, 8131, 1840, 74020, 16494, 27385, 11047, 27385, 2156, 27385, 17706, 508, 60, 84954, 5927, 66386, 13404, 2156, 4929, 72952, 5927, 27385, 2156, 9015, 242, 86995, 8341, 27385, 6578, 44946, 46410, 66144, 28086, 27385, 6735, 12182, 37405, 2233, 9706, 2156, 16494, 21923, 6, 141, 242, 4898, 94866, 13373, 6850, 27385, 6148, 2156, 72952, 6850, 50693, 27385, 5173, 27385, 2297, 14009, 45458, 27385, 21204, 10589, 4329, 11047, 1506, 23784, 5372, 7753, 1840, 627]
# [b'\n',
#  b'\xd0',
#  b'\xae',
#  b'\xd0\xbf',
#  b'\xd1\x96',
#  b'\xd1\x82\xd0\xb5\xd1\x80',
#  b' -',
#  b' \xd0\xbf',
#  b"'",
#  b'\xd1\x8f',
#  b'\xd1\x82\xd0\xb0',
#  b' \xd0\xbf',
#  b'\xd0\xbb',
#  b'\xd0\xb0\xd0\xbd',
#  b'\xd0\xb5\xd1\x82',
#  b'\xd0\xb0',
#  b' \xd0\xb2',
#  b'\xd1\x96',
#  b'\xd0\xb4',
#  b' \xd0\xa1',
#  b'\xd0\xbe\xd0\xbd',
#  b'\xd1\x86',
#  b'\xd1\x8f',
#  b' \xd1\x96',
#  b' \xd0\xbd',
#  b'\xd0\xb0\xd0\xb9',
#  b'\xd0\xb1',
#  b'\xd1\x96',
#  b'\xd0\xbb\xd1\x8c',
#  b'\xd1\x88',
#  b'\xd0\xb0',
#  b' \xd0\xb2',
#  b' \xd0\xa1',
#  b'\xd0\xbe\xd0\xbd',
#  b'\xd1\x8f',
#  b'\xd1\x87',
#  b'\xd0\xbd',
#  b'\xd1\x96',
#  b'\xd0\xb9',
#  b' \xd1\x81\xd0\xb8\xd1\x81\xd1\x82\xd0\xb5\xd0\xbc',
#  b'\xd1\x96',
#  b'.',
#  b' \xd0',
#  b'\xa6',
#  b'\xd0\xb5',
#  b' \xd0\xb3',
#  b'\xd0\xb0\xd0\xb7',
#  b'\xd0\xbe\xd0\xb2',
#  b'\xd0\xb8\xd0\xb9',
#  b' \xd0\xb3',
#  b'\xd1\x96',
#  b'\xd0\xb3',
#  b'\xd0\xb0\xd0\xbd',
#  b'\xd1\x82',
#  b' \xd0\xb7',
#  b' \xd0\xbc',
#  b'\xd0\xb0\xd1\x81',
#  b'\xd0\xbe',
#  b'\xd1\x8e',
#  b' \xd0\xb2',
#  b' \xd0\xbe\xd0\xb4',
#  b'\xd0\xbd',
#  b'\xd1\x83',
#  b' \xd1\x82',
#  b'\xd0\xb8\xd1\x81',
#  b'\xd1\x8f',
#  b'\xd1\x87',
#  b'\xd0\xbd',
#  b'\xd1\x83',
#  b' \xd0\xb2',
#  b'\xd1\x96',
#  b'\xd0\xb4',
#  b' \xd0\xbc',
#  b'\xd0\xb0\xd1\x81',
#  b'\xd0\xb8',
#  b' \xd0\xa1',
#  b'\xd0\xbe\xd0\xbd',
#  b'\xd1\x86',
#  b'\xd1\x8f',
#  b',',
#  b' \xd0\xb0',
#  b'\xd0\xbb',
#  b'\xd0\xb5',
#  b' \xd0\xb2',
#  b' \xd0\xb4\xd0\xb2',
#  b'\xd0\xb0',
#  b' \xd0\xb7',
#  b' \xd0\xbf\xd0\xbe\xd0\xbb',
#  b'\xd0\xbe\xd0\xb2',
#  b'\xd0\xb8',
#  b'\xd0\xbd\xd0\xbe',
#  b'\xd1\x8e',
#  b' \xd1\x80\xd0\xb0\xd0\xb7',
#  b'\xd0\xb8',
#  b' \xd0\xb1',
#  b'\xd1\x96',
#  b'\xd0\xbb\xd1\x8c',
#  b'\xd1\x88',
#  b'\xd0\xbe',
#  b'\xd1\x8e',
#  b' \xd0\xb7\xd0\xb0',
#  b' \xd0\xbc',
#  b'\xd0\xb0\xd1\x81',
#  b'\xd1\x83',
#  b' \xd0\xb2\xd1\x81',
#  b'\xd1\x96',
#  b'\xd1\x85',
#  b' \xd1\x96',
#  b'\xd0\xbd',
#  b'\xd1\x88\xd0\xb8',
#  b'\xd1\x85',
#  b' \xd0\xbf',
#  b'\xd0\xbb',
#  b'\xd0\xb0\xd0\xbd',
#  b'\xd0\xb5\xd1\x82',
#  b' \xd0\xa1',
#  b'\xd0\xbe\xd0\xbd',
#  b'\xd1\x8f',
#  b'\xd1\x87',
#  b'\xd0\xbd\xd0\xbe',
#  b'\xd1',
#  b'\x97',
#  b' \xd1\x81\xd0\xb8\xd1\x81\xd1\x82\xd0\xb5\xd0\xbc',
#  b'\xd0\xb8',
#  b' \xd1\x80\xd0\xb0\xd0\xb7',
#  b'\xd0\xbe\xd0\xbc',
#  b' \xd1\x83',
#  b'\xd0\xb7',
#  b'\xd1\x8f',
#  b'\xd1\x82\xd0\xb8',
#  b'\xd1\x85',
#  b'.',
#  b' \xd0',
#  b'\xae',
#  b'\xd0\xbf',
#  b'\xd1\x96',
#  b'\xd1\x82\xd0\xb5\xd1\x80',
#  b' -',
#  b' \xd0\xbe\xd0\xb4',
#  b'\xd0\xb8\xd0\xbd',
#  b' \xd0\xb7',
#  b' \xd0\xbd',
#  b'\xd0\xb0\xd0\xb9',
#  b'\xd1\x8f',
#  b'\xd1\x81\xd0\xba',
#  b'\xd1\x80\xd0\xb0\xd0\xb2',
#  b'\xd1\x96',
#  b'\xd1\x88\xd0\xb8',
#  b'\xd1\x85',
#  b' \xd0\xbe\xd0\xb1',
#  b"'",
#  b'\xd1',
#  b'\x94',
#  b'\xd0\xba',
#  b'\xd1\x82',
#  b'\xd1\x96',
#  b'\xd0\xb2',
#  b',',
#  b' \xd0\xb2\xd0\xb8\xd0\xb4',
#  b'\xd0\xb8\xd0\xbc',
#  b'\xd0\xb8\xd1\x85',
#  b' \xd0\xbd\xd0\xb5',
#  b'\xd0\xbe\xd0\xb7',
#  b'\xd0\xb1',
#  b'\xd1\x80',
#  b'\xd0\xbe',
#  b'\xd1',
#  b'\x94',
#  b'\xd0\xbd',
#  b'\xd0\xb8\xd0\xbc',
#  b' \xd0\xbe\xd0\xba',
#  b'\xd0\xbe\xd0\xbc',
#  b' \xd0\xbd\xd0\xb0',
#  b' \xd0\xbd',
#  b'\xd1\x96',
#  b'\xd1\x87',
#  b'\xd0\xbd',
#  b'\xd0\xbe\xd0\xbc\xd1\x83',
#  b' \xd0\xbd',
#  b'\xd0\xb5\xd0\xb1',
#  b'\xd1\x96',
#  b',',
#  b' \xd1\x96',
#  b' \xd0\xb1',
#  b'\xd1\x83',
#  b'\xd0\xb2',
#  b' \xd0\xb2',
#  b'\xd1\x96',
#  b'\xd0\xb4',
#  b'\xd0\xbe\xd0\xbc',
#  b'\xd0\xb8\xd0\xb9',
#  b' \xd1\x81\xd1\x82',
#  b'\xd0\xb0\xd1\x80',
#  b'\xd0\xbe\xd0\xb4',
#  b'\xd0\xb0\xd0\xb2',
#  b'\xd0\xbd',
#  b'\xd1\x96',
#  b'\xd0\xbc',
#  b' \xd1\x86',
#  b'\xd0\xb8\xd0\xb2',
#  b'\xd1\x96',
#  b'\xd0\xbb',
#  b'\xd1\x96',
#  b'\xd0\xb7',
#  b'\xd0\xb0',
#  b'\xd1\x86',
#  b'\xd1\x96',
#  b'\xd1\x8f',
#  b'\xd0\xbc',
#  b' \xd1',
#  b'\x89',
#  b'\xd0\xb5',
#  b' \xd0\xb4\xd0\xbe',
#  b' \xd0\xbf',
#  b'\xd0\xb8\xd1\x81',
#  b'\xd0\xb0\xd0\xbd',
#  b'\xd0\xbe',
#  b'\xd1',
#  b'\x97',
#  b' \xd1\x96',
#  b'\xd1\x81\xd1\x82',
#  b'\xd0\xbe\xd1\x80',
#  b'\xd1\x96',
#  b'\xd1',
#  b'\x97',
#  b'.',
#  b' \xd0\x92',
#  b'\xd1\x96',
#  b'\xd0\xbd',
#  b' \xd0\xbd',
#  b'\xd0\xb0\xd0\xb7\xd0\xb2',
#  b'\xd0\xb0\xd0\xbd\xd0\xb8',
#  b'\xd0\xb9',
#  b' \xd0\xbd\xd0\xb0',
#  b' \xd1\x87',
#  b'\xd0\xb5',
#  b'\xd1\x81\xd1\x82\xd1\x8c',
#  b' \xd1\x80',
#  b'\xd0\xb8\xd0\xbc',
#  b'\xd1\x81',
#  b'\xd1\x8c',
#  b'\xd0\xba',
#  b'\xd0\xbe\xd0\xb3\xd0\xbe',
#  b' \xd0\xb1',
#  b'\xd0\xbe\xd0\xb3',
#  b'\xd0\xb0',
#  b' \xd0',
#  b'\xae',
#  b'\xd0\xbf',
#  b'\xd1\x96',
#  b'\xd1\x82\xd0\xb5\xd1\x80',
#  b'\xd0\xb0',
#  b'.[',
#  b'19',
#  b']',
#  b' \xd0\x9f',
#  b'\xd1\x80\xd0\xb8',
#  b' \xd1\x81\xd0\xbf',
#  b'\xd0\xbe\xd1\x81\xd1\x82',
#  b'\xd0\xb5\xd1\x80',
#  b'\xd0\xb5\xd0\xb6',
#  b'\xd0\xb5\xd0\xbd',
#  b'\xd0\xbd',
#  b'\xd1\x96',
#  b' \xd0\xb7',
#  b' \xd0\x97',
#  b'\xd0\xb5\xd0\xbc',
#  b'\xd0\xbb',
#  b'\xd1\x96',
#  b' \xd0',
#  b'\xae',
#  b'\xd0\xbf',
#  b'\xd1\x96',
#  b'\xd1\x82\xd0\xb5\xd1\x80',
#  b' \xd0\xbc\xd0\xbe\xd0\xb6',
#  b'\xd0\xb5',
#  b' \xd0\xb1',
#  b'\xd1\x83',
#  b'\xd1\x82\xd0\xb8',
#  b' \xd0\xbd\xd0\xb0',
#  b'\xd1\x81\xd1\x82',
#  b'\xd1\x96',
#  b'\xd0\xbb\xd1\x8c',
#  b'\xd0\xba\xd0\xb8',
#  b' \xd1\x8f',
#  b'\xd1\x81\xd0\xba',
#  b'\xd1\x80\xd0\xb0\xd0\xb2',
#  b'\xd0\xb8\xd0\xbc',
#  b',',
#  b' \xd1',
#  b'\x89',
#  b'\xd0\xbe',
#  b' \xd0',
#  b'\xb9',
#  b'\xd0\xbe\xd0\xb3\xd0\xbe',
#  b' \xd0\xb2',
#  b'\xd1\x96',
#  b'\xd0\xb4',
#  b'\xd0\xb1',
#  b'\xd0\xb8\xd1\x82\xd0\xb5',
#  b' \xd1\x81\xd0\xb2',
#  b'\xd1\x96',
#  b'\xd1\x82',
#  b'\xd0\xbb\xd0\xbe',
#  b' \xd0\xbc\xd0\xbe\xd0\xb6',
#  b'\xd0\xb5',
#  b' \xd0\xb2',
#  b'\xd1\x96',
#  b'\xd0\xb4',
#  b'\xd0\xba\xd0\xb8',
#  b'\xd0\xb4',
#  b'\xd0\xb0\xd1\x82',
#  b'\xd0\xb8',
#  b' \xd0\xb2\xd0\xb8\xd0\xb4',
#  b'\xd0\xb8\xd0\xbc',
#  b'\xd1\x96',
#  b' \xd1\x82',
#  b'\xd1\x96',
#  b'\xd0\xbd',
#  b'\xd1\x96',
#  b',[',
#  b'20',
#  b']',
#  b' \xd1\x96',
#  b' \xd0\xb2',
#  b' \xd1\x81\xd0\xb5\xd1\x80',
#  b'\xd0\xb5\xd0\xb4',
#  b'\xd0\xbd',
#  b'\xd1\x8c',
#  b'\xd0\xbe\xd0\xbc\xd1\x83',
#  b' \xd0\xb2',
#  b'\xd1\x96',
#  b'\xd0\xbd',
#  b' \xd1',
#  b'\x94',
#  b' \xd1\x82\xd1\x80',
#  b'\xd0\xb5\xd1\x82',
#  b'\xd1\x96',
#  b'\xd0\xbc',
#  b' \xd0\xb7\xd0\xb0',
#  b' \xd1\x8f',
#  b'\xd1\x81\xd0\xba',
#  b'\xd1\x80\xd0\xb0\xd0\xb2',
#  b'\xd1\x96',
#  b'\xd1\x81\xd1\x82',
#  b'\xd1\x8e',
#  b' \xd0\xbf\xd1\x80\xd0\xb8',
#  b'\xd1\x80',
#  b'\xd0\xbe\xd0\xb4',
#  b'\xd0\xbd',
#  b'\xd0\xb8\xd0\xbc',
#  b' \xd0\xbe\xd0\xb1',
#  b"'",
#  b'\xd1',
#  b'\x94',
#  b'\xd0\xba',
#  b'\xd1\x82\xd0\xbe\xd0\xbc',
#  b' \xd0\xbd\xd0\xb0',
#  b' \xd0\xbd',
#  b'\xd1\x96',
#  b'\xd1\x87',
#  b'\xd0\xbd',
#  b'\xd0\xbe\xd0\xbc\xd1\x83',
#  b' \xd0\xbd',
#  b'\xd0\xb5\xd0\xb1',
#  b'\xd1\x96',
#  b' \xd0\xbf',
#  b'\xd1\x96',
#  b'\xd1\x81',
#  b'\xd0\xbb\xd1\x8f',
#  b' \xd0\x9c',
#  b'\xd1\x96',
#  b'\xd1\x81\xd1\x8f',
#  b'\xd1\x86',
#  b'\xd1\x8f',
#  b' \xd1\x82',
#  b'\xd0\xb0',
#  b' \xd0\x92',
#  b'\xd0\xb5\xd0\xbd',
#  b'\xd0\xb5\xd1\x80',
#  b'\xd0\xb8',
#  b'.\n']

# %% [markdown]
# ### Вправа 2: Перевірка налаштування ключа Github Models
#
# Запустіть код нижче, щоб перевірити, чи правильно налаштована кінцева точка Github Models. Код просто випробовує простий базовий промпт і перевіряє завершення. Вхідний текст `о скажи, чи бачиш ти` має завершитись відповідно до контексту.

# %%
# !pip install azure-ai-inference
# Out:
# Requirement already satisfied: azure-ai-inference in c:\users\diman\desktop\коледж\бакалавр\1 курс\1 семестр\основи генеративного искуственого интелекта\venv\lib\site-packages (1.0.0b9)
# Requirement already satisfied: isodate>=0.6.1 in c:\users\diman\desktop\коледж\бакалавр\1 курс\1 семестр\основи генеративного искуственого интелекта\venv\lib\site-packages (from azure-ai-inference) (0.7.2)
# Requirement already satisfied: azure-core>=1.30.0 in c:\users\diman\desktop\коледж\бакалавр\1 курс\1 семестр\основи генеративного искуственого интелекта\venv\lib\site-packages (from azure-ai-inference) (1.36.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\diman\desktop\коледж\бакалавр\1 курс\1 семестр\основи генеративного искуственого интелекта\venv\lib\site-packages (from azure-ai-inference) (4.15.0)
# Requirement already satisfied: requests>=2.21.0 in c:\users\diman\desktop\коледж\бакалавр\1 курс\1 семестр\основи генеративного искуственого интелекта\venv\lib\site-packages (from azure-core>=1.30.0->azure-ai-inference) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\diman\desktop\коледж\бакалавр\1 курс\1 семестр\основи генеративного искуственого интелекта\venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-inference) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\diman\desktop\коледж\бакалавр\1 курс\1 семестр\основи генеративного искуственого интелекта\venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-inference) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\diman\desktop\коледж\бакалавр\1 курс\1 семестр\основи генеративного искуственого интелекта\venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-inference) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\diman\desktop\коледж\бакалавр\1 курс\1 семестр\основи генеративного искуственого интелекта\venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-inference) (2025.10.5)

# %%
import os
from dotenv import load_dotenv
from azure.ai.inference import ChatCompletionsClient
from azure.ai.inference.models import SystemMessage, UserMessage
from azure.core.credentials import AzureKeyCredential

load_dotenv()
token = os.getenv('GITHUB_TOKEN')

print(token)
print(type(token))

model_name = "gpt-4o"

client = ChatCompletionsClient(
    endpoint='https://models.inference.ai.azure.com',
    credential=AzureKeyCredential(token),
)

def get_completion(prompt, client, model_name, temperature=1.0, max_tokens=1000, top_p=1.0):
    response = client.complete(
        messages=[
            {
                "role": "system",
                "content": "Ви - корисний асистент.",
            },
            {
                "role": "user",
                "content": prompt,
            },
        ],
        model=model_name,
        temperature=temperature,
        max_tokens=max_tokens,
        top_p=top_p
    )
    return response.choices[0].message.content

## ---------- Виклик допоміжного методу

### 1. Встановіть основний вміст або текст промпту
text = f"""
о скажи, чи бачиш ти
"""

### 2. Використайте його в шаблоні промпту нижче
prompt = f"""
```{text}```
"""

## 3. Запустіть промпт
response = get_completion(prompt, client, model_name)
print(response)
# Out:
# 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
# <class 'str'>
# Ці рядки здаються початком відомого вірша Тараса Шевченка "Реве та стогне Дніпр широкий". Ось продовження цього твору:
#
# *О, чи бачиш світло з неба?
# Схід зорі вітає знов,
# Реве та стогне Дніпр широкий,
# Серце рідне тріпотить любов.
# (*уривок переформатовано для стилю.)
#
# Це правильний контекст?

# %% [markdown]
# ### Вправа 3: Вигадки
# Дослідіть, що відбувається, коли ви просите LLM повернути завершення для промпту про тему, яка може не існувати, або про теми, про які вона може не знати, оскільки вони були за межами її попередньо навченого набору даних (більш пізні). Подивіться, як змінюється відповідь, якщо ви спробуєте інший промпт або іншу модель.

# %%
## Встановіть текст для простого промпту або основного вмісту
## Промпт показує формат шаблону з текстом - додайте підказки, команди тощо, якщо потрібно
## Запустіть завершення
text = f"""
створіть план уроку про Марсіанську війну 2076 року.
"""

prompt = f"""
```{text}```
"""

response = get_completion(prompt, client, model_name)
print(response)
# Out:
# Оскільки "Марсіанська війна 2076 року" є вигаданою подією (на момент жовтня 2023 року така подія ніде не зафіксована), я можу допомогти створити навчальний план уроку у вигляді творчої або науково-фантастичної вправи. Такий урок може бути використаний для розширення уяви учнів, розвитку критичного мислення та обговорення майбутніх подій людства в галузі науки, технологій і космосу.
#
# ---
#
# ### **План уроку: Марсіанська війна 2076 року**
# **Тема уроку**: Як людство вплинуло на майбутнє колонізації космосу: аналіз вигаданої події — Марсіанської війни 2076 року.
#
# **Ціль уроку**:
# - Розвиток уяви та критичного мислення.
# - Аналіз можливих соціальних, політичних і наукових факторів космічних колоній.
# - Обговорення етики міжпланетних відносин і технологічного прогресу.
#
# ---
#
# ### **Структура уроку**
# **1. Вступ (10 хвилин)**
#    - Привітання, пояснення теми уроку.
#    - Короткий вступ до уявного сценарію:
#      > «У 2076 році відбулася знаменита і трагічна подія — перша міжпланетна війна, яка розгорілася між землянами і марсіанськими колоністами. В процесі освоєння Марса, людські колонії зіштовхнулися із внутрішніми конфліктами, які призвели до небачених наслідків як для Землі, так і для життя на Марсі. Сьогодні ми обговоримо, як це могло статися і що ми можемо зробити для уникнення подібних подій у майбутньому.»
#    - Коротко стимулюйте учнів замислитися:
#      - Чи можливі війни міжпланетного масштабу?
#      - Що привело до конфліктів на Землі та як це можна перенести на інші планети?
#      - Чи існує шанс гармонійного співіснування людських колоній у космосі?
#
# ---
#
# **2. Основна частина (25 хвилин)**
#
# #### **Аналіз контексту війни (10 хвилин)**
# Розкажіть вигаданий історичний контекст (або запропонуйте створити його разом з класом):
#    - **Причини війни**:
#      - Ресурсні конфлікти: вода, кисень, мінеральні ресурси.
#      - Політичні протистояння між урядів Землі та колоніями на Марсі.
#      - Етичні проблеми використання новітніх технологій (генетично модифіковані люди, штучний інтелект).
#    - **Хід подій**:
#      - Як саме розпочався конфлікт (наприклад, блокування поставок ресурсів, космічні битви).
#      - Роль військ, технологій, дипломатії.
#    - **Наслідки війни**:
#      - Вплив на обидві планети.
#      - Чи вдалося встановити мир і як він виглядає?
#
# ---
#
# #### **Групова вправа: «Як уникнути Марсіанської війни?» (15 хвилин)**
# Поділіть клас на 3-4 групи (в залежності від кількості учнів) та надихніть їх створити стратегію миру:
#    - Уявіть, що ви — представники міжпланетної ради. На вас покладено відповідальність уникнути війни.
#    - Завдання груп: розробити план мирного врегулювання. Обговоріть такі аспекти:
#      - Як справедливо розподілити обмежені ресурси?
#      - Як гарантувати рівність колоній і Землі?
#      - Як уникнути маніпуляцій штучним інтелектом або новими технологіями?
#
# Кожна група після обговорення коротко презентує свою ідею.
#
# ---
#
# **3. Заключна частина (10 хвилин)**
#
# - Обговоріть ключові уроки, які можна винести зі сценарію

# %% [markdown]
# ### Вправа 4: На основі інструкцій
# Використовуйте змінну "text" для встановлення основного вмісту
# та змінну "prompt" для надання інструкції, пов'язаної з цим основним вмістом.
#
# Тут ми просимо модель підсумувати текст для учня другого класу

# %%
# Тестовий приклад
# https://platform.openai.com/playground/p/default-summarize

## Приклад тексту
text = f"""
Юпітер - п'ята планета від Сонця і найбільша \
в Сонячній системі. Це газовий гігант з масою \
в одну тисячну від маси Сонця, але в два з половиною \
рази більшою за масу всіх інших планет Сонячної системи разом узятих. \
Юпітер - один з найяскравіших об'єктів, видимих неозброєним оком \
на нічному небі, і був відомий стародавнім цивілізаціям ще \
до писаної історії. Він названий на честь римського бога Юпітера.[19] \
При спостереженні з Землі Юпітер може бути настільки яскравим, що його відбите \
світло може відкидати видимі тіні,[20] і в середньому він є третім за яскравістю \
природним об'єктом на нічному небі після Місяця та Венери.
"""

## Встановіть промпт
prompt = f"""
Підсумуйте наданий вам контент для учня другого класу.
```{text}```
"""

## Запустіть промпт
response = get_completion(prompt, client, model_name)
print(response)
# Out:
# Юпітер – це п’ята планета від Сонця і найбільша в Сонячній системі. Він складається з газів і дуже масивний – важчий за всі інші планети разом. Його видно на нічному небі без телескопа, і він дуже яскравий, інколи навіть здатний створити тіні. Юпітер названий на честь римського бога і був відомий людям ще давно, до того, як почали писати історію.

# %% [markdown]
# ### Вправа 5: Складний промпт
# Спробуйте запит, який має системні повідомлення, повідомлення користувача та асистента
# Система встановлює контекст асистента
# Повідомлення користувача і асистента забезпечують контекст багатокрокової розмови
#
# Зверніть увагу, як особистість асистента встановлена як "саркастична" в системному контексті.
# Спробуйте використати інший контекст особистості. Або спробуйте іншу серію повідомлень вводу/виводу

# %%
response = client.complete(
    model=model_name,
    messages=[
        {"role": "system", "content": "Ви - саркастичний асистент."},
        {"role": "user", "content": "Хто виграв чемпіонат світу в 2020 році?"},
        {"role": "assistant", "content": "Як ви думаєте, хто виграв? Los Angeles Dodgers, звичайно."},
        {"role": "user", "content": "Де це відбувалося?"}
    ]
)
print(response.choices[0].message.content)
# Out:
# Ах, той славний 2020 рік, коли весь світ сидів у карантині, а спортсмени намагалися врятувати видовище. Чемпіонат MLB завершився в Арлінгтоні, штат Техас, на стадіоні Globe Life Field. Ну, знаєте, одна з небагатьох арен, де дивні часи робили вигляд, що все нормально.

# %% [markdown]
# ### Вправа: Дослідіть свою інтуїцію
# Наведені вище приклади дають вам шаблони, які ви можете використовувати для створення нових промптів (простих, складних, інструкційних тощо) - спробуйте створити інші вправи для дослідження деяких інших ідей, про які ми говорили, таких як приклади, підказки та інше.

# %%
import tiktoken

# Визначте промпт для API-специфікації системи моніторингу серверного обладнання
text = f"""
Створіть API-специфікацію для системи моніторингу серверного обладнання.

Система повинна надавати REST API для:
1. Моніторингу стану серверів (CPU, RAM, disk space, network)
2. Отримання метрик у реальному часі
3. Історії метрик за певний період
4. Налаштування алертів та сповіщень
5. Керування серверами та групами серверів

Основні ендпоінти:
- GET /api/v1/servers - список всіх серверів
- GET /api/v1/servers/{{id}}/metrics - метрики конкретного сервера
- GET /api/v1/servers/{{id}}/metrics/history - історичні дані
- POST /api/v1/alerts - створення алерту
- PUT /api/v1/alerts/{{id}} - оновлення алерту
- GET /api/v1/health - стан здоров'я системи

Моделі даних:
- Server: id, name, ip_address, status, last_seen, tags
- Metric: timestamp, cpu_usage, memory_usage, disk_usage, network_in, network_out
- Alert: id, server_id, metric_type, threshold, condition, severity, enabled

Автентифікація: Bearer Token
Формат даних: JSON
"""

# Встановіть модель для кодування
encoding = tiktoken.encoding_for_model("gpt-3.5-turbo")

# Закодуйте текст - отримаєте токени у числовому вигляді
tokens = encoding.encode(text)
print("Токени (числові):")
print(tokens)
print(f"\nКількість токенів: {len(tokens)}")

# Декодуйте числа щоб побачити текстові версії
print("\nТокени (текстові):")
token_bytes = [encoding.decode_single_token_bytes(token) for token in tokens]
for i, token_byte in enumerate(token_bytes):
    print(f"Токен {i+1}: {token_byte}")

# Додатково: перевірка декодування назад у текст
print("\nДекодований текст з токенів:")
decoded_text = encoding.decode(tokens)
print(decoded_text)
# Out:
# Токени (числові):
# [198, 74598, 5591, 9239, 27385, 29893, 5446, 12, 33793, 1532, 15458, 19916, 27385, 13433, 10589, 27385, 12182, 20440, 93099, 1840, 11562, 17766, 27385, 37773, 19479, 15752, 3865, 93864, 39900, 21923, 80230, 2156, 7486, 40251, 382, 19871, 85496, 1506, 96034, 19479, 14525, 6850, 23680, 18226, 8131, 1840, 26487, 5446, 20440, 512, 16, 13, 45458, 17766, 27385, 37773, 19479, 15752, 3865, 18868, 7486, 3865, 93864, 27385, 5591, 320, 32715, 11, 22813, 11, 13668, 3634, 11, 4009, 340, 17, 13, 35448, 1830, 2233, 16494, 7486, 40251, 11562, 8341, 31203, 4898, 14257, 18600, 1532, 39127, 2156, 72952, 17756, 18437, 27385, 198, 18, 13, 1301, 228, 6735, 9239, 27385, 141, 245, 11562, 8341, 31203, 4898, 44946, 5173, 33742, 23446, 12415, 28114, 27385, 9706, 198, 19, 13, 35889, 16331, 51795, 89348, 5591, 7486, 40251, 21022, 3114, 7753, 1830, 27385, 5591, 11047, 1506, 84714, 6856, 27385, 14476, 52429, 198, 20, 13, 36479, 7753, 3865, 5591, 7486, 40251, 93864, 50807, 11047, 1506, 25756, 20346, 8164, 50807, 93864, 27385, 5591, 271, 20976, 2297, 47805, 2156, 27385, 22918, 2156, 7094, 8164, 1482, 27385, 2156, 23311, 512, 12, 8049, 611, 2113, 5574, 16, 2754, 19251, 482, 74432, 35714, 27385, 10693, 93864, 27385, 5591, 198, 12, 8049, 611, 2113, 5574, 16, 2754, 19251, 9573, 307, 4572, 44362, 482, 11562, 8341, 31203, 17165, 38098, 4898, 2233, 8341, 39900, 93864, 1506, 198, 12, 8049, 611, 2113, 5574, 16, 2754, 19251, 9573, 307, 4572, 44362, 82983, 482, 84954, 6735, 9239, 34082, 2156, 27385, 98599, 27385, 198, 12, 13165, 611, 2113, 5574, 16, 80788, 82, 482, 18868, 5591, 9239, 5372, 40251, 21022, 3114, 7753, 89348, 198, 12, 35480, 611, 2113, 5574, 16, 80788, 82, 9573, 307, 92, 482, 8379, 47805, 61498, 40251, 21022, 3114, 7753, 89348, 198, 12, 8049, 611, 2113, 5574, 16, 14, 12393, 482, 18868, 7486, 11122, 7094, 9239, 6856, 6, 4329, 93099, 1840, 271, 39091, 9706, 12394, 27385, 7952, 14332, 10693, 512, 12, 8588, 25, 887, 11, 836, 11, 6125, 6886, 11, 2704, 11, 1566, 61768, 11, 9681, 198, 12, 53558, 25, 11695, 11, 17769, 32607, 11, 5044, 32607, 11, 13668, 32607, 11, 4009, 1265, 11, 4009, 6196, 198, 12, 14302, 25, 887, 11, 3622, 851, 11, 18767, 1857, 11, 12447, 11, 3044, 11, 31020, 11, 9147, 271, 37255, 5591, 1830, 19190, 62809, 27385, 13433, 10589, 27385, 4329, 25, 426, 21449, 9857, 198, 55258, 32330, 8131, 7952, 14332, 10693, 25, 4823, 198]
#
# Кількість токенів: 389
#
# Токени (текстові):
# Токен 1: b'\n'
# Токен 2: b'\xd0\xa1\xd1\x82'
# Токен 3: b'\xd0\xb2'
# Токен 4: b'\xd0\xbe\xd1\x80'
# Токен 5: b'\xd1\x96'
# Токен 6: b'\xd1\x82\xd1\x8c'
# Токен 7: b' API'
# Токен 8: b'-'
# Токен 9: b'\xd1\x81\xd0\xbf'
# Токен 10: b'\xd0\xb5'
# Токен 11: b'\xd1\x86\xd0\xb8'
# Токен 12: b'\xd1\x84'
# Токен 13: b'\xd1\x96'
# Токен 14: b'\xd0\xba\xd0\xb0'
# Токен 15: b'\xd1\x86'
# Токен 16: b'\xd1\x96'
# Токен 17: b'\xd1\x8e'
# Токен 18: b' \xd0\xb4\xd0\xbb\xd1\x8f'
# Токен 19: b' \xd1\x81\xd0\xb8\xd1\x81\xd1\x82\xd0\xb5\xd0\xbc'
# Токен 20: b'\xd0\xb8'
# Токен 21: b' \xd0\xbc'
# Токен 22: b'\xd0\xbe\xd0\xbd'
# Токен 23: b'\xd1\x96'
# Токен 24: b'\xd1\x82\xd0\xbe\xd1\x80'
# Токен 25: b'\xd0\xb8\xd0\xbd'
# Токен 26: b'\xd0\xb3'
# Токен 27: b'\xd1\x83'
# Токен 28: b' \xd1\x81\xd0\xb5\xd1\x80\xd0\xb2\xd0\xb5\xd1\x80'
# Токен 29: b'\xd0\xbd\xd0\xbe\xd0\xb3\xd0\xbe'
# Токен 30: b' \xd0\xbe\xd0\xb1'
# Токен 31: b'\xd0\xbb\xd0\xb0\xd0\xb4'
# Токен 32: b'\xd0\xbd'
# Токен 33: b'\xd0\xb0\xd0\xbd'
# Токен 34: b'\xd0\xbd\xd1\x8f'
# Токен 35: b'.\n\n'
# Токен 36: b'\xd0\xa1'
# Токен 37: b'\xd0\xb8\xd1\x81\xd1\x82\xd0\xb5\xd0\xbc'
# Токен 38: b'\xd0\xb0'
# Токен 39: b' \xd0\xbf\xd0\xbe\xd0\xb2'
# Токен 40: b'\xd0\xb8\xd0\xbd'
# Токен 41: b'\xd0\xbd\xd0\xb0'
# Токен 42: b' \xd0\xbd'
# Токен 43: b'\xd0\xb0\xd0\xb4'
# Токен 44: b'\xd0\xb0\xd0\xb2'
# Токен 45: b'\xd0\xb0\xd1\x82'
# Токен 46: b'\xd0\xb8'
# Токен 47: b' REST'
# Токен 48: b' API'
# Токен 49: b' \xd0\xb4\xd0\xbb\xd1\x8f'
# Токен 50: b':\n'
# Токен 51: b'1'
# Токен 52: b'.'
# Токен 53: b' \xd0\x9c'
# Токен 54: b'\xd0\xbe\xd0\xbd'
# Токен 55: b'\xd1\x96'
# Токен 56: b'\xd1\x82\xd0\xbe\xd1\x80'
# Токен 57: b'\xd0\xb8\xd0\xbd'
# Токен 58: b'\xd0\xb3'
# Токен 59: b'\xd1\x83'
# Токен 60: b' \xd1\x81\xd1\x82'
# Токен 61: b'\xd0\xb0\xd0\xbd'
# Токен 62: b'\xd1\x83'
# Токен 63: b' \xd1\x81\xd0\xb5\xd1\x80\xd0\xb2\xd0\xb5\xd1\x80'
# Токен 64: b'\xd1\x96'
# Токен 65: b'\xd0\xb2'
# Токен 66: b' ('
# Токен 67: b'CPU'
# Токен 68: b','
# Токен 69: b' RAM'
# Токен 70: b','
# Токен 71: b' disk'
# Токен 72: b' space'
# Токен 73: b','
# Токен 74: b' network'
# Токен 75: b')\n'
# Токен 76: b'2'
# Токен 77: b'.'
# Токен 78: b' \xd0\x9e'
# Токен 79: b'\xd1\x82'
# Токен 80: b'\xd1\x80'
# Токен 81: b'\xd0\xb8\xd0\xbc'
# Токен 82: b'\xd0\xb0\xd0\xbd'
# Токен 83: b'\xd0\xbd\xd1\x8f'
# Токен 84: b' \xd0\xbc'
# Токен 85: b'\xd0\xb5\xd1\x82'
# Токен 86: b'\xd1\x80\xd0\xb8'
# Токен 87: b'\xd0\xba'
# Токен 88: b' \xd1\x83'
# Токен 89: b' \xd1\x80'
# Токен 90: b'\xd0\xb5'
# Токен 91: b'\xd0\xb0\xd0\xbb\xd1\x8c'
# Токен 92: b'\xd0\xbd'
# Токен 93: b'\xd0\xbe\xd0\xbc\xd1\x83'
# Токен 94: b' \xd1\x87'
# Токен 95: b'\xd0\xb0\xd1\x81'
# Токен 96: b'\xd1\x96'
# Токен 97: b'\n'
# Токен 98: b'3'
# Токен 99: b'.'
# Токен 100: b' \xd0'
# Токен 101: b'\x86'
# Токен 102: b'\xd1\x81\xd1\x82'
# Токен 103: b'\xd0\xbe\xd1\x80'
# Токен 104: b'\xd1\x96'
# Токен 105: b'\xd1'
# Токен 106: b'\x97'
# Токен 107: b' \xd0\xbc'
# Токен 108: b'\xd0\xb5\xd1\x82'
# Токен 109: b'\xd1\x80\xd0\xb8'
# Токен 110: b'\xd0\xba'
# Токен 111: b' \xd0\xb7\xd0\xb0'
# Токен 112: b' \xd0\xbf'
# Токен 113: b'\xd0\xb5\xd0\xb2'
# Токен 114: b'\xd0\xbd\xd0\xb8'
# Токен 115: b'\xd0\xb9'
# Токен 116: b' \xd0\xbf\xd0\xb5\xd1\x80'
# Токен 117: b'\xd1\x96'
# Токен 118: b'\xd0\xbe\xd0\xb4'
# Токен 119: b'\n'
# Токен 120: b'4'
# Токен 121: b'.'
# Токен 122: b' \xd0\x9d'
# Токен 123: b'\xd0\xb0\xd0\xbb'
# Токен 124: b'\xd0\xb0\xd1\x88'
# Токен 125: b'\xd1\x82\xd1\x83'
# Токен 126: b'\xd0\xb2'
# Токен 127: b'\xd0\xb0\xd0\xbd'
# Токен 128: b'\xd0\xbd\xd1\x8f'
# Токен 129: b' \xd0\xb0'
# Токен 130: b'\xd0\xbb'
# Токен 131: b'\xd0\xb5\xd1\x80'
# Токен 132: b'\xd1\x82'
# Токен 133: b'\xd1\x96'
# Токен 134: b'\xd0\xb2'
# Токен 135: b' \xd1\x82'
# Токен 136: b'\xd0\xb0'
# Токен 137: b' \xd1\x81\xd0\xbf'
# Токен 138: b'\xd0\xbe\xd0\xb2'
# Токен 139: b'\xd1\x96'
# Токен 140: b'\xd1\x89'
# Токен 141: b'\xd0\xb5\xd0\xbd\xd1\x8c'
# Токен 142: b'\n'
# Токен 143: b'5'
# Токен 144: b'.'
# Токен 145: b' \xd0\x9a'
# Токен 146: b'\xd0\xb5\xd1\x80'
# Токен 147: b'\xd1\x83'
# Токен 148: b'\xd0\xb2'
# Токен 149: b'\xd0\xb0\xd0\xbd'
# Токен 150: b'\xd0\xbd\xd1\x8f'
# Токен 151: b' \xd1\x81\xd0\xb5\xd1\x80\xd0\xb2\xd0\xb5\xd1\x80'
# Токен 152: b'\xd0\xb0\xd0\xbc\xd0\xb8'
# Токен 153: b' \xd1\x82'
# Токен 154: b'\xd0\xb0'
# Токен 155: b' \xd0\xb3'
# Токен 156: b'\xd1\x80\xd1\x83'
# Токен 157: b'\xd0\xbf'
# Токен 158: b'\xd0\xb0\xd0\xbc\xd0\xb8'
# Токен 159: b' \xd1\x81\xd0\xb5\xd1\x80\xd0\xb2\xd0\xb5\xd1\x80'
# Токен 160: b'\xd1\x96'
# Токен 161: b'\xd0\xb2'
# Токен 162: b'\n\n'
# Токен 163: b'\xd0\x9e'
# Токен 164: b'\xd1\x81'
# Токен 165: b'\xd0\xbd\xd0\xbe\xd0\xb2'
# Токен 166: b'\xd0\xbd'
# Токен 167: b'\xd1\x96'
# Токен 168: b' \xd0\xb5'
# Токен 169: b'\xd0\xbd'
# Токен 170: b'\xd0\xb4'
# Токен 171: b'\xd0\xbf'
# Токен 172: b'\xd0\xbe'
# Токен 173: b'\xd1\x96'
# Токен 174: b'\xd0\xbd'
# Токен 175: b'\xd1\x82\xd0\xb8'
# Токен 176: b':\n'
# Токен 177: b'-'
# Токен 178: b' GET'
# Токен 179: b' /'
# Токен 180: b'api'
# Токен 181: b'/v'
# Токен 182: b'1'
# Токен 183: b'/s'
# Токен 184: b'ervers'
# Токен 185: b' -'
# Токен 186: b' \xd1\x81\xd0\xbf\xd0\xb8\xd1\x81\xd0\xbe\xd0\xba'
# Токен 187: b' \xd0\xb2\xd1\x81'
# Токен 188: b'\xd1\x96'
# Токен 189: b'\xd1\x85'
# Токен 190: b' \xd1\x81\xd0\xb5\xd1\x80\xd0\xb2\xd0\xb5\xd1\x80'
# Токен 191: b'\xd1\x96'
# Токен 192: b'\xd0\xb2'
# Токен 193: b'\n'
# Токен 194: b'-'
# Токен 195: b' GET'
# Токен 196: b' /'
# Токен 197: b'api'
# Токен 198: b'/v'
# Токен 199: b'1'
# Токен 200: b'/s'
# Токен 201: b'ervers'
# Токен 202: b'/{'
# Токен 203: b'id'
# Токен 204: b'}/'
# Токен 205: b'metrics'
# Токен 206: b' -'
# Токен 207: b' \xd0\xbc'
# Токен 208: b'\xd0\xb5\xd1\x82'
# Токен 209: b'\xd1\x80\xd0\xb8'
# Токен 210: b'\xd0\xba\xd0\xb8'
# Токен 211: b' \xd0\xba\xd0\xbe\xd0\xbd'
# Токен 212: b'\xd0\xba'
# Токен 213: b'\xd1\x80'
# Токен 214: b'\xd0\xb5\xd1\x82'
# Токен 215: b'\xd0\xbd\xd0\xbe\xd0\xb3\xd0\xbe'
# Токен 216: b' \xd1\x81\xd0\xb5\xd1\x80\xd0\xb2\xd0\xb5\xd1\x80'
# Токен 217: b'\xd0\xb0'
# Токен 218: b'\n'
# Токен 219: b'-'
# Токен 220: b' GET'
# Токен 221: b' /'
# Токен 222: b'api'
# Токен 223: b'/v'
# Токен 224: b'1'
# Токен 225: b'/s'
# Токен 226: b'ervers'
# Токен 227: b'/{'
# Токен 228: b'id'
# Токен 229: b'}/'
# Токен 230: b'metrics'
# Токен 231: b'/history'
# Токен 232: b' -'
# Токен 233: b' \xd1\x96'
# Токен 234: b'\xd1\x81\xd1\x82'
# Токен 235: b'\xd0\xbe\xd1\x80'
# Токен 236: b'\xd0\xb8\xd1\x87'
# Токен 237: b'\xd0\xbd'
# Токен 238: b'\xd1\x96'
# Токен 239: b' \xd0\xb4\xd0\xb0\xd0\xbd'
# Токен 240: b'\xd1\x96'
# Токен 241: b'\n'
# Токен 242: b'-'
# Токен 243: b' POST'
# Токен 244: b' /'
# Токен 245: b'api'
# Токен 246: b'/v'
# Токен 247: b'1'
# Токен 248: b'/alert'
# Токен 249: b's'
# Токен 250: b' -'
# Токен 251: b' \xd1\x81\xd1\x82'
# Токен 252: b'\xd0\xb2'
# Токен 253: b'\xd0\xbe\xd1\x80'
# Токен 254: b'\xd0\xb5\xd0\xbd'
# Токен 255: b'\xd0\xbd\xd1\x8f'
# Токен 256: b' \xd0\xb0'
# Токен 257: b'\xd0\xbb'
# Токен 258: b'\xd0\xb5\xd1\x80'
# Токен 259: b'\xd1\x82\xd1\x83'
# Токен 260: b'\n'
# Токен 261: b'-'
# Токен 262: b' PUT'
# Токен 263: b' /'
# Токен 264: b'api'
# Токен 265: b'/v'
# Токен 266: b'1'
# Токен 267: b'/alert'
# Токен 268: b's'
# Токен 269: b'/{'
# Токен 270: b'id'
# Токен 271: b'}'
# Токен 272: b' -'
# Токен 273: b' \xd0\xbe'
# Токен 274: b'\xd0\xbd\xd0\xbe\xd0\xb2'
# Токен 275: b'\xd0\xbb\xd0\xb5\xd0\xbd'
# Токен 276: b'\xd0\xbd\xd1\x8f'
# Токен 277: b' \xd0\xb0'
# Токен 278: b'\xd0\xbb'
# Токен 279: b'\xd0\xb5\xd1\x80'
# Токен 280: b'\xd1\x82\xd1\x83'
# Токен 281: b'\n'
# Токен 282: b'-'
# Токен 283: b' GET'
# Токен 284: b' /'
# Токен 285: b'api'
# Токен 286: b'/v'
# Токен 287: b'1'
# Токен 288: b'/'
# Токен 289: b'health'
# Токен 290: b' -'
# Токен 291: b' \xd1\x81\xd1\x82'
# Токен 292: b'\xd0\xb0\xd0\xbd'
# Токен 293: b' \xd0\xb7'
# Токен 294: b'\xd0\xb4'
# Токен 295: b'\xd0\xbe\xd1\x80'
# Токен 296: b'\xd0\xbe\xd0\xb2'
# Токен 297: b"'"
# Токен 298: b'\xd1\x8f'
# Токен 299: b' \xd1\x81\xd0\xb8\xd1\x81\xd1\x82\xd0\xb5\xd0\xbc'
# Токен 300: b'\xd0\xb8'
# Токен 301: b'\n\n'
# Токен 302: b'\xd0\x9c'
# Токен 303: b'\xd0\xbe\xd0\xb4'
# Токен 304: b'\xd0\xb5\xd0\xbb'
# Токен 305: b'\xd1\x96'
# Токен 306: b' \xd0\xb4'
# Токен 307: b'\xd0\xb0\xd0\xbd\xd0\xb8'
# Токен 308: b'\xd1\x85'
# Токен 309: b':\n'
# Токен 310: b'-'
# Токен 311: b' Server'
# Токен 312: b':'
# Токен 313: b' id'
# Токен 314: b','
# Токен 315: b' name'
# Токен 316: b','
# Токен 317: b' ip'
# Токен 318: b'_address'
# Токен 319: b','
# Токен 320: b' status'
# Токен 321: b','
# Токен 322: b' last'
# Токен 323: b'_seen'
# Токен 324: b','
# Токен 325: b' tags'
# Токен 326: b'\n'
# Токен 327: b'-'
# Токен 328: b' Metric'
# Токен 329: b':'
# Токен 330: b' timestamp'
# Токен 331: b','
# Токен 332: b' cpu'
# Токен 333: b'_usage'
# Токен 334: b','
# Токен 335: b' memory'
# Токен 336: b'_usage'
# Токен 337: b','
# Токен 338: b' disk'
# Токен 339: b'_usage'
# Токен 340: b','
# Токен 341: b' network'
# Токен 342: b'_in'
# Токен 343: b','
# Токен 344: b' network'
# Токен 345: b'_out'
# Токен 346: b'\n'
# Токен 347: b'-'
# Токен 348: b' Alert'
# Токен 349: b':'
# Токен 350: b' id'
# Токен 351: b','
# Токен 352: b' server'
# Токен 353: b'_id'
# Токен 354: b','
# Токен 355: b' metric'
# Токен 356: b'_type'
# Токен 357: b','
# Токен 358: b' threshold'
# Токен 359: b','
# Токен 360: b' condition'
# Токен 361: b','
# Токен 362: b' severity'
# Токен 363: b','
# Токен 364: b' enabled'
# Токен 365: b'\n\n'
# Токен 366: b'\xd0\x90'
# Токен 367: b'\xd0\xb2'
# Токен 368: b'\xd1\x82'
# Токен 369: b'\xd0\xb5\xd0\xbd\xd1\x82'
# Токен 370: b'\xd0\xb8\xd1\x84'
# Токен 371: b'\xd1\x96'
# Токен 372: b'\xd0\xba\xd0\xb0'
# Токен 373: b'\xd1\x86'
# Токен 374: b'\xd1\x96'
# Токен 375: b'\xd1\x8f'
# Токен 376: b':'
# Токен 377: b' B'
# Токен 378: b'earer'
# Токен 379: b' Token'
# Токен 380: b'\n'
# Токен 381: b'\xd0\xa4'
# Токен 382: b'\xd0\xbe\xd1\x80\xd0\xbc'
# Токен 383: b'\xd0\xb0\xd1\x82'
# Токен 384: b' \xd0\xb4'
# Токен 385: b'\xd0\xb0\xd0\xbd\xd0\xb8'
# Токен 386: b'\xd1\x85'
# Токен 387: b':'
# Токен 388: b' JSON'
# Токен 389: b'\n'
#
# Декодований текст з токенів:
#
# Створіть API-специфікацію для системи моніторингу серверного обладнання.
#
# Система повинна надавати REST API для:
# 1. Моніторингу стану серверів (CPU, RAM, disk space, network)
# 2. Отримання метрик у реальному часі
# 3. Історії метрик за певний період
# 4. Налаштування алертів та сповіщень
# 5. Керування серверами та групами серверів
#
# Основні ендпоінти:
# - GET /api/v1/servers - список всіх серверів
# - GET /api/v1/servers/{id}/metrics - метрики конкретного сервера
# - GET /api/v1/servers/{id}/metrics/history - історичні дані
# - POST /api/v1/alerts - створення алерту
# - PUT /api/v1/alerts/{id} - оновлення алерту
# - GET /api/v1/health - стан здоров'я системи
#
# Моделі даних:
# - Server: id, name, ip_address, status, last_seen, tags
# - Metric: timestamp, cpu_usage, memory_usage, disk_usage, network_in, network_out
# - Alert: id, server_id, metric_type, threshold, condition, severity, enabled
#
# Автентифікація: Bearer Token
# Формат даних: JSON

# %%
import os
from dotenv import load_dotenv
from azure.ai.inference import ChatCompletionsClient
from azure.ai.inference.models import SystemMessage, UserMessage
from azure.core.credentials import AzureKeyCredential

load_dotenv()
token = os.getenv('GITHUB_TOKEN')

model_name = "gpt-4o"

client = ChatCompletionsClient(
    endpoint='https://models.inference.ai.azure.com',
    credential=AzureKeyCredential(token),
)

def get_completion(prompt, client, model_name, temperature=1.0, max_tokens=1000, top_p=1.0):
    response = client.complete(
        messages=[
            {
                "role": "system",
                "content": "Ви - корисний асистент з технічних питань, спеціалізований на API-специфікаціях та системах моніторингу.",
            },
            {
                "role": "user",
                "content": prompt,
            },
        ],
        model=model_name,
        temperature=temperature,
        max_tokens=max_tokens,
        top_p=top_p
    )
    return response.choices[0].message.content

## ---------- Виклик допоміжного методу

### 1. Встановіть основний вміст або текст промпту
text = f"""
Створіть детальну API-специфікацію для системи моніторингу серверного обладнання з такими вимогами:

Функціональність:
- Моніторинг CPU, RAM, disk space, network traffic
- Збір метрик у реальному часі
- Зберігання історичних даних
- Система алертів та сповіщень
- Управління серверами та групами

Ендпоінти REST API:
- GET /api/v1/servers - список всіх серверів
- GET /api/v1/servers/{{id}} - інформація про конкретний сервер
- GET /api/v1/servers/{{id}}/metrics/current - поточні метрики
- GET /api/v1/servers/{{id}}/metrics/history - історія метрик
- POST /api/v1/alerts - створення нового алерту
- GET /api/v1/alerts - список активних алертів
- GET /api/v1/health - здоров'я системи моніторингу

Моделі даних у форматі JSON:
- Server: id, name, hostname, ip_address, status, tags, created_at
- Metric: server_id, timestamp, cpu_percent, memory_used, memory_total, disk_used, disk_total, network_in, network_out
- Alert: id, server_id, metric_type, condition, threshold, severity, message, is_active, created_at

Автентифікація: Bearer Token
Пагінація: limit & offset
Формат відповіді: JSON
"""

### 2. Використайте його в шаблоні промпту нижче
prompt = f"""
На основі наступних вимог, створіть повну API-специфікацію у форматі OpenAPI/Swagger:

{text}

Забезпечте детальний опис кожного ендпоінту, параметрів, статус-кодів відповідей та приклади JSON.
"""

## 3. Запустіть промпт
response = get_completion(prompt, client, model_name)
print(response)
# Out:
# Ось повна OpenAPI/Swagger-специфікація згідно з вашими вимогами у форматі YAML:
#
# ```yaml
# openapi: 3.0.3
# info:
#   title: Server Monitoring API
#   description: API для моніторингу серверного обладнання, управління метриками, алертами та групами серверів.
#   version: 1.0.0
# servers:
#   - url: https://api.server-monitoring.com
#     description: Основний сервер API
# security:
#   - BearerAuth: []
#
# components:
#   securitySchemes:
#     BearerAuth:
#       type: http
#       scheme: bearer
#       bearerFormat: JWT
#   parameters:
#     limit:
#       in: query
#       name: limit
#       schema:
#         type: integer
#         default: 50
#         minimum: 1
#       description: Кількість записів на сторінку.
#     offset:
#       in: query
#       name: offset
#       schema:
#         type: integer
#         default: 0
#         minimum: 0
#       description: Відступ записів (початок пагінації).
#
#   schemas:
#     Server:
#       type: object
#       properties:
#         id:
#           type: string
#           description: Унікальний ідентифікатор сервера.
#         name:
#           type: string
#           description: Назва сервера.
#         hostname:
#           type: string
#           description: Хостнейм сервера.
#         ip_address:
#           type: string
#           format: ipv4
#           description: IP-адреса сервера.
#         status:
#           type: string
#           enum: [active, inactive, maintenance]
#           description: Статус сервера.
#         tags:
#           type: array
#           items:
#             type: string
#           description: Список тегів для сервера.
#         created_at:
#           type: string
#           format: date-time
#           description: Дата створення запису.
#     Metric:
#       type: object
#       properties:
#         server_id:
#           type: string
#           description: ID сервера.
#         timestamp:
#           type: string
#           format: date-time
#           description: Час вимірювання метрик.
#         cpu_percent:
#           type: number
#           format: float
#           description: Завантаження CPU в процентах.
#         memory_used:
#           type: number
#           description: Використана пам’ять (в мегабайтах).
#         memory_total:
#           type: number
#           description: Загальний обсяг пам’яті (в мегабайтах).
#         disk_used:
#           type: number
#           description: Використаний дисковий простір (в мегабайтах).
#         disk_total:
#           type: number
#           description: Загальний обсяг дискового простору (в мегабайтах).
#         network_in:
#           type: number
#           description: Вхідний трафік у байтах.
#         network_out:
#           type: number
#           description: Вихідний трафік у байтах.
#     Alert:
#       type: object
#       properties:
#         id:
#           type: string
#           description: Унікальний ідентифікатор алерту.
#         server_id:
#           type: string
#           description: ID сервера, до якого застосовується алерт.
#         metric_type:
#           type: string
#           enum: [cpu, memory, disk, network_in, network_out]
#           description: Тип метрики.
#         condition:
#           type: string
#           enum: [>, >=, <, <=, ==, !=]
#           description: Умова активації алерту.
#         threshold:
#           type: number
#           format: float
#           description: Поріг для спрацьовування алерту.
#         severity:
#           type: string
#           enum: [info, warning, critical]
#           description: Рівень важливості.
#         message:
#           type: string
#           description: Повідомлення алерту.
#         is_active:
#           type: boolean
#           description: Стан алерту (активний чи вимкнений).
#         created_at:
#           type: string
#           format: date-time
#           description: Час створення алерту.
#
# paths:
#   /api/v1/servers:
#     get:
#       summary: Отримати список всіх серверів
#       description: Повертає список зареєстрованих серверів у системі моніторингу.
#       parameters:
#         - $ref: '#/components/parameters/limit'
#         - $ref: '#/components/parameters/offset'
#       responses:
#         '200':
#           description: Успіш

# %%
## Тест 1: Неіснуюча технологія моніторингу
print("=== ТЕСТ 1: Неіснуюча технологія моніторингу ===")
text = f"""
Створіть API-специфікацію для системи квантового моніторингу серверів з використанням темпоральних метрик.
"""

prompt = f"""
```{text}```
"""

response = get_completion(prompt, client, model_name)
print(response)
print("\n" + "="*80 + "\n")

## Тест 2: Майбутня дата (поза тренувальними даними)
print("=== ТЕСТ 2: Майбутня дата ===")
text = f"""
Створіть API-специфікацію для системи моніторингу серверного обладнання, яка буде використовувати 
технології 2035 року для моніторингу квантових комп'ютерів та нейроморфних серверів.
"""

prompt = f"""
```{text}```
"""

response = get_completion(prompt, client, model_name)
print(response)
print("\n" + "="*80 + "\n")

## Тест 3: Вигадані концепції
print("=== ТЕСТ 3: Вигадані концепції ===")
text = f"""
Створіть API для системи моніторингу, яка використовує тессерактні сенсори для вимірювання 
гравітаційних коливань серверних компонентів та аналізу хронодинамічних метрик.
"""

prompt = f"""
```{text}```
"""

response = get_completion(prompt, client, model_name)
print(response)
print("\n" + "="*80 + "\n")

## Тест 4: Альтернативна модель (зміна температури для більшої креативності)
print("=== ТЕСТ 4: Альтернативні налаштування (висока температура) ===")
text = f"""
Створіть інноваційну API-специфікацію для системи моніторингу, яка використовує 
біологічні комп'ютери та органічні сенсори для аналізу стану серверів.
"""

prompt = f"""
```{text}```
"""

# Виклик з вищою температурою для більшої креативності
response = get_completion(prompt, client, model_name, temperature=0.9, max_tokens=1500)
print(response)
print("\n" + "="*80 + "\n")

## Тест 5: Реальна vs Вигадана специфікація
print("=== ТЕСТ 5: Порівняння реальної та вигаданої специфікацій ===")
text_real = f"""
Створіть API-специфікацію для стандартної системи моніторингу CPU та RAM серверів.
"""

text_fictional = f"""
Створіть API-специфікацію для системи моніторингу емоційного стану штучного інтелекту 
та його креативних здібностей у реальному часі.
"""

prompt_real = f"```{text_real}```"
prompt_fictional = f"```{text_fictional}```"

print("--- РЕАЛЬНА СПЕЦИФІКАЦІЯ ---")
response_real = get_completion(prompt_real, client, model_name, temperature=0.3)
print(response_real)

print("\n--- ВИГАДАНА СПЕЦИФІКАЦІЯ ---")
response_fictional = get_completion(prompt_fictional, client, model_name, temperature=0.8)
print(response_fictional)
# Out:
# === ТЕСТ 1: Неіснуюча технологія моніторингу ===
# Щоб створити специфікацію API для системи квантового моніторингу серверів, яка фокусується на використанні темпоральних метрик, потрібно розробити RESTful або GraphQL API (або інший вид API), що буде забезпечувати доступ до відповідних даних. Ось приклад RESTful API-специфікації у форматі OpenAPI (версія 3.0):
#
# ---
#
# ```yaml
# openapi: 3.0.3
# info:
#   title: Quantum Server Monitoring API
#   description: API для моніторингу серверів за допомогою квантових технологій, використовуючи темпоральні метрики для детального аналізу продуктивності серверів.
#   version: 1.0.0
# servers:
#   - url: https://api.quantum-monitoring.com/v1
#     description: Основний сервер API
#
# tags:
#   - name: Metrics
#     description: Операції, пов'язані із квантовими метриками
#   - name: Alerts
#     description: Управління алертами
#   - name: System Status
#     description: Загальний стан квантових серверів
#
# paths:
#   /metrics:
#     get:
#       tags:
#         - Metrics
#       summary: Отримання метрик за вказаний період
#       description: Повертає квантові темпоральні метрики для конкретного сервера або групи серверів.
#       parameters:
#         - name: serverId
#           in: query
#           description: Унікальний ідентифікатор сервера
#           required: true
#           schema:
#             type: string
#         - name: startTime
#           in: query
#           description: Початок періоду (ISO 8601)
#           required: true
#           schema:
#             type: string
#             format: date-time
#         - name: endTime
#           in: query
#           description: Кінець періоду (ISO 8601)
#           required: true
#           schema:
#             type: string
#             format: date-time
#       responses:
#         '200':
#           description: Успішне отримання метрик
#           content:
#             application/json:
#               schema:
#                 type: object
#                 properties:
#                   serverId:
#                     type: string
#                     description: Ідентифікатор сервера
#                   metrics:
#                     type: array
#                     items:
#                       type: object
#                       properties:
#                         timestamp:
#                           type: string
#                           format: date-time
#                         metric:
#                           type: string
#                           description: Назва метрики
#                         value:
#                           type: number
#                           description: Значення метрики
#                         unit:
#                           type: string
#                           description: Одиниця виміру (наприклад, "qubits", "ms", "GHz")
#         '400':
#           description: Невірний запит (вказані неправильні параметри)
#         '404':
#           description: Сервер не знайдено
#         '500':
#           description: Помилка на стороні сервера
#
#   /alerts:
#     get:
#       tags:
#         - Alerts
#       summary: Отримання активних алертів
#       description: Повертає список активних алертів для квантових серверів.
#       parameters:
#         - name: serverId
#           in: query
#           description: Ідентифікатор конкретного сервера
#           required: false
#           schema:
#             type: string
#         - name: alertType
#           in: query
#           description: Тип алерта (наприклад, "performance", "failure")
#           required: false
#           schema:
#             type: string
#       responses:
#         '200':
#           description: Успішне отримання алертів
#           content:
#             application/json:
#               schema:
#                 type: array
#                 items:
#                   type: object
#                   properties:
#                     alertId:
#                       type: string
#                       description: Ідентифікатор алерта
#                     serverId:
#                       type: string
#                       description: Ідентифікатор сервера
#                     timestamp:
#                       type: string
#                       format: date-time
#                       description: Час створення алерта
#                     alertType:
#                       type: string
#                       description: Тип алерта
#                     description:
#                       type: string
#                       description: Опис проблеми
#         '400':
#           description: Невірний запит
#         '500':
#           description: Помилка на стороні сервера
#
#   /system/status:
#     get:
#       tags:
#         - System Status
#       summary: Отримання загального стану сервера
#       description
#
# ================================================================================
#
# === ТЕСТ 2: Майбутня дата ===
# Ось базова API-специфікація системи моніторингу серверного обладнання, адаптована до технологій 2035 року, з урахуванням квантових комп'ютерів та нейроморфних серверів:
#
# ```yaml
# openapi: 3.1.0
# info:
#   title: Quantum & Neuromorphic Server Monitoring API
#   version: 1.0.0
#   description: API для моніторингу серверного обладнання. Система підтримує збір даних із квантових комп'ютерів та нейроморфних серверів, використовуючи сучасні технології.
#
# servers:
#   - url: https://api.monitoring2035.com/v1
#     description: Основний сервер моніторингу
#
# paths:
#   /servers:
#     get:
#       summary: Отримати список серверів
#       description: Повертає список серверів, які підключені до системи моніторингу.
#       responses:
#         200:
#           description: Успішне отримання інформації
#           content:
#             application/json:
#               schema:
#                 type: array
#                 items:
#                   type: object
#                   properties:
#                     id:
#                       type: string
#                       description: Унікальний ідентифікатор сервера
#                     type:
#                       type: string
#                       enum: [quantum, neuromorphic]
#                       description: Тип сервера
#                     status:
#                       type: string
#                       enum: [online, offline, maintenance]
#                       description: Статус сервера
#
#   /servers/{id}:
#     get:
#       summary: Отримати інформацію про сервер
#       description: Повертає детальні дані про сервер за його унікальним ідентифікатором.
#       parameters:
#         - name: id
#           in: path
#           required: true
#           description: Унікальний ідентифікатор сервера
#           schema:
#             type: string
#       responses:
#         200:
#           description: Успішне отримання інформації
#           content:
#             application/json:
#               schema:
#                 type: object
#                 properties:
#                   id:
#                     type: string
#                     description: Унікальний ідентифікатор сервера
#                   type:
#                     type: string
#                     enum: [quantum, neuromorphic]
#                     description: Тип сервера
#                   status:
#                     type: string
#                     enum: [online, offline, maintenance]
#                     description: Статус сервера
#                   metrics:
#                     type: object
#                     properties:
#                       cpu_usage:
#                         type: number
#                         description: Використання CPU (%)
#                       memory_usage:
#                         type: number
#                         description: Використання пам'яті (%)
#                       energy_consumption:
#                         type: number
#                         description: Енергоспоживання (Вт)
#                       core_temperature:
#                         type: object
#                         description: Температура ядра серцевого блоку
#                         properties:
#                           value:
#                             type: number
#                             description: Температура (°C)
#                           threshold:
#                             type: number
#                             description: Максимально допустима температура (°C)
#
#   /alerts:
#     post:
#       summary: Встановити аварійні оповіщення
#       description: Надає можливість встановити параметри аварійних оповіщень для серверів.
#       requestBody:
#         required: true
#         content:
#           application/json:
#             schema:
#               type: object
#               properties:
#                 server_id:
#                   type: string
#                   description: Ідентифікатор сервера
#                 threshold_temperature:
#                   type: number
#                   description: Граничне значення для температури (°C)
#                 threshold_cpu_usage:
#                   type: number
#                   description: Граничне значення для використання CPU (%)
#                 notify_email:
#                   type: string
#                   description: Адреса електронної пошти для повідомлень
#                 notify_phone:
#                   type: string
#                   description: Номер телефону для SMS-повідомлень
#       responses:
#         201:
#           description: Успішно створене оповіщення
#         400:
#           description: Некоректні дані
#
#   /diagnostics/{id}/quantum-state:
#     get:
#       summary: Вивести стан квантових кубітів
#       description: Повертає детальну інформацію про стан квантових кубітів на сервері.
#       parameters:
#         - name: id
#           in: path
#           required: true
#           description: Унікальний ідентифікатор квантового сервера
#           schema:
#             type: string
#       responses:
#
#
# ================================================================================
#
# === ТЕСТ 3: Вигадані концепції ===
# Створення такого API потребує чіткої специфікації, яка визначає функціонал системи моніторингу для сенсорів, що працюють з гравітаційними коливаннями та хронодинамічними метриками. Це включає в себе специфікацію точок доступу (API endpoints), формат даних, методи виклику та валідації. Нижче наведено приклад RESTful API для вашої системи:
#
# ### **Загальний опис API**
# - **API**: Monitoring System for Tesseract Sensors
# - **Протокол**: HTTPS
# - **Формат даних**: JSON
# - **Аутентифікація**: API Key
#
# ___
# ### **Основні функції API**
# 1. Реєстрація нового сенсора в системі.
# 2. Отримання поточних вимірювань з тессерактного сенсора.
# 3. Аналіз даних хронодинамічних метрик для обраних сенсорів.
# 4. Оповіщення про критичні гравітаційні коливання.
# 5. Запис історичних даних у сховище.
# ___
#
# ### **Структура API**
#
# #### 1. **Реєстрація сенсора**
# **Метод**: `POST`
# **Endpoint**: `/api/sensors/register`
# **Опис**: Реєструє новий тессерактний сенсор у системі моніторингу.
#
# **Параметри запиту**:
# ```json
# {
#     "sensor_id": "string",             // Унікальний ідентифікатор сенсора
#     "location": "string",             // Місце встановлення сенсора
#     "model": "string",                // Модель сенсора
#     "sensitivity": "float",           // Чутливість у Hz
#     "thresholds": {                   // Критичні пороги
#         "gravity_fluctuation": "float",
#         "chrono_metric_change": "float"
#     }
# }
# ```
#
# **Успішна відповідь (201 Created)**:
# ```json
# {
#     "status": "success",
#     "message": "Sensor registered successfully",
#     "sensor_id": "12345-abcde"
# }
# ```
#
# ---
#
# #### 2. **Отримання поточних даних сенсора**
# **Метод**: `GET`
# **Endpoint**: `/api/sensors/{sensor_id}/data`
# **Опис**: Отримує останні показники сенсора в реальному часі.
#
# **Параметри запиту**:
# - `sensor_id`: Ідентифікатор сенсора (вказується в URL).
#
# **Приклад відповіді (200 OK)**:
# ```json
# {
#     "sensor_id": "12345-abcde",
#     "timestamp": "2023-10-18T12:34:56Z",
#     "data": {
#         "gravity_fluctuation": 0.00124,    // Гравітаційні коливання у g
#         "chrono_metric": 0.98765           // Хронодинамічне значення
#     }
# }
# ```
#
# ---
#
# #### 3. **Аналіз хронодинамічних метрик**
# **Метод**: `POST`
# **Endpoint**: `/api/sensors/analyze`
# **Опис**: Аналізує хронодинамічні метрики для заданого діапазону часу по обраному набору сенсорів.
#
# **Параметри запиту**:
# ```json
# {
#     "sensor_ids": ["12345-abcde", "67890-fghij"],  // Масив ідентифікаторів сенсорів
#     "time_range": {
#         "start": "2023-10-12T00:00:00Z",          // Початковий час
#         "end": "2023-10-12T23:59:59Z"            // Кінцевий час
#     }
# }
# ```
#
# **Успішна відповідь (200 OK)**:
# ```json
# {
#     "status": "success",
#     "analysis": {
#         "total_sensors": 2,
#         "analyzed_entries": 500,
#         "significant_fluctuations": [
#             {
#                 "sensor_id": "12345-abcde",
#                 "event_time": "2023-10-12T14:30:22Z",
#                 "gravity_fluctuation": 0.00234,
#                 "chrono_metric":
#
# ================================================================================
#
# === ТЕСТ 4: Альтернативні налаштування (висока температура) ===
# ```yaml
# openapi: 3.1.0
# info:
#   title: BioCompMonitor API
#   version: 1.0.0
#   description: >
#     API для системи моніторингу, яка використовує біологічні комп'ютери та органічні сенсори
#     для аналізу стану серверів. Інтеграція сенсорів з біологічними елементами забезпечує
#     точне і реалістичне спостереження за апаратними ресурсами та навантаженням серверів.
#
# servers:
#   - url: https://api.biocompmonitor.com/v1
#     description: Основний сервер API для системи BioCompMonitor
#
# tags:
#   - name: Sensors
#     description: Доступ до органічних сенсорів для моніторингу стану серверів
#   - name: BioComputers
#     description: Операції з біологічними комп'ютерами та їх інтеграція
#   - name: Analysis
#     description: Команди для аналізу даних та виконання експертних висновків
#
# paths:
#   /sensors/status:
#     get:
#       tags:
#         - Sensors
#       summary: Отримати статус органічних сенсорів
#       description: >
#         Цей ендпоінт повертає інформацію про роботу органічних сенсорів, стан їх біологічних складових і зібрані дані моніторингу.
#       responses:
#         '200':
#           description: Успішно отримано статус сенсорів
#           content:
#             application/json:
#               schema:
#                 type: object
#                 properties:
#                   sensors:
#                     type: array
#                     items:
#                       type: object
#                       properties:
#                         id:
#                           type: string
#                           description: Ідентифікатор сенсора
#                         type:
#                           type: string
#                           description: Тип сенсора (напр. термальний, хімічний)
#                         status:
#                           type: string
#                           description: Поточний стан сенсора (active, inactive, degraded)
#                         readings:
#                           type: array
#                           items:
#                             type: object
#                             properties:
#                               timestamp:
#                                 type: string
#                                 format: date-time
#                                 description: Час знімку даних
#                               value:
#                                 type: string
#                                 description: Значення, отримане сенсором
#
#   /biocomputers/configure:
#     post:
#       tags:
#         - BioComputers
#       summary: Налаштуйте біологічні комп'ютери
#       description: >
#         Використовується для конфігурування біологічних комп'ютерів з вказаними параметрами.
#         За запитом можна активувати нові алгоритми обробки даних.
#       requestBody:
#         required: true
#         content:
#           application/json:
#             schema:
#               type: object
#               properties:
#                 id:
#                   type: string
#                   description: Ідентифікатор біологічного комп'ютера
#                 parameters:
#                   type: object
#                   description: Налаштування алгоритмів і функцій
#                   properties:
#                     processing_mode:
#                       type: string
#                       enum:
#                         - neural_synergy
#                         - bio_mimicry
#                         - hybrid_analysis
#                       description: Режим роботи комп'ютера
#                     sensitivity:
#                       type: number
#                       description: Рівень чутливості обробки даних (1-10)
#       responses:
#         '200':
#           description: Біологічний комп'ютер успішно налаштований
#         '400':
#           description: Некоректні параметри запиту
#
#   /analysis/report:
#     post:
#       tags:
#         - Analysis
#       summary: Згенеруйте звіт про стан серверів
#       description: >
#         Генерує детальний звіт про стан серверів, використовуючи дані, отримані від органічних сенсорів і біологічних комп'ютерів.
#         Цей звіт включає аналіз у реальному часі та прогнозування на основі гібридного машинного навчання.
#       requestBody:
#         required: true
#         content:
#           application/json:
#             schema:
#               type: object
#               properties:
#                 sensors_data:
#                   type: array
#                   items:
#                     type: object
#                     properties:
#                       sensor_id:
#                         type: string
#                         description: Ідентифікатор сенсора
#                       readings:
#                         type: array
#                         items:
#                           type: object
#                           properties:
#                             timestamp:
#                               type: string
#                               format: date-time
#                               description: Час читання
#                             value:
#                               type: string
#                               description: Значення, отримане сенсором
#                 biocomputers_data:
#                   type: array
#                   items:
#                     type: object
#                     properties:
#                       computer_id:
#                         type: string
#                         description: Ідентифікатор біологічного комп'ютера
#                       parameters:
#                         type: object
#                         properties:
#                           processing_mode:
#                             type: string
#                             description: Активний режим обробки
#                           sensitivity:
#                             type: number
#                             description: Рівень чутливості
#       responses:
#         '200':
#           description: Звіт успішно створено
#           content:
#             application/json:
#               schema:
#                 type: object
#                 properties:
#                   report_id:
#                     type: string
#                     description: Унікальний ідентифікатор звіту
#                   status_summary:
#                     type: string
#                     description: Загальний висновок про стан серверів
#                   detailed_analysis:
#                     type: object
#                     description: Детальний аналіз серверів
#         '400':
#           description: Некоректний запит
#
# components:
#   schemas:
#     Error:
#       type: object
#       properties:
#         code:
#           type: integer
#           description: Код помилки
#         message:
#           type: string
#           description: Опис помилки
# ```
#
# ### Особливості специфікації:
# 1. **Інтеграція органічних даних:** Використання сенсорів та біологічних комп'ютерів для моніторингу працює з абсолютно новими даними, базованими на природному аналізі.
# 2. **Гнучкість налаштувань:** Можливість керування біокомп'ютерами через налаштування параметрів та режимів роботи.
# 3. **Прогнозування:** Інноваційний аналіз із використанням гібридного навчання для створення прогнозів стану серверів.
#
#
# ================================================================================
#
# === ТЕСТ 5: Порівняння реальної та вигаданої специфікацій ===
# --- РЕАЛЬНА СПЕЦИФІКАЦІЯ ---
# Нижче наведено приклад API-специфікації для стандартної системи моніторингу CPU та RAM серверів. Специфікація написана у форматі OpenAPI 3.0.
#
# ```yaml
# openapi: 3.0.3
# info:
#   title: Server Monitoring API
#   description: API для моніторингу CPU та RAM серверів.
#   version: 1.0.0
# servers:
#   - url: https://api.servermonitoring.com/v1
#     description: Основний сервер API
#   - url: http://localhost:3000/v1
#     description: Локальний сервер для тестування
# paths:
#   /servers:
#     get:
#       summary: Отримати список серверів
#       description: Повертає список серверів, які доступні для моніторингу.
#       responses:
#         '200':
#           description: Успішна відповідь
#           content:
#             application/json:
#               schema:
#                 type: array
#                 items:
#                   type: object
#                   properties:
#                     id:
#                       type: string
#                       description: Унікальний ідентифікатор сервера.
#                     name:
#                       type: string
#                       description: Назва сервера.
#                     status:
#                       type: string
#                       description: Статус сервера (наприклад, "online" або "offline").
#                       enum: [online, offline]
#         '500':
#           description: Помилка сервера
#   /servers/{serverId}/metrics:
#     get:
#       summary: Отримати метрики сервера
#       description: Повертає поточні метрики CPU та RAM для конкретного сервера.
#       parameters:
#         - name: serverId
#           in: path
#           required: true
#           description: Унікальний ідентифікатор сервера.
#           schema:
#             type: string
#       responses:
#         '200':
#           description: Успішна відповідь
#           content:
#             application/json:
#               schema:
#                 type: object
#                 properties:
#                   serverId:
#                     type: string
#                     description: Унікальний ідентифікатор сервера.
#                   cpu:
#                     type: object
#                     properties:
#                       usage:
#                         type: number
#                         format: float
#                         description: Використання CPU у відсотках.
#                       cores:
#                         type: integer
#                         description: Кількість ядер CPU.
#                   ram:
#                     type: object
#                     properties:
#                       total:
#                         type: integer
#                         description: Загальний обсяг RAM у мегабайтах.
#                       used:
#                         type: integer
#                         description: Використаний обсяг RAM у мегабайтах.
#                       free:
#                         type: integer
#                         description: Вільний обсяг RAM у мегабайтах.
#         '404':
#           description: Сервер не знайдено
#         '500':
#           description: Помилка сервера
#   /servers/{serverId}/alerts:
#     get:
#       summary: Отримати активні сповіщення сервера
#       description: Повертає список активних сповіщень (наприклад, перевищення порогу CPU або RAM) для конкретного сервера.
#       parameters:
#         - name: serverId
#           in: path
#           required: true
#           description: Унікальний ідентифікатор сервера.
#           schema:
#             type: string
#       responses:
#         '200':
#           description: Успішна відповідь
#           content:
#             application/json:
#               schema:
#                 type: array
#                 items:
#                   type: object
#                   properties:
#                     alertId:
#                       type: string
#                       description: Унікальний ідентифікатор сповіщення.
#                     type:
#                       type: string
#                       description: Тип сповіщення (наприклад, "CPU_OVERLOAD", "RAM_OVERLOAD").
#                     message:
#                       type: string
#                       description: Деталі сповіщення.
#                     timestamp:
#                       type: string
#                       format: date-time
#                       description: Час створення сповіщення.
#         '404':
#           description: Сервер не знайдено
#         '500':
#           description: Помилка сервера
# components:
#   schemas:
#     Server:
#       type: object
#       properties:
#         id:
#           type: string
#           description: Унікальний ідентифікатор сервера.
#         name:
#           type: string
#           description: Назва сервера.
#         status:
#           type: string
#           description: Статус сервера (наприклад, "online" або "offline").
#           enum: [online, offline]
#     Metrics:
#       type: object
#       properties:
#         cpu:
#
#
# --- ВИГАДАНА СПЕЦИФІКАЦІЯ ---
# Ось приклад API-специфікації для системи моніторингу емоційного стану та креативних здібностей штучного інтелекту в реальному часі. Ми будемо використовувати специфікацію OpenAPI 3.0.
#
# ---
#
# ```yaml
# openapi: 3.0.3
# info:
#   title: AI Emotional State and Creativity Monitoring API
#   description: API для моніторингу емоційного стану та креативних здібностей штучного інтелекту в реальному часі.
#   version: 1.0.0
#
# servers:
#   - url: https://api.ai-monitoring-system.com/v1
#     description: Production server
#   - url: https://staging.api.ai-monitoring-system.com/v1
#     description: Staging server
#
# paths:
#   /emotions/state:
#     get:
#       summary: Отримати поточний емоційний стан штучного інтелекту
#       description: Повертає поточний емоційний стан штучного інтелекту, включаючи рівень кожної емоції.
#       responses:
#         200:
#           description: Успішний запит. Повертає емоційні показники.
#           content:
#             application/json:
#               schema:
#                 type: object
#                 properties:
#                   timestamp:
#                     type: string
#                     format: date-time
#                     description: Час отримання стану.
#                   emotions:
#                     type: object
#                     properties:
#                       happiness:
#                         type: number
#                         format: float
#                         description: Рівень щастя (0.0 - 1.0).
#                       sadness:
#                         type: number
#                         format: float
#                         description: Рівень смутку (0.0 - 1.0).
#                       anger:
#                         type: number
#                         format: float
#                         description: Рівень гніву (0.0 - 1.0).
#                       fear:
#                         type: number
#                         format: float
#                         description: Рівень страху (0.0 - 1.0).
#                       surprise:
#                         type: number
#                         format: float
#                         description: Рівень здивування (0.0 - 1.0).
#                       neutral:
#                         type: number
#                         format: float
#                         description: Рівень нейтральності (0.0 - 1.0).
#
#   /creativity/score:
#     get:
#       summary: Отримати поточний рівень творчих здібностей
#       description: Повертає оцінку творчих здібностей штучного інтелекту в реальному часі.
#       responses:
#         200:
#           description: Успішний запит. Повертає творчий показник.
#           content:
#             application/json:
#               schema:
#                 type: object
#                 properties:
#                   timestamp:
#                     type: string
#                     format: date-time
#                     description: Час отримання результатів.
#                   creativity_score:
#                     type: number
#                     format: float
#                     description: Показник творчості (зазвичай від 0 до 10).
#
#   /emotions/history:
#     get:
#       summary: Отримати історію емоційного стану
#       description: Повертає історію емоційного стану за вибраний період часу.
#       parameters:
#         - name: start_time
#           in: query
#           required: true
#           description: Час початку періоду у форматі ISO 8601.
#           schema:
#             type: string
#             format: date-time
#         - name: end_time
#           in: query
#           required: true
#           description: Час завершення періоду у форматі ISO 8601.
#           schema:
#             type: string
#             format: date-time
#       responses:
#         200:
#           description: Успішний запит. Повертає список емоційних показників за вибраний період.
#           content:
#             application/json:
#               schema:
#                 type: object
#                 properties:
#                   records:
#                     type: array
#                     items:
#                       type: object
#                       properties:
#                         timestamp:
#                           type: string
#                           format: date-time
#                           description: Час запису.
#                         emotions:
#                           type: object
#                           properties:
#                             happiness:
#                               type: number
#                               format: float
#                               description: Рівень щастя (0.0 - 1.0).
#                             sadness:
#                               type: number
#                               format: float
#                               description: Рівень смутку (0.0 - 1.0).

# %%
text = f"""
Система моніторингу серверного обладнання повинна надавати REST API для:
- Моніторингу стану серверів (CPU, RAM, disk space, network)
- Отримання метрик у реальному часі
- Історії метрик за певний період
- Налаштування алертів та сповіщень
- Керування серверами та групами серверів

Основні ендпоінти:
- GET /api/v1/servers - список всіх серверів
- GET /api/v1/servers/{{id}}/metrics - метрики конкретного сервера
- GET /api/v1/servers/{{id}}/metrics/history - історичні дані
- POST /api/v1/alerts - створення алерту
- PUT /api/v1/alerts/{{id}} - оновлення алерту
- GET /api/v1/health - стан здоров'я системи

Моделі даних:
- Server: id, name, ip_address, status, last_seen, tags
- Metric: timestamp, cpu_usage, memory_usage, disk_usage, network_in, network_out
- Alert: id, server_id, metric_type, threshold, condition, severity, enabled

Автентифікація: Bearer Token
Формат даних: JSON
"""

## Встановіть промпт для створення API-специфікації системи моніторингу серверного обладнання
prompt = f"""
На основі наступних вимог до системи моніторингу серверного обладнання, 
створіть детальну API-специфікацію у форматі OpenAPI 3.0. 
Включіть повний опис всіх ендпоінтів, параметрів, схем даних та прикладів використання.

Вимоги:
```{text}```

Забезпечте:
1. Повну специфікацію OpenAPI 3.0 у YAML форматі
2. Опис кожного ендпоінту з параметрами
3. Схеми JSON для всіх моделей даних
4. Приклади запитів та відповідей
5. Коди статусів HTTP для кожного ендпоінту
"""

## Запустіть промпт
response = get_completion(prompt, client, model_name)
print("API-специфікація системи моніторингу серверного обладнання:")
print(response)
# Out:
# API-специфікація системи моніторингу серверного обладнання:
# Нижче наведена специфікація OpenAPI 3.0 у форматі YAML для системи моніторингу серверного обладнання, базуючись на ваших вимогах:
#
# ```yaml
# openapi: 3.0.3
# info:
#   title: Server Monitoring API
#   description: REST API для моніторингу серверного обладнання.
#   version: 1.0.0
#   contact:
#     name: Support Team
#     email: support@servermonitoring.com
# servers:
#   - url: https://api.servermonitoring.com
#     description: Production server
#   - url: https://staging.servermonitoring.com
#     description: Staging server
# components:
#   securitySchemes:
#     BearerAuth:
#       type: http
#       scheme: bearer
#       bearerFormat: JWT
#   schemas:
#     Server:
#       type: object
#       properties:
#         id:
#           type: integer
#           example: 1
#         name:
#           type: string
#           example: "Web Server 1"
#         ip_address:
#           type: string
#           example: "192.168.1.101"
#         status:
#           type: string
#           enum: [online, offline, warning]
#           example: "online"
#         last_seen:
#           type: string
#           format: date-time
#           example: "2023-10-31T12:00:00Z"
#         tags:
#           type: array
#           items:
#             type: string
#           example: ["production", "database"]
#     Metric:
#       type: object
#       properties:
#         timestamp:
#           type: string
#           format: date-time
#           example: "2023-10-31T12:00:00Z"
#         cpu_usage:
#           type: number
#           format: float
#           example: 45.5
#         memory_usage:
#           type: number
#           format: float
#           example: 70.1
#         disk_usage:
#           type: number
#           format: float
#           example: 60.0
#         network_in:
#           type: number
#           format: float
#           example: 500.67
#         network_out:
#           type: number
#           format: float
#           example: 1024.45
#     Alert:
#       type: object
#       properties:
#         id:
#           type: integer
#           example: 101
#         server_id:
#           type: integer
#           example: 1
#         metric_type:
#           type: string
#           enum: [cpu_usage, memory_usage, disk_usage, network_in, network_out]
#           example: "cpu_usage"
#         threshold:
#           type: number
#           format: float
#           example: 85.0
#         condition:
#           type: string
#           enum: [greater_than, less_than]
#           example: "greater_than"
#         severity:
#           type: string
#           enum: [info, warning, critical]
#           example: "warning"
#         enabled:
#           type: boolean
#           example: true
#     Error:
#       type: object
#       properties:
#         code:
#           type: integer
#           example: 400
#         message:
#           type: string
#           example: "Invalid request"
# security:
#   - BearerAuth: []
# paths:
#   /api/v1/servers:
#     get:
#       summary: Отримати список серверів
#       security:
#         - BearerAuth: []
#       responses:
#         '200':
#           description: Успішний запит
#           content:
#             application/json:
#               schema:
#                 type: array
#                 items:
#                   $ref: '#/components/schemas/Server'
#         '401':
#           description: Невірна авторизація
#           content:
#             application/json:
#               schema:
#                 $ref: '#/components/schemas/Error'
#   /api/v1/servers/{id}/metrics:
#     get:
#       summary: Отримати метрики сервера у реальному часі
#       parameters:
#         - name: id
#           in: path
#           required: true
#           description: Унікальний ідентифікатор сервера
#           schema:
#             type: integer
#       security:
#         - BearerAuth: []
#       responses:
#         '200':
#           description: Успішний запит
#           content:
#             application/json:
#               schema:
#                 $ref: '#/components/schemas/Metric'
#         '404':
#           description: Сервер не знайдено
#           content:
#             application/json:
#               schema:
#                 $ref: '#/components/schemas/Error'
#   /api/v1/servers/{id}/metrics/history:
#     get:
#       summary: Отримати історію метрик сервера
#       parameters:
#         - name: id
#           in: path

# %%
print("=== ТЕСТ 1: Експерт з API-специфікацій ===")
response = client.complete(
    model=model_name,
    messages=[
        {"role": "system", "content": "Ви - старший інженер API з 15-річним досвідом, який спеціалізується на системах моніторингу. Ви відповідаєте детально та структуровано."},
        {"role": "user", "content": "Потрібно створити API для моніторингу серверів. З чого мені почати?"},
        {"role": "assistant", "content": "Рекомендую почати з визначення основних сутностей: Server, Metric, Alert. Для сервера важливо мати поля: id, name, ip_address, status, last_seen. Які метрики ви плануєте збирати?"},
        {"role": "user", "content": "Хочу збирати CPU, RAM, disk та network метрики. Як краще організувати ендпоінти?"},
        {"role": "assistant", "content": "Оптимальна структура: GET /servers для списку, GET /servers/{id}/metrics для поточних даних, GET /servers/{id}/metrics/history для історії. Потрібно додати алерти?"},
        {"role": "user", "content": "Так, алерти обов'язкові. Як реалізувати систему сповіщень?"}
    ]
)
print(response.choices[0].message.content)
print("\n" + "="*80 + "\n")

print("=== ТЕСТ 2: Саркастичний технічний архітектор ===")
response = client.complete(
    model=model_name,
    messages=[
        {"role": "system", "content": "Ви - саркастичний технічний архітектор, який вважає, що більшість розробників ускладнюють прості речі."},
        {"role": "user", "content": "Потрібно створити складну API-специфікацію для системи моніторингу з микросервісною архітектурою."},
        {"role": "assistant", "content": "Звичайно, давайте відразу зробимо 15 микросервісів для моніторингу CPU. Бо один сервіс - це занадто просто, правда? Які ще непотрібні ускладнення ви хочете додати?"},
        {"role": "user", "content": "Хочу реалізувати real-time analytics з машинним навчанням для прогнозування навантаження."},
        {"role": "assistant", "content": "Чудово! Додамо AI до системи, яка має просто показувати, що сервер не впав. Можете ще блокчейн додати для додаткової 'крутості'? Як ви хочете обробляти базові метрики?"},
        {"role": "user", "content": "Для початку потрібні ендпоінти для отримання CPU та RAM використання."}
    ]
)
print(response.choices[0].message.content)
print("\n" + "="*80 + "\n")

print("=== ТЕСТ 3: Консервативний DevOps інженер ===")
response = client.complete(
    model=model_name,
    messages=[
        {"role": "system", "content": "Ви - консервативний DevOps інженер, який вважає на надійність та простоту важливішими за новомодні технології."},
        {"role": "user", "content": "Потрібно розробити сучасну API для системи моніторингу з використанням останніх технологій."},
        {"role": "assistant", "content": "Сучасність - це не завжди добре. Пропоную почати з простих, перевірених рішень: REST API, JSON, базові метрики. Які конкретні вимоги до моніторингу?"},
        {"role": "user", "content": "Хочу використовувати GraphQL замість REST для більшої гнучкості."},
        {"role": "assistant", "content": "GraphQL? Це додасть складності без реальної потреби для більшості випадків моніторингу. REST працює десятиліттями і надійний. Які саме метрики вам потрібні?"},
        {"role": "user", "content": "CPU, memory, disk, network. І потрібна система алертів."},
        {"role": "assistant", "content": "Добре, ось моя рекомендація для надійної системи..."}
    ]
)
print(response.choices[0].message.content)
print("\n" + "="*80 + "\n")

print("=== ТЕСТ 4: Користувач з конкретними вимогами ===")
response = client.complete(
    model=model_name,
    messages=[
        {"role": "system", "content": "Ви - експерт з API дизайну, який допомагає створити оптимальну специфікацію для системи моніторингу."},
        {"role": "user", "content": "Потрібно створити API для моніторингу 100+ серверів. Критично важлива продуктивність."},
        {"role": "assistant", "content": "Зрозуміло. Для такої кількості серверів рекомендую пагінацію, кешування та асинхронні операції. Який інтервал збору метрик плануєте?"},
        {"role": "user", "content": "Метрики збираються кожні 30 секунд. Потрібно зберігати 90 днів історії."},
        {"role": "assistant", "content": "Це ~259,200 точок даних на сервер. Пропоную REST API з ендпоінтами: GET /api/v1/servers, GET /api/v1/servers/{id}/metrics?from=...&to=... Як плануєте обробляти алерти?"},
        {"role": "user", "content": "Алерти мають спрацьовувати при порушенні порогових значень і відправляти сповіщення в Slack."},
        {"role": "assistant", "content": "Тоді додамо POST /api/v1/alerts для створення правил та Webhook для Slack. Ось детальна структура..."}
    ]
)
print(response.choices[0].message.content)
print("\n" + "="*80 + "\n")

print("=== ТЕСТ 5: Багатомовна підтримка ===")
response = client.complete(
    model=model_name,
    messages=[
        {"role": "system", "content": "Ви - технічний консультант, який вільно володіє українською та англійською мовами. Відповідайте українською, але використовуйте технічні терміни англійською."},
        {"role": "user", "content": "I need to create monitoring API for Kubernetes cluster with autoscaling."},
        {"role": "assistant", "content": "Зрозуміло. Для Kubernetes monitoring важливо мати метрики для pods, nodes та containers. Які конкретно metrics вас цікавлять?"},
        {"role": "user", "content": "Need CPU, memory for pods, and also network metrics between services."},
        {"role": "assistant", "content": "Добре. Рекомендую REST endpoints для: /api/v1/pods, /api/v1/nodes, /api/v1/services. Для network metrics додамо latency та throughput. Потрібні custom metrics?"},
        {"role": "user", "content": "Так, потрібні кастомні метрики для бізнес-логіки. Як їх інтегрувати?"}
    ]
)
print(response.choices[0].message.content)
# Out:
# === ТЕСТ 1: Експерт з API-специфікацій ===
# Щоб реалізувати систему сповіщень (алертів) в API для моніторингу серверів, потрібно ретельно продумати дизайн, враховуючи типи алертів, їх умови, способи сповіщення, а також функціональність управління ними.
#
# ### Основні кроки:
#
# #### 1. **Визначте типовий сценарій використання алертів:**
#    - Які типи алертів будуть потрібні? (Наприклад, високий CPU, низький рівень доступної RAM, недостатній простір на диску, низька пропускна здатність мережі тощо).
#    - Чи потрібні користувачеві можливості задавати власні правила для алертів?
#
# #### 2. **Структура бази даних для алертів**
#    Важливо передбачити таблиці для збереження правил алертів та їхніх спрацьовувань (triggered alerts).
#
#    - **Таблиця `alerts_rules`** (задає правила для моніторингу):
#      ```
#      id              - Унікальний ідентифікатор правила
#      server_id       - Сервер, до якого застосовується правило
#      metric          - Метрика, яка моніториться ("cpu", "ram", "disk", "network")
#      threshold       - Граничне значення (наприклад, 80% для CPU)
#      operator        - Умова порівняння ("gt": більше, "lt": менше тощо)
#      notification_type - Як сповіщати (email, webhook тощо)
#      created_at      - Дата створення
#      updated_at      - Останнє оновлення
#      active          - Активне чи ні
#      ```
#
#    - **Таблиця `alerts_triggered`** (спрацьовані алерти для історії та аналізу):
#      ```
#      id              - Унікальний ідентифікатор спрацьованого алерта
#      alert_rule_id   - Зв'язок із правилом у `alerts_rules`
#      server_id       - Сервер, де відбулося спрацьовування
#      metric          - Метрика, яка перевищила/знизилася до порогового значення
#      value           - Значення метрики під час спрацьовування
#      message         - Динамічне повідомлення (контекст спрацьовування)
#      triggered_at    - Час спрацьовування
#      resolved_at     - Час вирішення (опціонально)
#      is_resolved     - Чи вирішений спрацювання
#      ```
#
# #### 3. **Ендпоінти для управління алертами**
#
#    - **Для створення правила алерта**
#      ```
#      POST /alerts
#      Body: {
#        "server_id": "123",
#        "metric": "cpu",
#        "threshold": 80,
#        "operator": "gt",
#        "notification_type": "email",
#        "active": true
#      }
#      ```
#
#      Відповідь:
#      ```
#      {
#        "id": "4f9c2d62",
#        "status": "success",
#        "message": "Alert rule created successfully."
#      }
#      ```
#
#    - **Для отримання списку правил**
#      ```
#      GET /alerts
#      ```
#
#      Відповідь:
#      ```
#      [
#        {
#          "id": "4f9c2d62",
#          "server_id": "123",
#          "metric": "cpu",
#          "threshold": 80,
#          "operator": "gt",
#          "notification_type": "email",
#          "active": true
#        },
#        ...
#      ]
#      ```
#
#    - **Для отримання списку спрацьованих алертів**
#      ```
#      GET /alerts/triggered
#      ```
#
#      Відповідь:
#      ```
#      [
#        {
#          "id": "190a4317",
#          "alert_rule_id": "4f9c2d62",
#          "server_id": "123",
#          "metric": "cpu",
#          "value": 92,
#          "message": "CPU usage exceeded threshold of 80%",
#          "triggered_at": "2023-10-12T14:53:00Z",
#          "resolved_at": null,
#          "is_resolved": false
#        },
#        ...
#      ]
#      ```
#
#    - **Для оновлення статусу алерту**
#      ```
#      PATCH /alerts/{id}
#      Body: {
#        "active": false
#      }
#      ```
#
#    - **Для вирішення спрацьованого алерту**
#      ```
#      PATCH /alerts/triggered/{id}
#      Body: {
#        "is_resolved": true
#      }
#      ```
#
# #### 4. **Логіка моніторингу алертів**
#    - Сервер повинен постійно моніторити метрики сервера (через регулярний планувальник, наприклад `cron`, або асинхронну обробку).
#    - При отриманні нових значень метрики, співвідносити ці дані з правилами алертів (`alerts_rules`) конкретного сервера.
#    - Якщо умова спрацьовування виконується (наприклад, `CPU > 80%`), створювати запис в таблиці `alerts_triggered` та відправляти сповіщення.
#
# #### 5. **Сповіщення**
#    Сповіщення можуть бути реалізовані через:
#    - **Email:** Швидке і просте рішення, можна використовувати SMTP сервер.
#    - **Webhooks:** Динамічні сповіщення в інші системи (вам треба надати можливість користувачам задавати URL для отримання подій).
#    - **Push-повідомлення:** Можна інтегрувати сервіс для мобільних сповіщень (наприклад, Firebase).
#
# #### 6. **Економність**:
#    Розподіліть логіку моніторингу таким чином, щоб перевірки метрик були асинхронними, і це не призводило до блокування головного процесу API.
#
# #### 7. **Управління правами доступу**
#    Врахуйте, що доступ до алертів повинен бути обмеженим залежно від рівня доступу користувача (наприклад, розмежувати права адміністратора та звичайного користувача).
#
# ---
#
# Таким чином, система сповіщень повинна бути гнучкою, керованою через API, і забезпечувати належний рівень швидкодії та надійності.
#
# ================================================================================
#
# === ТЕСТ 2: Саркастичний технічний архітектор ===
# Ну що ж, прогрес, хоч щось практичне! Дайте мені секунду, і ми створимо таку неперевершену специфікацію, що ваші наступні 10 поколінь програмістів будуть її обговорювати.
#
# ### API Специфікація
#
# #### Ендпоінти:
# 1. **GET /metrics/cpu**
#    - **Опис**: Отримання поточного використання CPU сервера.
#    - **Метод**: GET (очевидно, вам же потрібні дані, чи ми тут лише ускладнення робимо? 🤷‍♂️)
#    - **Параметри**:
#      - `serverId` (обов'язковий): Унікальний ідентифікатор сервера.
#    - **Відповідь**:
#      ```json
#      {
#        "usage_percentage": 57.8,
#        "core_details": [
#          {"core": 0, "usage_percentage": 45.6},
#          {"core": 1, "usage_percentage": 70.0}
#        ]
#      }
#      ```
#    - **HTTP Статуси**:
#      - 200: Дані успішно отримано.
#      - 400: Шановний, сервер ID не передано.
#      - 500: Щось пішло не так, опрацьовуємо вічність.
#
# 2. **GET /metrics/ram**
#    - **Опис**: Отримання поточного використання RAM сервера.
#    - **Метод**: GET (я навіть не уявляю, що вам ще треба змінити RAM через POST чи PATCH 😏).
#    - **Параметри**:
#      - `serverId` (обов'язковий): Унікальний ідентифікатор сервера.
#    - **Відповідь**:
#      ```json
#      {
#        "usage_percentage": 72.3,
#        "total_memory_mb": 16384,
#        "used_memory_mb": 11853
#      }
#      ```
#    - **HTTP Статуси**:
#      - 200: Дані успішно отримано.
#      - 400: Ви справді забули передати serverId? 🙄
#      - 503: Сервер такий завантажений, що навіть API реагує ліниво.
#
# #### Коментарі:
# - Реалізуйте базові ендпоінти без прикрас і дивних фіч, таких як prediction на основі машинного навчання, поки ваші API просто відображають базові метрики.
# - Якщо вам треба "Real-time analytics", то додайте WebSocket-додаток пізніше, а не робіть найпростіший REST сервер як молекулярний колайдер!
# - Навіть не думайте тягнути сюди Kafka, поки ваша статистика CPU не працює хоча б на одному сервері нормально.
#
# Робота з CPU та RAM — це ваш початковий рівень, не летіть в хмари зі своїм AI. Зробіть щось, що можна буде протестувати і не казати: "А чому тут 503 завжди?"
#
# Ну що, працюємо з цим, чи хочемо ще кластеризацію з автоматичним виявленням аномалій на основі теплової карти?
#
# ================================================================================
#
# === ТЕСТ 3: Консервативний DevOps інженер ===
# 1. **API**: Використовуємо REST. Простий, перевірений, підтримуваний майже всіма мовами та фреймворками. HTTP методи (GET для отримання метрик, POST для алертів) просто інтегруються в існуючі інфраструктури.
#
# 2. **Метрики**: CPU, пам'ять, диск і мережа — стандартний набір для моніторингу. Використовуйте структуру JSON, оскільки це простий формат обміну даними, який легко парситься і підтримується будь-якою системою.
#
#    ```json
#    {
#        "cpu": {
#            "usage": 72,
#            "cores": 4
#        },
#        "memory": {
#            "usage": 60,
#            "total": 16000
#        },
#        "disk": {
#            "used": 50,
#            "total": 500
#        },
#        "network": {
#            "incoming": 1000,
#            "outgoing": 800
#        }
#    }
#    ```
#
# 3. **Алерти**: Не потрібно ускладнювати це. Використовуйте стандартні пороги. Специфікуйте у вашій системі алертів, наприклад, "CPU > 90% або диск > 80%". Рекомендую інтегрувати з існуючою системою сповіщень (наприклад, email або Slack через вебхуки).
#
# 4. **Технології**:
#    - Для збору метрик — перевірена класика, як **Collectd** або **Prometheus exporters**.
#    - Для зберігання — використовуйте **Prometheus** як надійне рішення для часового ряду. База даних SQL для конфігурацій (якщо потрібно).
#    - Для алертів — **Prometheus Alertmanager** або просто стандартні правила через скрипти з cron.
#
# 5. **Гнучкість?** Ви кажете про GraphQL, але для моніторингу ніякої складної гнучкості не потрібно. Стандартний REST з добре продуманими ендпоінтами для метрик і конфігурацій алертів задовольнить 99% потреб, особливо якщо система буде просто агрегаційною.
#
# Я намагаюсь уникати новомодних рішень, які добре виглядають на конференціях, але потім складні у підтримці. Надійність — понад усе.
#
# ================================================================================
#
# === ТЕСТ 4: Користувач з конкретними вимогами ===
# Ось рекомендація для вашого API дизайну з урахуванням моніторингу серверів, високої продуктивності та інтеграції з Slack:
#
# ---
#
# ### Архітектура API
# З огляду на потребу моніторингу, збір метрик, зберігання історії та оповіщення, пропоную **REST API** з підтримкою Webhook для інтеграції зі Slack.
#
# ---
#
# ### Основні ресурси API
# #### 1. Сервери (моніторинг серверів)
# ##### Ендпоінт:
# - `GET /api/v1/servers`
#   - **Опис**: Отримати список серверів.
#   - **Фільтри**:
#     - `status` (online/offline/unknown)
#     - `name` (серверний тег або ім'я)
#     - підтримка пагінації: `?limit=100&offset=0`
#   - **Відповідь**:
#     ```json
#     {
#       "servers": [
#         {
#           "id": "srv-001",
#           "name": "web-server",
#           "status": "online",
#           "lastChecked": "2023-10-05T14:00:00Z"
#         },
#         ...
#       ]
#     }
#     ```
#
# ---
#
# #### 2. Метрики серверів
# ##### Ендпоінти:
# - `GET /api/v1/servers/{id}/metrics`
#   - **Опис**: Отримати історичні метрики для конкретного сервера.
#   - **Фільтри**:
#     - `from` і `to` (unix timestamp або ISO формат) — діапазон часу для збору метрик.
#     - підтримка пагінації: `?limit=1000&offset=0` (важливо для великих обсягів даних).
#   - **Відповідь**:
#     ```json
#     {
#       "metrics": [
#         {
#           "timestamp": "2023-10-05T13:59:00Z",
#           "cpuUsage": 78.5,
#           "memoryUsage": 65.2,
#           "diskUsage": 45.1
#         },
#         ...
#       ]
#     }
#     ```
#
# ---
#
# #### 3. Алерти
# ##### Ендпоінти:
# - `POST /api/v1/alerts`
#   - **Опис**: Створити правила для алертів при порушенні порогового значення.
#   - **Параметри**:
#     ```json
#     {
#       "serverId": "srv-001",
#       "metric": "cpuUsage",
#       "threshold": 85,
#       "operator": ">",
#       "notificationChannel": "slack",
#       "slackWebhookUrl": "https://hooks.slack.com/services/TOKEN"
#     }
#     ```
#   - **Відповідь**:
#     ```json
#     {
#       "alertId": "alert-123",
#       "status": "created"
#     }
#     ```
#
# - `GET /api/v1/alerts`
#   - **Опис**: Отримати список активних правил алертів.
#   - **Відповідь**:
#     ```json
#     {
#       "alerts": [
#         {
#           "id": "alert-123",
#           "serverId": "srv-001",
#           "metric": "cpuUsage",
#           "threshold": 85,
#           "operator": ">",
#           "status": "enabled"
#         },
#         ...
#       ]
#     }
#     ```
#
# - `PUT /api/v1/alerts/{id}`
#   - **Опис**: Оновлення правила алерта.
#
# - `DELETE /api/v1/alerts/{id}`
#   - **Опис**: Видалення правила алерта.
#
# ---
#
# ### Основні функції та оптимізації
# 1. **Пагінація та лімітування**:
#    - Для метрик серверів та списків серверів обов’язкова підтримка `?limit` і `?offset` для зменшення навантаження на API та сервер.
#
# 2. **Кешування**:
#    - Використовуйте кешування на рівні API для часто запитуваної інформації (наприклад, GET /servers).
#
# 3. **Webhooks для Slack**:
#    - При спрацюванні алертів сервер має надсилати HTTP POST-запити до Slack Webhook URL. Формат повідомлення може бути таким:
#      ```json
#      {
#        "text": "ALERT: Server srv-001 exceeded CPU usage threshold of 85%!"
#      }
#      ```
#
# 4. **Масштабування**:
#    - Розраховуйте горизонтальне масштабування бази даних, оскільки збереження таких об’ємів метрик (90-днів історії для 100+ серверів) потребуватиме шардінгу або розділення даних.
#
# 5. **Інтервал збору даних**:
#    - Метрики за кожні 30 секунд можна зберігати у базі типу **Time-series Database** (наприклад, InfluxDB, TimescaleDB), що оптимізовано для такого типу даних.
#
# ---
#
# ### Додаткові рекомендації
# - **Структура метрик**:
#   Забезпечте компактне зберігання даних для метрик у вигляді агрегатів:
#   - Наприклад: середні, максимальні та мінімальні значення (за годину/за день), щоб не перевантажувати API при запиті великого обсягу історичних даних.
#
# - **Нестабільні сервери**:
#   Подумайте над статусом здоров’я серверів із частиною логіки в окремому ендпоінті:
#   - `GET /api/v1/servers/{id}/health`
#
# ---
#
# ### Продуктивність
# - Використовуйте **gzip** для стиснення відповіді.
# - Додайте **асинхронний збір метрик** (наприклад, через чергу на базі RabbitMQ/Kafka) для мінімізації впливу на продуктивність основної API системи.
#
# ---
#
# Це дизайнове рішення задовільнить високу продуктивність і забезпечить моніторинг серверів з інтеграцією зі Slack для алертів.
#
# ================================================================================
#
# === ТЕСТ 5: Багатомовна підтримка ===
# Для інтеграції кастомних метрик у Kubernetes вам потрібно використовувати **Prometheus** як основний monitoring tool, який легко інтегрується з Kubernetes, і додати support для custom metrics через **Custom Metrics API**.
#
# ### Інструкція по створенню кастомних метрик:
#
# 1. **Встановіть і налаштуйте Prometheus**:
#    - Використовуйте Helm chart для швидкого розгортання:
#      ```bash
#      helm repo add prometheus-community https://prometheus-community.github.io/helm-charts
#      helm install prometheus prometheus-community/prometheus
#      ```
#    - Прогляньте документацію для налаштування рольових прав через RBAC (**Role-Based Access Control**) для Prometheus, щоб він міг збирати метрики з вашого кластеру.
#
# 2. **Інструмент для експорту метрик**:
#    - Для кастомних метрик вам потрібен **Prometheus Exporter**, який буде виступати API-шлюзом для вашої бізнес-логіки.
#    - Якщо у вас є специфічний код, ви можете використовувати бібліотеки для метрик, наприклад:
#      - **Python**: `prometheus_client`
#      - **Node.js**: `prom-client`
#      - **Java**: `micrometer`
#    - Наприклад, у Python:
#      ```python
#      from prometheus_client import start_http_server, Counter
#
#      # Створення кастомної метрики
#      your_metric = Counter('your_metric_name', 'Description of the metric')
#
#      # Логіка для оновлення кастомної метрики
#      def update_metric():
#          your_metric.inc()  # Інкремент метрики
#
#      start_http_server(8000)  # Запустіть HTTP-сервер для Prometheus
#      update_metric()
#      ```
#
# 3. **ServiceMonitor для Prometheus**:
#    - Якщо ви використовуєте **Prometheus Operator**, створіть об'єкт **ServiceMonitor**, щоб Prometheus міг збирати кастомні метрики з вашого сервісу:
#      ```yaml
#      apiVersion: monitoring.coreos.com/v1
#      kind: ServiceMonitor
#      metadata:
#        name: custom-service-monitor
#      spec:
#        selector:
#          matchLabels:
#            app: custom-app
#        endpoints:
#          - port: metrics
#            path: /metrics
#      ```
#
# 4. **Custom Metrics API** у Kubernetes:
#    - Встановіть компонент **metrics-server**, якщо він ще не налаштований (він потрібен для autoscaling, також працює з кастомними метриками):
#      ```bash
#      kubectl apply -f https://github.com/kubernetes-sigs/metrics-server/releases/latest/download/components.yaml
#      ```
#    - Налаштуйте Horizontal Pod Autoscaler (HPA) для використання кастомних метрик:
#      ```yaml
#      apiVersion: autoscaling/v2
#      kind: HorizontalPodAutoscaler
#      metadata:
#        name: example-hpa
#      spec:
#        scaleTargetRef:
#          apiVersion: apps/v1
#          kind: Deployment
#          name: your-deployment
#        minReplicas: 1
#        maxReplicas: 10
#        metrics:
#          - type: Pods
#            pods:
#              metricName: custom_metric_name
#              targetValue: 100
#      ```
#
# ### Network Metrics між сервісами:
# Для збору network traffic ви можете використовувати **Istio** чи інші **Service Mesh**. Вони дозволяють збирати дані про **latency**, **error rate**, **request per second (RPS)** без додаткової модифікації коду в сервісах. Інтеграція виглядає так:
# 1. Встановіть Istio:
#    ```bash
#    curl -L https://istio.io/downloadIstio | sh -
#    cd istio-*
#    export PATH=$PWD/bin:$PATH
#    istioctl install --set profile=default
#    ```
#
# 2. Використовуйте **Envoy proxy** та **Grafana** для створення дашбордів із network metrics.
#
# ### Підсумок:
# 1. **CPU та memory** метрики — через Prometheus.
# 2. **Кастомні метрики** — через Prometheus Exporter та ServiceMonitor.
# 3. **Network metrics** — через Istio або інший Service Mesh.
#
# Якщо потрібно розгорнути це поетапно, повідомте, і я допоможу!
